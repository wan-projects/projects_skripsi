# %%
# # ACC

# import os
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
# from PIL import UnidentifiedImageError  # Import UnidentifiedImageError

# # Definisi path input dan output
# directory_input = "../data/data_original/Pengenalan Aksara Jawa.v1/train"
# directory_output = "../data/data_preprocessing/v1.1/"

# # Membuat objek ImageDataGenerator untuk augmentasi gambar
# datagen = ImageDataGenerator(
#     rotation_range=19,
#     shear_range=0.1,
#     zoom_range=0.1,
#     fill_mode='nearest'
# )

# # Menetapkan ukuran gambar target
# target_size = (96, 96)

# # Mengambil daftar nama file dari folder input
# file_list = os.listdir(directory_input)

# # Inisialisasi DataFrame kosong untuk menyimpan label hasil augmentasi
# augmented_label_data = pd.DataFrame(columns=["filename"] + label_data.columns.tolist())

# # Mengulang setiap file gambar
# for filename in file_list:
#     try:  # Tambahkan blok try-except untuk menangani kesalahan saat memuat gambar
#         # Membuat directory baru untuk hasil augmentasi
#         output_dir = directory_output  # Output langsung ke folder data_preprocessing
#         os.makedirs(output_dir, exist_ok=True)

#         # Memuat gambar dan mengubah ukurannya
#         img = load_img(os.path.join(directory_input, filename), target_size=target_size)

#         # Mengonversi gambar menjadi array numpy
#         img_array = img_to_array(img)

#         # Menyimpan hasil augmentasi ke dalam folder output dalam format PNG
#         for i, img_aug_array in enumerate(datagen.flow(x=img_array.reshape((1,) + img_array.shape),
#                                                         batch_size=1)):
#             img_aug = array_to_img(img_aug_array[0])

#             # Menyimpan hasil augmentasi ke dalam folder output dalam format PNG
#             output_filename = f"{filename.split('.')[0]}_{i}.png"  # Mengubah ekstensi ke PNG
#             output_path = os.path.join(output_dir, output_filename)
#             img_aug.save(output_path, format='PNG')  # Menyimpan dalam format PNG

#             # Menambahkan label hasil augmentasi ke DataFrame
#             label = label_data[label_data['filename'] == filename]
#             augmented_label = label.copy()
#             augmented_label['filename'] = output_filename
#             if augmented_label_data.empty:  # Memeriksa apakah DataFrame sudah diinisialisasi
#                 augmented_label_data = augmented_label  # Jika belum, gunakan DataFrame pertama sebagai inisialisasi
#             else:
#                 augmented_label_data = pd.concat([augmented_label_data, augmented_label], ignore_index=True)

#             # Batasi jumlah augmentasi menjadi 5 gambar
#             if i == 2:
#                 break

#     except (UnidentifiedImageError, FileNotFoundError) as e:  # Tangkap UnidentifiedImageError dan FileNotFoundError
#         # print(f"Error: {filename} tidak dapat diidentifikasi sebagai file gambar. Melewatinya...")
#         continue  # Lanjutkan ke file berikutnya jika terjadi kesalahan

# # Menyimpan data label hasil augmentasi ke dalam file CSV
# augmented_label_data.to_csv("../data/data_preprocessing/v1.1/augmented_labels.csv", index=False)

# %%
import os
import matplotlib.pyplot as plt

# Path folder dataset
dataset_folder = "../data/data_preprocessing/v1.1/"

# Memilih satu gambar dari setiap kelas
unique_classes = os.listdir(dataset_folder)  # Mengambil nama subfolder sebagai kelas
sample_images = []

for class_folder in unique_classes:
    class_path = os.path.join(dataset_folder, class_folder)
    if os.path.isdir(class_path):
        # Ambil nama file gambar dari subfolder kelas
        image_files = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
        if image_files:
            # Ambil salah satu gambar dari subfolder
            sample_image_filename = image_files[0]
            sample_image_path = os.path.join(class_path, sample_image_filename)
            sample_images.append(sample_image_path)

# Menampilkan gambar yang dipilih dari setiap kelas
num_images = len(sample_images)
plt.figure(figsize=(16, 12))
for i, sample_image_path in enumerate(sample_images, 0):
    plt.subplot(4, 5, i + 1)
    img = plt.imread(sample_image_path)
    plt.imshow(img)
    plt.title(os.path.basename(os.path.dirname(sample_image_path)), fontsize=19)  # Nama kelas dari nama subfolder
    plt.axis('on')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

main_path = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\"
file = main_path + "augmented_labels.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                                             filename  width  height class  \
# 0  ga_original_ga16-meki-png_0f30e507-35d9-440c-b...    640     640    Ga
# 1  ga_original_ga16-meki-png_0f30e507-35d9-440c-b...    640     640    Ga
# 2  ga_original_ga16-meki-png_0f30e507-35d9-440c-b...    640     640    Ga
# 3  ga_original_ga16-meki-png_0f30e507-35d9-440c-b...    640     640    Ga
# 4  ga_original_ga16-meki-png_0f30e507-35d9-440c-b...    640     640    Ga
#
#    xmin  ymin  xmax  ymax
# 0     0     0   622   498
# 1     0     0   622   498
# 2     0     0   622   498
# 3     0     0   622   498
# 4     0     0   622   498

# %%
import matplotlib.pyplot as plt
import os
# Define an empty list
file_counts = []
def countFile(link):
    path = link
    num_files = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
    file_counts.append(num_files)
    print(f"Jumlah File {link} is ", num_files)
    
    
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ba")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ca")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\da")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\dha")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ga")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ha")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ja")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ka")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\la")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ma")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\na")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\nga")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\nya")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\pa")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ra")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\sa")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ta")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\tha")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\wa")
countFile("C:\\Users\\wawn1\\projects_skripsi\\data\\data_preprocessing\\v1.1\\ya")

# Define the input path aksara
c = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na',
                     'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'pink', 'indigo', 'purple', 
          'cyan', 'magenta', 'lime', 'maroon', 'navy', 'olive', 'orchid', 'peru', 
          'salmon', 'sienna', 'skyblue', 'tan']  # Colors for each bar

# Create bar chart
plt.figure(figsize=(10, 5))
plt.bar(aksara_categories, file_counts, color=colors)
plt.xlabel('Kategori Aksara', fontsize=14)
plt.ylabel('Jumlah Gambar', fontsize=14)
plt.title('Jumlah Gambar Aksara Jawa', fontsize=16)
plt.xticks(fontsize=12, rotation=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ba is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ca is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\da is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\dha is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ga is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ha is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ja is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ka is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\la is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\ma is  684
# Jumlah File C:\Users\wawn1\projects_skripsi\data\data_preprocessing\v1.1\na is  684
# ...

# %%
AksaraJawa = [f.name for f in os.scandir(main_path) if f.is_dir()]

# Define the target image size
image_size = (96, 96)

print("Jumlah Kategori Emosi:", len(AksaraJawa))
print(AksaraJawa)
# Out:
# Jumlah Kategori Emosi: 20
# ['Ba', 'Ca', 'Da', 'Dha', 'Ga', 'Ha', 'Ja', 'Ka', 'La', 'Ma', 'Na', 'Nga', 'Nya', 'Pa', 'Ra', 'Sa', 'Ta', 'Tha', 'Wa', 'Ya']

# %%
import cv2
import numpy as np
from keras.utils import to_categorical

def apply_laplacian_of_gaussian(image, size, sigma):
    # Convert image to uint8
    image_uint8 = (image * 255).astype(np.uint8)
    
    # Apply Gaussian filter
    gaussian_filtered = cv2.GaussianBlur(image_uint8, (5, 5), 0)
    
    # Apply Laplacian filter
    laplacian_filtered = cv2.Laplacian(gaussian_filtered, cv2.CV_64F)
    
    return laplacian_filtered

def create_image_generator_with_log(input_path, aksara, image_size):
    for index, emotion in enumerate(aksara):
        emotion_path = os.path.join(input_path, emotion)
        for filename in os.listdir(emotion_path):
            image_path = os.path.join(emotion_path, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
            image = cv2.resize(image, image_size)  # Resize image
            
            # Normalization
            image = image.astype('float32') / 255.0
            
            # Apply Laplacian of Gaussian filter
            image_filtered = apply_laplacian_of_gaussian(image, size=3, sigma=1.0)
            
            yield image, image_filtered, index

def load_images(input_path, aksara, image_size):
    X, y = [], []
    
    for image, _, label in create_image_generator_with_log(input_path, aksara, image_size):
        X.append(image)
        y.append(label)
    
    X = np.array(X)
    y = to_categorical(np.array(y))
    
    return X, y

# Load images with Laplacian of Gaussian filter applied
X, y = load_images(main_path, aksara_categories, image_size)

# Define the input shape
input_shape = (96, 96,1)

# Select one image to display
index_to_display = 0
sample_image_original_log = X[index_to_display]
sample_image_filtered_log = apply_laplacian_of_gaussian(sample_image_original_log, size=3, sigma=1.0)

# Apply thresholding for edge detection results
threshold = 5
sample_image_filtered_log_thresholded = np.zeros_like(sample_image_filtered_log)
sample_image_filtered_log_thresholded[sample_image_filtered_log > threshold] = 255

# Display the original image, filtered image, and their difference
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.imshow(sample_image_original_log, cmap='gray')
plt.title("Original Image")

plt.subplot(1, 3, 2)
plt.imshow(sample_image_filtered_log_thresholded, cmap='gray')  
plt.title("Filtered Image (LoG + Threshold)")

# plt.subplot(1, 3, 3)
# plt.imshow(np.abs(sample_image_original_log - sample_image_filtered_log_thresholded), cmap='gray')
# plt.title("Difference")

plt.show()

# %% [markdown]
# follow up

# %%
# import os
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from keras.utils import to_categorical

# def apply_laplacian_of_gaussian(image, size, sigma):
#     # Apply Gaussian filter
#     gaussian_filtered = cv2.GaussianBlur(image, (size, size), sigma)

#     # Apply Laplacian filter
#     laplacian_filtered = cv2.Laplacian(gaussian_filtered, cv2.CV_64F)
    
#     return laplacian_filtered

# def create_image_generator_with_log(input_path, aksara, image_size):
#     for index, jowo in enumerate(aksara):
#         jowo_path = os.path.join(input_path, jowo)
#         for filename in os.listdir(jowo_path):
#             image_path = os.path.join(jowo_path, filename)
#             image = cv2.imread(image_path)
#             # image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
#             image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # Read in grayscale
#             image = cv2.resize(image, image_size)  # Resize image
            
#             # Normalization
#             image = image.astype('float32') / 255.0
            
#             # Apply Laplacian of Gaussian filter
#             image_filtered = apply_laplacian_of_gaussian(image, size=5, sigma=1.0)
            
#             yield image, image_filtered, index

# def load_images(input_path, aksara, image_size):
#     X, y = [], []
    
#     for image, _, label in create_image_generator_with_log(input_path, aksara, image_size):
#         X.append(image)
#         y.append(label)
    
#     X = np.array(X)
#     y = to_categorical(np.array(y))
    
#     return X, y

# # Set the desired image size
# image_size = (96, 96)

# # Load images with Laplacian of Gaussian filter applied
# X, y = load_images(main_path, aksara_categories, image_size)

# # Define the input shape
# input_shape = (*image_size, 1)

# # Select one image to display
# index_to_display = 0
# sample_image_original = X[index_to_display]
# sample_image_filtered = apply_laplacian_of_gaussian(sample_image_original, size=3, sigma=1.0)

# # Apply thresholding for edge detection results
# threshold = 5
# sample_image_filtered_log_thresholded = np.zeros_like(sample_image_filtered_log)
# sample_image_filtered_log_thresholded[sample_image_filtered_log > threshold] = 255

# # Display the original image, grayscale image, and filtered image
# plt.figure(figsize=(12, 4))

# plt.subplot(1, 3, 1)
# plt.imshow(sample_image_original, cmap='gray')
# plt.title("Original Image")

# plt.subplot(1, 3, 2)
# plt.imshow(cv2.cvtColor(sample_image_original, cv2.COLOR_GRAY2RGB))  
# plt.title("Grayscale Image")

# plt.subplot(1, 3, 3)
# plt.imshow(sample_image_filtered, cmap='gray')
# plt.title("Filtered Image (LoG)")

# plt.show()

# %%
print(f"Bentuk input pada gambar: {image_size}")
# Out:
# Bentuk input pada gambar: (96, 96)

# %%
from sklearn.model_selection import train_test_split

# Train test split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Jumlah data pelatihan (X_train):", X_train.shape[0])
print("Jumlah data pengujian (X_test):", X_test.shape[0])
# Out:
# Jumlah data pelatihan (X_train): 9576
# Jumlah data pengujian (X_test): 4104

# %% [markdown]
# # Model 1

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model

from tensorflow.keras.applications import VGG16

vgg16 = tf.keras.applications.VGG16(input_shape=(96,96,3),
                                    pooling=max,
                                    include_top=False,
                                    weights="imagenet")
vgg16.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 96, 96, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 96, 96, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 48, 48, 128)    │        73,856 │
# ...

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import layers, initializers, models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization

model = Sequential()
model.add(vgg16)
model = models.Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.75))

# Block 2
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.75))

# Block 3
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.75))

# Block 4
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.75))

# Block 5
model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.75))

# Flatten
model.add(Flatten())

# Dense layers
model.add(Dense(256, activation='relu', kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.0001, seed=None)))
model.add(BatchNormalization())
model.add(Dropout(0.75))

model.add(Dense(128, activation='relu', kernel_initializer=initializers.RandomNormal(mean=0.0, stddev=0.0001, seed=None)))
model.add(BatchNormalization())
model.add(Dropout(0.75))

# Output layer
model.add(Dense(20, activation='softmax'))

# Adam optimizer with learning rate scheduling, Weight Decay, and Gradient Clipping
opt = Adam(learning_rate=0.0001, weight_decay=1e-4, clipvalue=0.0005)
    
# Compile the model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_39 (Conv2D)              │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
history_v1 = model.fit(X_train, y_train, batch_size=64, epochs=75, validation_data=(X_test, y_test))
# Out:
# Epoch 1/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 850s 5s/step - accuracy: 0.0712 - loss: 3.3520 - val_accuracy: 0.0500 - val_loss: 3.2513
# Epoch 2/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 770s 5s/step - accuracy: 0.0937 - loss: 3.5744 - val_accuracy: 0.0500 - val_loss: 3.2910
# Epoch 3/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 797s 5s/step - accuracy: 0.1163 - loss: 3.4019 - val_accuracy: 0.0500 - val_loss: 4.9518
# Epoch 4/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 769s 5s/step - accuracy: 0.1833 - loss: 3.0912 - val_accuracy: 0.0500 - val_loss: 14.0045
# Epoch 5/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 803s 5s/step - accuracy: 0.2419 - loss: 2.8672 - val_accuracy: 0.0500 - val_loss: 31.2957
# Epoch 6/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 791s 5s/step - accuracy: 0.3066 - loss: 2.6741 - val_accuracy: 0.0500 - val_loss: 25.3781
# Epoch 7/75
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 803s 5s/step - accuracy: 0.3771 - loss: 2.3518 - val_accuracy: 0.0500 - val_loss: 22.1167
# Epoch 8/75
# ...

# %%
# pd.DataFrame(history_v1.history).plot()
# Out:
# <Axes: >

# %%
# Menampilkan grafik training dan validation accuracy
import matplotlib.pyplot as plt

acc_v1 = history_v1.history['accuracy']
val_acc = history_v1.history['val_accuracy']

loss_v1 = history_v1.history['loss']

val_loss = history_v1.history['val_loss']

epochs_range = range(len(acc_v1))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc_v1, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss_v1, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Evaluasi model menggunakan data uji
loss_v1, acc_v1 = model.evaluate(X_test, y_test)

# Print hasil evaluasi
print("Loss:", loss_v1)
print("Accuracy:", acc_v1)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 36s 476ms/step - accuracy: 0.1267 - loss: 10.2303
# Loss: 10.253982543945312
# Accuracy: 0.12833333015441895

# %% [markdown]
# ## Calculates the false positive rate, true positive rate, and AUC score

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt

# Make predictions
y_pred = model.predict(X_test)

# Compute ROC curve and ROC AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(8):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC AUC score
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = roc_auc_score(y_test, y_pred, multi_class='ovr')

# Plot the ROC curves for each class and the micro-average ROC curve
plt.figure(figsize=(8, 6))
lw = 2
plt.plot(fpr["micro"], tpr["micro"], lw=lw, label='micro-average ROC curve (AUC = {0:0.2f})'
                                                   ''.format(roc_auc["micro"]))
colors = ['cornflowerblue', 'darkorange', 'forestgreen', 'red', 'purple', 'gray', 'black', 'pink']
for i, color in zip(range(8), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of {0} (AUC = {1:0.2f})'.format(aksara_categories[i], roc_auc[i]))
    
plt.plot([0, 1], [0, 1], color='gray', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 666ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score,roc_curve,confusion_matrix

y_test_int = np.argmax(y_test, axis=1)
y_pred = model.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)

print(classification_report(y_test_int, y_pred_int))
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 47s 618ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       313
#            1       0.00      0.00      0.00       333
#            2       0.00      0.00      0.00       291
#            3       0.00      0.00      0.00       269
#            4       0.00      0.00      0.00       300
#            5       0.00      0.00      0.00       300
#            6       0.13      1.00      0.23       308
#            7       0.00      0.00      0.00       286
#
#     accuracy                           0.13      2400
#    macro avg       0.02      0.12      0.03      2400
# weighted avg       0.02      0.13      0.03      2400
# c:\Users\wawn1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

plt.figure(figsize=(10, 10))
cm = confusion_matrix(y_test_int, y_pred_int)

# Hitung total sampel untuk setiap kelas aktual
total_per_class = np.sum(cm, axis=1)

# Konversi setiap elemen dalam confusion matrix menjadi persentase
cm_percent = (cm.astype('float') / total_per_class[:, np.newaxis]) * 100

# Gunakan label langsung dari variabel Aksara
emotions_labels = aksara_categories

sns.heatmap(cm_percent, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=emotions_labels, yticklabels=emotions_labels)
plt.xlabel("Predicted Emotions")
plt.ylabel("Actual Emotions")
plt.title("Confusion Matrix (Percentage)")
plt.show()
