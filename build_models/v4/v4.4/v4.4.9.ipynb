# %% [markdown]
# # Note
# 1. Melakukan percobaan build_models v4.0
# 2. Dilakukan pada hari Sabtu, 10 Agustus 2024
# 3. Tempat di Lab
# 4. Data menggunakan Dataset yang dari Roboflow
# 4. Meliputi Class: 20 Kelas Aksara Jawa:
# - Ba, Ca, Da, Dha, Ga, Ha, Ja, Ka, La, Ma,
# - Na, Nga, Nya, Pa, Ra, Sa, Ta, Tha, Wa, Ya

# %% [markdown]
# # Setup Environment

# %%
# pip install tensorflow

# %%
# pip install keras

# %%
# pip install opencv-python

# %%
# pip install imutils

# %%
# pip install matplotlib

# %%
# pip install seaborn

# %%
# pip install scikit-learn

# %% [markdown]
# # Import Library

# %%
# import pandas as pd
# import matplotlib.pyplot as plt  
# import os
# from os.path import join
# import random
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from tensorflow.keras.utils import to_categorical
# from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
# from keras.models import Sequential
# from tensorflow.keras import layers, models
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization , Activation,Conv2D
# from keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# from sklearn.metrics import roc_curve, auc, roc_auc_score
# from sklearn.metrics import classification_report
# import seaborn as sns
# from sklearn.metrics import classification_report, accuracy_score,roc_curve,confusion_matrix

# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
import cv2

def convert_to_png(image_path, output_path):
    # Read the image using OpenCV
    image = cv2.imread(image_path)
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    # Save the image as PNG
    cv2.imwrite(output_path, image)

def get_last_n_parts(path, n):
    return os.path.join(*path.split(os.sep)[-n:])

def create_labels_csv(data_collection, output_csv, path_output):
    # Check if the CSV file already exists
    if os.path.exists(output_csv):
        print(f'Label CSV already exists at: {output_csv}')
        return  # Exit the function if the file already exists
    
    # List to store image file paths and their corresponding labels and dimensions
    data = []

    # Traverse the dataset directory
    for root, dirs, files in os.walk(data_collection):
        for file in files:
            if file.endswith(('.jpg', '.jpeg', '.png')):
                # Get the class label from the subdirectory name
                label = os.path.basename(root)
                # Get the full file path
                file_path = os.path.join(root, file)
                
                # Create a new file path for the PNG image
                relative_path = os.path.relpath(file_path, data_collection)
                png_file_path = os.path.join(path_output, os.path.splitext(relative_path)[0] + '.png')
                
                # Convert the image to PNG
                convert_to_png(file_path, png_file_path)
                
                # Get image dimensions
                img = cv2.imread(file_path)
                height, width, _ = img.shape
                
                # Get only the last 3 parts of the path for CSV
                csv_path = get_last_n_parts(png_file_path, 2)
                
                # Append to the data list including dimensions
                data.append([csv_path, width, height, label])
    
    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=['file_path', 'width', 'height', 'label'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, index=False)
    print(f'Labels CSV file created at: {output_csv}')

# Define the paths for the two datasets and their respective output directories
data_collection = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\dataset_collection\\"
output_csv = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_preprocessing\\dataset\\labels.csv"
path_output = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_preprocessing\\dataset\\"

# Process the dataset
create_labels_csv(data_collection, output_csv, path_output)
# Out:
# Label CSV already exists at: C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\labels.csv

# %%
import pandas as pd

# Path main
PATH_MAIN = path_output
file = PATH_MAIN + "labels.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                                      file_path  width  height label
# 0  ba\002798ad-631c-4f0c-b899-aa66fb5c2ac1.png    239     167    ba
# 1  ba\040ab1c7-bffa-4a93-8c42-54e5597f2243.png     96      67    ba
# 2  ba\0789a0d8-e129-48ec-b74e-2e53f4a7ece9.png    235     166    ba
# 3  ba\11f6c317-635a-4e64-8552-05bf8b7b3a95.png     96      67    ba
# 4  ba\13469389-6f9b-43dc-be99-8dfbfaae51cb.png    235     165    ba

# %%
import matplotlib.pyplot as plt
import os

# Define an empty list
file_counts = []
aksara_categories = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na',
                     'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

def countFile(link):
    path = link
    num_files = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
    file_counts.append(num_files)
    print(f"Jumlah File {link} is ", num_files)

# Define the input path
base_path = PATH_MAIN

# Count files for each category
for category in aksara_categories:
    countFile(os.path.join(base_path, category))

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'pink', 'indigo', 'purple', 
          'cyan', 'magenta', 'lime', 'maroon', 'navy', 'olive', 'orchid', 'peru', 
          'salmon', 'sienna', 'skyblue', 'tan']  # Colors for each bar

# Create bar chart
plt.figure(figsize=(13, 6))
bars = plt.bar(aksara_categories, file_counts, color=colors)
plt.xlabel('Kategori Aksara', fontsize=15)
plt.ylabel('Jumlah Gambar', fontsize=15)
plt.title('Jumlah Aksara Jawa di Setiap Kelas nya', fontsize=17)
plt.xticks(fontsize=15, rotation=13)
plt.tight_layout()

# Add text labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Show the plot
plt.show()
# Out:
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ba is  226
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ca is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\da is  222
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\dha is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ga is  221
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ha is  221
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ja is  219
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ka is  221
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\la is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ma is  219
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\na is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\nga is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\nya is  218
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\pa is  219
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ra is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\sa is  221
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ta is  219
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\tha is  218
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\wa is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\dataset\ya is  216

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Define the input path and aksaraJowo
INPUT_PATH = PATH_MAIN  
AKSARA = aksara_categories

# Define the target image size
IMAGE_SIZE = (96, 96)
INPUT_SHAPE = (96, 96, 1)

def apply_custom_preprocessing(image):
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

def create_image_generator(input_path, aksaraJowo, image_size):
    for index, jowo in enumerate(aksaraJowo):
        aksara_path = os.path.join(input_path, jowo)
        
        for filename in os.listdir(aksara_path):
            image_path = os.path.join(aksara_path, filename)
            original_image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)  # Baca dan ubah warna asli
            original_image_resized = cv2.resize(original_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar asli
            grayscale_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Baca gambar sebagai grayscale
            grayscale_image_resized = cv2.resize(grayscale_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar grayscale
            image_filtered = apply_custom_preprocessing(grayscale_image_resized)
            
            yield original_image_resized, grayscale_image_resized, image_filtered, index

# tranform list to numpy array
def load_images(input_path, aksaraJowo, image_size):
    X_original, X_grayscale, X_filtered, y_label = [], [], [], []
    
    for original_image, grayscale_image, image_filtered, label in create_image_generator(input_path, aksaraJowo, image_size):
        X_original.append(original_image)
        X_grayscale.append(grayscale_image)
        X_filtered.append(image_filtered)
        y_label.append(label)
        
    X_original = np.array(X_original)
    X_grayscale = np.array(X_grayscale)
    X_filtered = np.array(X_filtered)
    y_label = to_categorical(np.array(y_label))
    
    return X_original, X_grayscale, X_filtered, y_label

# Load images with custom preprocessing applied
X_original, X_grayscale, X_filtered, y_label = load_images(INPUT_PATH, AKSARA, IMAGE_SIZE)

# %%
# Select one image to display
index_to_display = 100

# Display the original image, grayscale image, and filtered image
original_image = X_original[index_to_display]
grayscale_image = X_grayscale[index_to_display]
filtered_image = X_filtered[index_to_display]

# Plot the images
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(original_image)
plt.axis('on')

plt.subplot(1, 3, 2)
plt.title('Grayscale Image')
plt.imshow(grayscale_image)
plt.axis('on')

plt.subplot(1, 3, 3)
plt.title('Filtered Image')
# plt.imshow(filtered_image, cmap='gray')
plt.imshow(filtered_image, cmap='gray')
plt.axis('on')

plt.show()

# %%
# Reshape X_filtered
X_filtered_reshaped = X_filtered.reshape(-1, 96, 96, 1) / 255  # Reshape dan normalisasi

print("X_filtered shape after reshape:", X_filtered_reshaped.shape)
# Out:
# X_filtered shape after reshape: (4400, 96, 96, 1)

# %%
from sklearn.model_selection import train_test_split

# Tahap pertama: Membagi data menjadi data pelatihan (80%) dan data pengujian (20%)
X_train, X_test, y_train, y_test = train_test_split(X_filtered_reshaped, y_label, test_size=0.2, random_state=54)

# Verifikasi ukuran data
print("Ukuran data pelatihan:", X_train.shape, y_train.shape)
print("Ukuran data pengujian:", X_test.shape, y_test.shape)
# Out:
# Ukuran data pelatihan: (3520, 96, 96, 1) (3520, 20)
# Ukuran data pengujian: (880, 96, 96, 1) (880, 20)

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_train[100], cmap='gray')
plt.title("Sample Image in Class {} from Training Data !!!".format(AKSARA[np.argmax(y_train[100])]))
plt.axis('on')
plt.show()

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_test[150], cmap='gray')
plt.title("Sample Image in Class {} from Testing Data !!!".format(AKSARA[np.argmax(y_test[150])]))
plt.axis('on')
plt.show()

# %% [markdown]
# # Build the Model

# %% [markdown]
# ## Training Models_1 - 50

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras import optimizers

# Set hyperparameters tuning
optimizer = 'SGD'
learning_rate = 0.0001
dropout_rate = 0.2
weight_decay = 0.0001
momentum = 0.9
clip_norm = 0.0
num_classes = 20
input_shape = INPUT_SHAPE

def create_model(input_shape, num_classes, optimizer_name, learning_rate, dropout_rate, weight_decay, momentum, clip_norm):
    model = Sequential()

    # Block 1
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 3
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 4
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 5
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Flatten
    model.add(Flatten())

    # Dense layers
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))

    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    # Define optimizer with hyperparameters
    if optimizer_name == 'SGD':
        optimizer = optimizers.SGD(learning_rate=learning_rate, decay=weight_decay, momentum=momentum, clipnorm=clip_norm)
    elif optimizer_name == 'Adam':
        optimizer = optimizers.Adam(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    elif optimizer_name == 'RMSprop':
        optimizer = optimizers.RMSprop(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    else:
        raise ValueError("Optimizer not supported. Choose from 'SGD', 'Adam', or 'RMSprop'.")

    # Compile model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Create the model
model = create_model(input_shape=input_shape, num_classes=num_classes, optimizer_name=optimizer, learning_rate=learning_rate, 
                     dropout_rate=dropout_rate, weight_decay=weight_decay, momentum=momentum, clip_norm=clip_norm)

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 20)             │        10,260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,081,460 (49.90 MB)
#  Trainable params: 13,072,628 (49.87 MB)
#  Non-trainable params: 8,832 (34.50 KB)

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import numpy as np

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = 1

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.test_loss = []
        self.test_accuracy = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        self.test_loss.append(test_loss)
        self.test_accuracy.append(test_accuracy)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_train.csv"
test_log_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_test.csv"
model_filepath_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_keras\\v4.4.9_keras.keras"

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1)

# Initialize test log file with header
with open(test_log_v1, 'w') as f:
    f.write("epoch,test_loss,test_accuracy\n")

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=64,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.0495 - loss: 4.0220
# Epoch 1: Test Loss: 3.0866243839263916, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 793s 14s/step - accuracy: 0.0496 - loss: 4.0205 - epoch: 1.0000
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.0732 - loss: 3.8520
# Epoch 2: Test Loss: 3.3262789249420166, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 669s 12s/step - accuracy: 0.0732 - loss: 3.8516 - epoch: 2.0000
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.0776 - loss: 3.7048
# Epoch 3: Test Loss: 3.5858561992645264, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 432s 8s/step - accuracy: 0.0777 - loss: 3.7045 - epoch: 3.0000
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.0983 - loss: 3.6168
# Epoch 4: Test Loss: 3.938032627105713, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 589s 11s/step - accuracy: 0.0983 - loss: 3.6158 - epoch: 4.0000
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.1236 - loss: 3.3747
# Epoch 5: Test Loss: 4.984858512878418, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 554s 10s/step - accuracy: 0.1238 - loss: 3.3738 - epoch: 5.0000
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.1657 - loss: 3.1526
# Epoch 6: Test Loss: 5.270846366882324, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 476s 9s/step - accuracy: 0.1658 - loss: 3.1516 - epoch: 6.0000
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.1875 - loss: 2.9100
# Epoch 7: Test Loss: 5.634507179260254, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 662s 12s/step - accuracy: 0.1878 - loss: 2.9091 - epoch: 7.0000
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.2649 - loss: 2.6026
# Epoch 8: Test Loss: 6.657712459564209, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 555s 10s/step - accuracy: 0.2650 - loss: 2.6019 - epoch: 8.0000
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.3060 - loss: 2.3594
# Epoch 9: Test Loss: 6.574904918670654, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 513s 9s/step - accuracy: 0.3062 - loss: 2.3588 - epoch: 9.0000
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.3587 - loss: 2.1399
# Epoch 10: Test Loss: 6.239741802215576, Test Accuracy: 0.05113636329770088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 445s 8s/step - accuracy: 0.3587 - loss: 2.1395 - epoch: 10.0000
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4284 - loss: 1.9758
# Epoch 11: Test Loss: 6.079610824584961, Test Accuracy: 0.07613636553287506
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 432s 8s/step - accuracy: 0.4284 - loss: 1.9751 - epoch: 11.0000
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4678 - loss: 1.8379
# Epoch 12: Test Loss: 5.175056457519531, Test Accuracy: 0.0988636389374733
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 440s 8s/step - accuracy: 0.4677 - loss: 1.8378 - epoch: 12.0000
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4923 - loss: 1.6872
# Epoch 13: Test Loss: 4.705358982086182, Test Accuracy: 0.125
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 403s 7s/step - accuracy: 0.4924 - loss: 1.6871 - epoch: 13.0000
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5113 - loss: 1.5922
# Epoch 14: Test Loss: 4.003250598907471, Test Accuracy: 0.17954544723033905
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 414s 8s/step - accuracy: 0.5114 - loss: 1.5921 - epoch: 14.0000
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.5460 - loss: 1.4582
# Epoch 15: Test Loss: 3.918811321258545, Test Accuracy: 0.20454545319080353
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 604s 11s/step - accuracy: 0.5459 - loss: 1.4587 - epoch: 15.0000
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5634 - loss: 1.4248
# Epoch 16: Test Loss: 3.2270216941833496, Test Accuracy: 0.24772727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 501s 9s/step - accuracy: 0.5637 - loss: 1.4243 - epoch: 16.0000
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.5807 - loss: 1.3671
# Epoch 17: Test Loss: 3.37131929397583, Test Accuracy: 0.24318182468414307
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 567s 10s/step - accuracy: 0.5810 - loss: 1.3662 - epoch: 17.0000
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5997 - loss: 1.2841
# Epoch 18: Test Loss: 3.0429189205169678, Test Accuracy: 0.2818181812763214
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 592s 10s/step - accuracy: 0.6000 - loss: 1.2834 - epoch: 18.0000
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.6457 - loss: 1.1682
# Epoch 19: Test Loss: 2.7273519039154053, Test Accuracy: 0.33181819319725037
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 527s 10s/step - accuracy: 0.6457 - loss: 1.1681 - epoch: 19.0000
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.6574 - loss: 1.1101
# Epoch 20: Test Loss: 2.978285074234009, Test Accuracy: 0.2965908944606781
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 715s 12s/step - accuracy: 0.6573 - loss: 1.1102 - epoch: 20.0000
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.6638 - loss: 1.0717
# Epoch 21: Test Loss: 2.9581048488616943, Test Accuracy: 0.3068181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 542s 10s/step - accuracy: 0.6640 - loss: 1.0717 - epoch: 21.0000
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7033 - loss: 1.0066
# Epoch 22: Test Loss: 3.172240734100342, Test Accuracy: 0.28409090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 649s 12s/step - accuracy: 0.7032 - loss: 1.0063 - epoch: 22.0000
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7056 - loss: 0.9701
# Epoch 23: Test Loss: 2.718622922897339, Test Accuracy: 0.36250001192092896
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 613s 11s/step - accuracy: 0.7056 - loss: 0.9700 - epoch: 23.0000
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7026 - loss: 0.9609
# Epoch 24: Test Loss: 2.715334177017212, Test Accuracy: 0.3659090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 426s 8s/step - accuracy: 0.7028 - loss: 0.9603 - epoch: 24.0000
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.7315 - loss: 0.8935
# Epoch 25: Test Loss: 2.524693250656128, Test Accuracy: 0.40340909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 506s 9s/step - accuracy: 0.7314 - loss: 0.8934 - epoch: 25.0000
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7294 - loss: 0.8498
# Epoch 26: Test Loss: 2.5799078941345215, Test Accuracy: 0.3806818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 381s 7s/step - accuracy: 0.7296 - loss: 0.8494 - epoch: 26.0000
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.7475 - loss: 0.8199
# Epoch 27: Test Loss: 2.637666702270508, Test Accuracy: 0.37840908765792847
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 481s 9s/step - accuracy: 0.7474 - loss: 0.8201 - epoch: 27.0000
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.7694 - loss: 0.7628
# Epoch 28: Test Loss: 2.499150276184082, Test Accuracy: 0.4056818187236786
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 570s 10s/step - accuracy: 0.7692 - loss: 0.7632 - epoch: 28.0000
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7610 - loss: 0.7637
# Epoch 29: Test Loss: 2.2503204345703125, Test Accuracy: 0.4465909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 536s 10s/step - accuracy: 0.7609 - loss: 0.7637 - epoch: 29.0000
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.7875 - loss: 0.7057
# Epoch 30: Test Loss: 2.2479569911956787, Test Accuracy: 0.4522727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 531s 10s/step - accuracy: 0.7874 - loss: 0.7059 - epoch: 30.0000
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7888 - loss: 0.6900
# Epoch 31: Test Loss: 2.4691686630249023, Test Accuracy: 0.4227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 428s 8s/step - accuracy: 0.7887 - loss: 0.6900 - epoch: 31.0000
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.8051 - loss: 0.6581
# Epoch 32: Test Loss: 2.114654302597046, Test Accuracy: 0.478409081697464
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 530s 10s/step - accuracy: 0.8049 - loss: 0.6583 - epoch: 32.0000
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.7796 - loss: 0.6918
# Epoch 33: Test Loss: 2.247170925140381, Test Accuracy: 0.4545454680919647
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 790s 14s/step - accuracy: 0.7798 - loss: 0.6914 - epoch: 33.0000
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7985 - loss: 0.6501
# Epoch 34: Test Loss: 2.1189687252044678, Test Accuracy: 0.47727271914482117
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 434s 8s/step - accuracy: 0.7984 - loss: 0.6500 - epoch: 34.0000
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8179 - loss: 0.6172
# Epoch 35: Test Loss: 2.2882747650146484, Test Accuracy: 0.44999998807907104
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 433s 8s/step - accuracy: 0.8178 - loss: 0.6171 - epoch: 35.0000
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8231 - loss: 0.5926
# Epoch 36: Test Loss: 2.087803602218628, Test Accuracy: 0.4829545319080353
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 427s 8s/step - accuracy: 0.8230 - loss: 0.5926 - epoch: 36.0000
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8261 - loss: 0.5608
# Epoch 37: Test Loss: 2.1021323204040527, Test Accuracy: 0.48750001192092896
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 438s 8s/step - accuracy: 0.8260 - loss: 0.5611 - epoch: 37.0000
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8183 - loss: 0.5949
# Epoch 38: Test Loss: 1.8906893730163574, Test Accuracy: 0.5204545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 444s 8s/step - accuracy: 0.8184 - loss: 0.5945 - epoch: 38.0000
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8391 - loss: 0.5369
# Epoch 39: Test Loss: 1.9765348434448242, Test Accuracy: 0.4988636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 8s/step - accuracy: 0.8389 - loss: 0.5371 - epoch: 39.0000
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8289 - loss: 0.5414
# Epoch 40: Test Loss: 1.9603502750396729, Test Accuracy: 0.5102272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 457s 8s/step - accuracy: 0.8290 - loss: 0.5412 - epoch: 40.0000
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8344 - loss: 0.5293
# Epoch 41: Test Loss: 2.004617214202881, Test Accuracy: 0.5034090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 428s 8s/step - accuracy: 0.8343 - loss: 0.5293 - epoch: 41.0000
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8517 - loss: 0.4781
# Epoch 42: Test Loss: 1.886678695678711, Test Accuracy: 0.5181818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 427s 8s/step - accuracy: 0.8517 - loss: 0.4782 - epoch: 42.0000
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8510 - loss: 0.4964
# Epoch 43: Test Loss: 1.8650708198547363, Test Accuracy: 0.512499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 423s 8s/step - accuracy: 0.8511 - loss: 0.4961 - epoch: 43.0000
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8405 - loss: 0.4828
# Epoch 44: Test Loss: 1.8864339590072632, Test Accuracy: 0.5022727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 8s/step - accuracy: 0.8405 - loss: 0.4826 - epoch: 44.0000
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8611 - loss: 0.4519
# Epoch 45: Test Loss: 1.6928635835647583, Test Accuracy: 0.5545454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 423s 8s/step - accuracy: 0.8611 - loss: 0.4522 - epoch: 45.0000
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8457 - loss: 0.4797
# Epoch 46: Test Loss: 1.8317596912384033, Test Accuracy: 0.5295454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 425s 8s/step - accuracy: 0.8458 - loss: 0.4794 - epoch: 46.0000
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8698 - loss: 0.4299
# Epoch 47: Test Loss: 1.8245924711227417, Test Accuracy: 0.5227272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 433s 8s/step - accuracy: 0.8696 - loss: 0.4305 - epoch: 47.0000
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.8642 - loss: 0.4536
# Epoch 48: Test Loss: 1.5807411670684814, Test Accuracy: 0.574999988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 440s 8s/step - accuracy: 0.8641 - loss: 0.4534 - epoch: 48.0000
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8610 - loss: 0.4350
# Epoch 49: Test Loss: 1.5548748970031738, Test Accuracy: 0.5727272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 435s 8s/step - accuracy: 0.8610 - loss: 0.4350 - epoch: 49.0000
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8662 - loss: 0.4299
# Epoch 50: Test Loss: 1.4385943412780762, Test Accuracy: 0.6022727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 429s 8s/step - accuracy: 0.8662 - loss: 0.4299 - epoch: 50.0000

# %%
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Senin, 12 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ## Training Models_50 - 200

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename, initial_epoch=1):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0 and self.epoch == 2:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename, initial_epoch=1):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.initial_epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_train.csv"
test_log_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_test.csv"
model_filepath_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.9_keras.keras"

# Load the last saved model
try:
    model = tf.keras.models.load_model(model_filepath_v1)
    print("Model loaded from checkpoint.")
except Exception as e:
    print(f"Failed to load model from checkpoint: {e}")

# Determine the last epoch trained
try:
    history_df = pd.read_csv(csv_logger_v1)
    initial_epoch = history_df['epoch'].max()
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
    initial_epoch = 1

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1, initial_epoch=initial_epoch + 1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1, initial_epoch=initial_epoch + 1)

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    # validation_data=(X_val, y_val),
    epochs=initial_epoch + 200,  # change this to the desired number of total epochs
    batch_size=64,
    initial_epoch=initial_epoch,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Model loaded from checkpoint.
# Epoch 51/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8610 - loss: 0.4297
# Epoch 51: Test Loss: 1.5520511865615845, Test Accuracy: 0.5784090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8612 - loss: 0.4293 - epoch: 51.0000
# Epoch 52/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8801 - loss: 0.4042
# Epoch 52: Test Loss: 1.610537052154541, Test Accuracy: 0.5659090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8802 - loss: 0.4043 - epoch: 52.0000
# Epoch 53/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8771 - loss: 0.3847
# Epoch 53: Test Loss: 1.5228327512741089, Test Accuracy: 0.5920454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8772 - loss: 0.3845 - epoch: 53.0000
# Epoch 54/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8693 - loss: 0.4232
# Epoch 54: Test Loss: 1.4473382234573364, Test Accuracy: 0.612500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8695 - loss: 0.4226 - epoch: 54.0000
# Epoch 55/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8820 - loss: 0.3726
# Epoch 55: Test Loss: 1.4648113250732422, Test Accuracy: 0.6022727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8820 - loss: 0.3727 - epoch: 55.0000
# Epoch 56/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8951 - loss: 0.3638
# Epoch 56: Test Loss: 1.444655179977417, Test Accuracy: 0.6090909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8949 - loss: 0.3640 - epoch: 56.0000
# Epoch 57/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9062 - loss: 0.3315
# Epoch 57: Test Loss: 1.3048734664916992, Test Accuracy: 0.6568182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9060 - loss: 0.3317 - epoch: 57.0000
# Epoch 58/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8904 - loss: 0.3563
# Epoch 58: Test Loss: 1.3593766689300537, Test Accuracy: 0.637499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8903 - loss: 0.3564 - epoch: 58.0000
# Epoch 59/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8889 - loss: 0.3474
# Epoch 59: Test Loss: 1.4261181354522705, Test Accuracy: 0.6318181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8890 - loss: 0.3472 - epoch: 59.0000
# Epoch 60/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8981 - loss: 0.3250
# Epoch 60: Test Loss: 1.2853741645812988, Test Accuracy: 0.6727272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8982 - loss: 0.3250 - epoch: 60.0000
# Epoch 61/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8900 - loss: 0.3510
# Epoch 61: Test Loss: 1.3643147945404053, Test Accuracy: 0.6386363506317139
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8900 - loss: 0.3509 - epoch: 61.0000
# Epoch 62/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8826 - loss: 0.3706
# Epoch 62: Test Loss: 1.441735863685608, Test Accuracy: 0.6193181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8828 - loss: 0.3702 - epoch: 62.0000
# Epoch 63/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9082 - loss: 0.3159
# Epoch 63: Test Loss: 1.292519211769104, Test Accuracy: 0.6556817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9081 - loss: 0.3158 - epoch: 63.0000
# Epoch 64/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9044 - loss: 0.3111
# Epoch 64: Test Loss: 1.179468035697937, Test Accuracy: 0.6954545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9043 - loss: 0.3111 - epoch: 64.0000
# Epoch 65/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9049 - loss: 0.3113
# Epoch 65: Test Loss: 1.1929887533187866, Test Accuracy: 0.6852272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9049 - loss: 0.3113 - epoch: 65.0000
# Epoch 66/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9066 - loss: 0.3002
# Epoch 66: Test Loss: 1.1763916015625, Test Accuracy: 0.6954545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9066 - loss: 0.3002 - epoch: 66.0000
# Epoch 67/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9029 - loss: 0.3036
# Epoch 67: Test Loss: 1.140199899673462, Test Accuracy: 0.6977272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9030 - loss: 0.3033 - epoch: 67.0000
# Epoch 68/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9134 - loss: 0.2941
# Epoch 68: Test Loss: 1.1703687906265259, Test Accuracy: 0.6920454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9135 - loss: 0.2940 - epoch: 68.0000
# Epoch 69/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9120 - loss: 0.2848
# Epoch 69: Test Loss: 1.1050846576690674, Test Accuracy: 0.7022727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9119 - loss: 0.2847 - epoch: 69.0000
# Epoch 70/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9026 - loss: 0.3128
# Epoch 70: Test Loss: 1.240697979927063, Test Accuracy: 0.675000011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9027 - loss: 0.3124 - epoch: 70.0000
# Epoch 71/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9044 - loss: 0.2922
# Epoch 71: Test Loss: 1.152580976486206, Test Accuracy: 0.6931818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9045 - loss: 0.2921 - epoch: 71.0000
# Epoch 72/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9134 - loss: 0.2868
# Epoch 72: Test Loss: 1.149417757987976, Test Accuracy: 0.6931818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9133 - loss: 0.2870 - epoch: 72.0000
# Epoch 73/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9056 - loss: 0.2964
# Epoch 73: Test Loss: 1.1692991256713867, Test Accuracy: 0.6909090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9058 - loss: 0.2960 - epoch: 73.0000
# Epoch 74/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9235 - loss: 0.2421
# Epoch 74: Test Loss: 1.1903607845306396, Test Accuracy: 0.6909090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9234 - loss: 0.2423 - epoch: 74.0000
# Epoch 75/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9132 - loss: 0.2683
# Epoch 75: Test Loss: 1.1539225578308105, Test Accuracy: 0.6988636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9133 - loss: 0.2683 - epoch: 75.0000
# Epoch 76/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9239 - loss: 0.2447
# Epoch 76: Test Loss: 1.1991245746612549, Test Accuracy: 0.6863636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9238 - loss: 0.2449 - epoch: 76.0000
# Epoch 77/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9151 - loss: 0.2698
# Epoch 77: Test Loss: 1.135959506034851, Test Accuracy: 0.6988636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9152 - loss: 0.2695 - epoch: 77.0000
# Epoch 78/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9291 - loss: 0.2491
# Epoch 78: Test Loss: 1.0288692712783813, Test Accuracy: 0.7227272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9290 - loss: 0.2491 - epoch: 78.0000
# Epoch 79/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9210 - loss: 0.2490
# Epoch 79: Test Loss: 1.0625133514404297, Test Accuracy: 0.7124999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9210 - loss: 0.2491 - epoch: 79.0000
# Epoch 80/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9237 - loss: 0.2340
# Epoch 80: Test Loss: 1.1069329977035522, Test Accuracy: 0.7090908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9237 - loss: 0.2341 - epoch: 80.0000
# Epoch 81/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9300 - loss: 0.2324
# Epoch 81: Test Loss: 0.9643418788909912, Test Accuracy: 0.737500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9300 - loss: 0.2323 - epoch: 81.0000
# Epoch 82/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9266 - loss: 0.2370
# Epoch 82: Test Loss: 0.9527339339256287, Test Accuracy: 0.7352272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9267 - loss: 0.2369 - epoch: 82.0000
# Epoch 83/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9326 - loss: 0.2376
# Epoch 83: Test Loss: 1.0185673236846924, Test Accuracy: 0.7250000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9325 - loss: 0.2377 - epoch: 83.0000
# Epoch 84/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9366 - loss: 0.2236
# Epoch 84: Test Loss: 0.9368116855621338, Test Accuracy: 0.7352272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9365 - loss: 0.2236 - epoch: 84.0000
# Epoch 85/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9326 - loss: 0.2163
# Epoch 85: Test Loss: 0.9498825073242188, Test Accuracy: 0.7352272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9325 - loss: 0.2165 - epoch: 85.0000
# Epoch 86/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9365 - loss: 0.2218
# Epoch 86: Test Loss: 0.9317668676376343, Test Accuracy: 0.7363636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9365 - loss: 0.2218 - epoch: 86.0000
# Epoch 87/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9410 - loss: 0.2049
# Epoch 87: Test Loss: 0.8672280311584473, Test Accuracy: 0.75
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9410 - loss: 0.2049 - epoch: 87.0000
# Epoch 88/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9389 - loss: 0.2048
# Epoch 88: Test Loss: 0.9948898553848267, Test Accuracy: 0.7250000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9389 - loss: 0.2050 - epoch: 88.0000
# Epoch 89/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9419 - loss: 0.2037
# Epoch 89: Test Loss: 0.9686238169670105, Test Accuracy: 0.7340909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9418 - loss: 0.2038 - epoch: 89.0000
# Epoch 90/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9216 - loss: 0.2315
# Epoch 90: Test Loss: 0.8964730501174927, Test Accuracy: 0.7522727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9217 - loss: 0.2312 - epoch: 90.0000
# Epoch 91/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9382 - loss: 0.2030
# Epoch 91: Test Loss: 0.9589405655860901, Test Accuracy: 0.737500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9382 - loss: 0.2031 - epoch: 91.0000
# Epoch 92/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9534 - loss: 0.1723
# Epoch 92: Test Loss: 0.9496921896934509, Test Accuracy: 0.7340909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9532 - loss: 0.1728 - epoch: 92.0000
# Epoch 93/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9445 - loss: 0.1860
# Epoch 93: Test Loss: 0.968205451965332, Test Accuracy: 0.737500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9444 - loss: 0.1862 - epoch: 93.0000
# Epoch 94/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9308 - loss: 0.2158
# Epoch 94: Test Loss: 0.9296883344650269, Test Accuracy: 0.7409090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9310 - loss: 0.2155 - epoch: 94.0000
# Epoch 95/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9389 - loss: 0.1971
# Epoch 95: Test Loss: 0.8122648000717163, Test Accuracy: 0.7715908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9390 - loss: 0.1971 - epoch: 95.0000
# Epoch 96/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9273 - loss: 0.2321
# Epoch 96: Test Loss: 0.8046465516090393, Test Accuracy: 0.7670454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9273 - loss: 0.2317 - epoch: 96.0000
# Epoch 97/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9451 - loss: 0.1783
# Epoch 97: Test Loss: 0.9123445749282837, Test Accuracy: 0.7431818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9451 - loss: 0.1784 - epoch: 97.0000
# Epoch 98/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9470 - loss: 0.1809
# Epoch 98: Test Loss: 0.8350417613983154, Test Accuracy: 0.7704545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9470 - loss: 0.1808 - epoch: 98.0000
# Epoch 99/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9448 - loss: 0.1805
# Epoch 99: Test Loss: 0.8287026882171631, Test Accuracy: 0.7670454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9449 - loss: 0.1805 - epoch: 99.0000
# Epoch 100/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9400 - loss: 0.1945
# Epoch 100: Test Loss: 0.8153849244117737, Test Accuracy: 0.7704545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9400 - loss: 0.1943 - epoch: 100.0000
# Epoch 101/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9444 - loss: 0.1803
# Epoch 101: Test Loss: 0.9531227350234985, Test Accuracy: 0.7409090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9444 - loss: 0.1802 - epoch: 101.0000
# Epoch 102/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9456 - loss: 0.1906
# Epoch 102: Test Loss: 0.7362135648727417, Test Accuracy: 0.7909091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9456 - loss: 0.1905 - epoch: 102.0000
# Epoch 103/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9481 - loss: 0.1813
# Epoch 103: Test Loss: 0.754442036151886, Test Accuracy: 0.7840909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9481 - loss: 0.1813 - epoch: 103.0000
# Epoch 104/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9477 - loss: 0.1798
# Epoch 104: Test Loss: 0.7910301089286804, Test Accuracy: 0.7738636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9477 - loss: 0.1798 - epoch: 104.0000
# Epoch 105/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9493 - loss: 0.1635
# Epoch 105: Test Loss: 0.8209088444709778, Test Accuracy: 0.7659090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9493 - loss: 0.1636 - epoch: 105.0000
# Epoch 106/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9381 - loss: 0.1814
# Epoch 106: Test Loss: 0.8376087546348572, Test Accuracy: 0.7590909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9382 - loss: 0.1813 - epoch: 106.0000
# Epoch 107/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9509 - loss: 0.1672
# Epoch 107: Test Loss: 0.752055287361145, Test Accuracy: 0.7886363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9509 - loss: 0.1672 - epoch: 107.0000
# Epoch 108/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9441 - loss: 0.1702
# Epoch 108: Test Loss: 0.680935800075531, Test Accuracy: 0.8022727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9441 - loss: 0.1702 - epoch: 108.0000
# Epoch 109/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9547 - loss: 0.1585
# Epoch 109: Test Loss: 0.7770299911499023, Test Accuracy: 0.7795454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9548 - loss: 0.1584 - epoch: 109.0000
# Epoch 110/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9438 - loss: 0.1603
# Epoch 110: Test Loss: 0.8237581253051758, Test Accuracy: 0.7681818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9439 - loss: 0.1602 - epoch: 110.0000
# Epoch 111/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9438 - loss: 0.1679
# Epoch 111: Test Loss: 0.7346470355987549, Test Accuracy: 0.7886363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9438 - loss: 0.1679 - epoch: 111.0000
# Epoch 112/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9558 - loss: 0.1687
# Epoch 112: Test Loss: 0.6884899735450745, Test Accuracy: 0.8056818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9558 - loss: 0.1686 - epoch: 112.0000
# Epoch 113/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9469 - loss: 0.1795
# Epoch 113: Test Loss: 0.6211705207824707, Test Accuracy: 0.8181818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9470 - loss: 0.1793 - epoch: 113.0000
# Epoch 114/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9609 - loss: 0.1372
# Epoch 114: Test Loss: 0.6678360104560852, Test Accuracy: 0.8056818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9608 - loss: 0.1374 - epoch: 114.0000
# Epoch 115/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9534 - loss: 0.1425
# Epoch 115: Test Loss: 0.7265410423278809, Test Accuracy: 0.7943181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9534 - loss: 0.1425 - epoch: 115.0000
# Epoch 116/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9633 - loss: 0.1328
# Epoch 116: Test Loss: 0.7227169871330261, Test Accuracy: 0.7943181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9631 - loss: 0.1331 - epoch: 116.0000
# Epoch 117/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9550 - loss: 0.1450
# Epoch 117: Test Loss: 0.7040578126907349, Test Accuracy: 0.7965909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9550 - loss: 0.1450 - epoch: 117.0000
# Epoch 118/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9557 - loss: 0.1504
# Epoch 118: Test Loss: 0.7086134552955627, Test Accuracy: 0.7943181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9557 - loss: 0.1504 - epoch: 118.0000
# Epoch 119/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9614 - loss: 0.1413
# Epoch 119: Test Loss: 0.670835554599762, Test Accuracy: 0.8136363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9613 - loss: 0.1413 - epoch: 119.0000
# Epoch 120/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9548 - loss: 0.1408
# Epoch 120: Test Loss: 0.669822633266449, Test Accuracy: 0.8136363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9548 - loss: 0.1409 - epoch: 120.0000
# Epoch 121/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9646 - loss: 0.1215
# Epoch 121: Test Loss: 0.70621657371521, Test Accuracy: 0.793181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9645 - loss: 0.1218 - epoch: 121.0000
# Epoch 122/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9634 - loss: 0.1256
# Epoch 122: Test Loss: 0.7007909417152405, Test Accuracy: 0.7977272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9633 - loss: 0.1258 - epoch: 122.0000
# Epoch 123/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.1359
# Epoch 123: Test Loss: 0.723252534866333, Test Accuracy: 0.793181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9607 - loss: 0.1360 - epoch: 123.0000
# Epoch 124/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9638 - loss: 0.1275
# Epoch 124: Test Loss: 0.64405357837677, Test Accuracy: 0.8090909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9638 - loss: 0.1277 - epoch: 124.0000
# Epoch 125/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9491 - loss: 0.1508
# Epoch 125: Test Loss: 0.6716791391372681, Test Accuracy: 0.8034090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9492 - loss: 0.1505 - epoch: 125.0000
# Epoch 126/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9621 - loss: 0.1396
# Epoch 126: Test Loss: 0.7659518122673035, Test Accuracy: 0.7772727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9621 - loss: 0.1396 - epoch: 126.0000
# Epoch 127/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9591 - loss: 0.1424
# Epoch 127: Test Loss: 0.740574300289154, Test Accuracy: 0.7829545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9591 - loss: 0.1424 - epoch: 127.0000
# Epoch 128/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.1292
# Epoch 128: Test Loss: 0.6891130208969116, Test Accuracy: 0.8045454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9607 - loss: 0.1292 - epoch: 128.0000
# Epoch 129/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9530 - loss: 0.1585
# Epoch 129: Test Loss: 0.566528856754303, Test Accuracy: 0.8295454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9532 - loss: 0.1581 - epoch: 129.0000
# Epoch 130/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9619 - loss: 0.1314
# Epoch 130: Test Loss: 0.6415668725967407, Test Accuracy: 0.8159090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9619 - loss: 0.1313 - epoch: 130.0000
# Epoch 131/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9668 - loss: 0.1152
# Epoch 131: Test Loss: 0.6292513608932495, Test Accuracy: 0.8147727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9668 - loss: 0.1153 - epoch: 131.0000
# Epoch 132/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9629 - loss: 0.1273
# Epoch 132: Test Loss: 0.5812207460403442, Test Accuracy: 0.8284090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9630 - loss: 0.1273 - epoch: 132.0000
# Epoch 133/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9590 - loss: 0.1301
# Epoch 133: Test Loss: 0.672408938407898, Test Accuracy: 0.8045454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9591 - loss: 0.1300 - epoch: 133.0000
# Epoch 134/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9699 - loss: 0.1079
# Epoch 134: Test Loss: 0.5656634569168091, Test Accuracy: 0.8352272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9698 - loss: 0.1081 - epoch: 134.0000
# Epoch 135/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9616 - loss: 0.1244
# Epoch 135: Test Loss: 0.5116469264030457, Test Accuracy: 0.8522727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9616 - loss: 0.1245 - epoch: 135.0000
# Epoch 136/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9617 - loss: 0.1242
# Epoch 136: Test Loss: 0.5537179112434387, Test Accuracy: 0.8409090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9616 - loss: 0.1243 - epoch: 136.0000
# Epoch 137/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9664 - loss: 0.1239
# Epoch 137: Test Loss: 0.6041243672370911, Test Accuracy: 0.8227272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9664 - loss: 0.1237 - epoch: 137.0000
# Epoch 138/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9635 - loss: 0.1189
# Epoch 138: Test Loss: 0.5683291554450989, Test Accuracy: 0.8363636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9635 - loss: 0.1188 - epoch: 138.0000
# Epoch 139/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9609 - loss: 0.1266
# Epoch 139: Test Loss: 0.5888522863388062, Test Accuracy: 0.824999988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9609 - loss: 0.1265 - epoch: 139.0000
# Epoch 140/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9650 - loss: 0.1148
# Epoch 140: Test Loss: 0.5567465424537659, Test Accuracy: 0.8374999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9650 - loss: 0.1148 - epoch: 140.0000
# Epoch 141/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9670 - loss: 0.1202
# Epoch 141: Test Loss: 0.5416111946105957, Test Accuracy: 0.8386363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9670 - loss: 0.1202 - epoch: 141.0000
# Epoch 142/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9643 - loss: 0.1161
# Epoch 142: Test Loss: 0.5461941361427307, Test Accuracy: 0.8409090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9643 - loss: 0.1161 - epoch: 142.0000
# Epoch 143/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9668 - loss: 0.1118
# Epoch 143: Test Loss: 0.5800739526748657, Test Accuracy: 0.8363636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9668 - loss: 0.1118 - epoch: 143.0000
# Epoch 144/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9630 - loss: 0.1097
# Epoch 144: Test Loss: 0.5917046070098877, Test Accuracy: 0.824999988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9630 - loss: 0.1097 - epoch: 144.0000
# Epoch 145/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9688 - loss: 0.1001
# Epoch 145: Test Loss: 0.6391289234161377, Test Accuracy: 0.8181818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9688 - loss: 0.1003 - epoch: 145.0000
# Epoch 146/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9721 - loss: 0.1099
# Epoch 146: Test Loss: 0.5878540873527527, Test Accuracy: 0.8238636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9721 - loss: 0.1099 - epoch: 146.0000
# Epoch 147/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9688 - loss: 0.1126
# Epoch 147: Test Loss: 0.5223667621612549, Test Accuracy: 0.8477272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9688 - loss: 0.1126 - epoch: 147.0000
# Epoch 148/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9647 - loss: 0.1180
# Epoch 148: Test Loss: 0.5484532713890076, Test Accuracy: 0.8409090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9647 - loss: 0.1179 - epoch: 148.0000
# Epoch 149/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9642 - loss: 0.1145
# Epoch 149: Test Loss: 0.5693519115447998, Test Accuracy: 0.831818163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9642 - loss: 0.1144 - epoch: 149.0000
# Epoch 150/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9695 - loss: 0.1063
# Epoch 150: Test Loss: 0.5528781414031982, Test Accuracy: 0.8409090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9694 - loss: 0.1064 - epoch: 150.0000
# Epoch 151/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9698 - loss: 0.1114
# Epoch 151: Test Loss: 0.5459945797920227, Test Accuracy: 0.8374999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9698 - loss: 0.1114 - epoch: 151.0000
# Epoch 152/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9738 - loss: 0.0946
# Epoch 152: Test Loss: 0.5687147378921509, Test Accuracy: 0.8352272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9738 - loss: 0.0947 - epoch: 152.0000
# Epoch 153/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9725 - loss: 0.0964
# Epoch 153: Test Loss: 0.5229553580284119, Test Accuracy: 0.8511363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9725 - loss: 0.0964 - epoch: 153.0000
# Epoch 154/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9716 - loss: 0.0934
# Epoch 154: Test Loss: 0.5293968319892883, Test Accuracy: 0.8522727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9716 - loss: 0.0934 - epoch: 154.0000
# Epoch 155/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 0.0928
# Epoch 155: Test Loss: 0.5455251932144165, Test Accuracy: 0.8454545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9754 - loss: 0.0929 - epoch: 155.0000
# Epoch 156/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9745 - loss: 0.0946
# Epoch 156: Test Loss: 0.5647688508033752, Test Accuracy: 0.8374999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9745 - loss: 0.0946 - epoch: 156.0000
# Epoch 157/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9701 - loss: 0.0987
# Epoch 157: Test Loss: 0.5530012249946594, Test Accuracy: 0.8454545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9701 - loss: 0.0987 - epoch: 157.0000
# Epoch 158/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9728 - loss: 0.0944
# Epoch 158: Test Loss: 0.578567624092102, Test Accuracy: 0.8340908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9727 - loss: 0.0945 - epoch: 158.0000
# Epoch 159/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9743 - loss: 0.0930
# Epoch 159: Test Loss: 0.5157316327095032, Test Accuracy: 0.855681836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9743 - loss: 0.0931 - epoch: 159.0000
# Epoch 160/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9639 - loss: 0.1095
# Epoch 160: Test Loss: 0.4756876826286316, Test Accuracy: 0.8647727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9639 - loss: 0.1095 - epoch: 160.0000
# Epoch 161/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9672 - loss: 0.0998
# Epoch 161: Test Loss: 0.5015739798545837, Test Accuracy: 0.8579545617103577
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9671 - loss: 0.0999 - epoch: 161.0000
# Epoch 162/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9734 - loss: 0.0913
# Epoch 162: Test Loss: 0.5082228779792786, Test Accuracy: 0.855681836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9734 - loss: 0.0913 - epoch: 162.0000
# Epoch 163/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9731 - loss: 0.0919
# Epoch 163: Test Loss: 0.5476458668708801, Test Accuracy: 0.8431817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9731 - loss: 0.0919 - epoch: 163.0000
# Epoch 164/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9737 - loss: 0.0923
# Epoch 164: Test Loss: 0.48311886191368103, Test Accuracy: 0.8636363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9737 - loss: 0.0923 - epoch: 164.0000
# Epoch 165/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9698 - loss: 0.1003
# Epoch 165: Test Loss: 0.5214094519615173, Test Accuracy: 0.8477272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9698 - loss: 0.1002 - epoch: 165.0000
# Epoch 166/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9715 - loss: 0.0959
# Epoch 166: Test Loss: 0.48934170603752136, Test Accuracy: 0.8579545617103577
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9715 - loss: 0.0958 - epoch: 166.0000
# Epoch 167/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9695 - loss: 0.0998
# Epoch 167: Test Loss: 0.4687795341014862, Test Accuracy: 0.8670454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9696 - loss: 0.0997 - epoch: 167.0000
# Epoch 168/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9744 - loss: 0.0881
# Epoch 168: Test Loss: 0.5288349390029907, Test Accuracy: 0.8477272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9744 - loss: 0.0881 - epoch: 168.0000
# Epoch 169/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9744 - loss: 0.0860
# Epoch 169: Test Loss: 0.4883631765842438, Test Accuracy: 0.855681836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9744 - loss: 0.0861 - epoch: 169.0000
# Epoch 170/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9738 - loss: 0.0929
# Epoch 170: Test Loss: 0.4629072844982147, Test Accuracy: 0.8670454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9739 - loss: 0.0927 - epoch: 170.0000
# Epoch 171/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9779 - loss: 0.0846
# Epoch 171: Test Loss: 0.455337256193161, Test Accuracy: 0.8681818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9779 - loss: 0.0846 - epoch: 171.0000
# Epoch 172/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9672 - loss: 0.0885
# Epoch 172: Test Loss: 0.4395498037338257, Test Accuracy: 0.8727272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9672 - loss: 0.0887 - epoch: 172.0000
# Epoch 173/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9780 - loss: 0.0796
# Epoch 173: Test Loss: 0.450916588306427, Test Accuracy: 0.8715909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9780 - loss: 0.0797 - epoch: 173.0000
# Epoch 174/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9796 - loss: 0.0821
# Epoch 174: Test Loss: 0.4831763505935669, Test Accuracy: 0.8590909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9795 - loss: 0.0821 - epoch: 174.0000
# Epoch 175/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9757 - loss: 0.0851
# Epoch 175: Test Loss: 0.45777902007102966, Test Accuracy: 0.8670454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9756 - loss: 0.0851 - epoch: 175.0000
# Epoch 176/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9762 - loss: 0.0795
# Epoch 176: Test Loss: 0.4513894021511078, Test Accuracy: 0.8727272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9762 - loss: 0.0796 - epoch: 176.0000
# Epoch 177/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9797 - loss: 0.0783
# Epoch 177: Test Loss: 0.4878595769405365, Test Accuracy: 0.855681836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9796 - loss: 0.0785 - epoch: 177.0000
# Epoch 178/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9747 - loss: 0.0865
# Epoch 178: Test Loss: 0.49871885776519775, Test Accuracy: 0.8534091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9746 - loss: 0.0866 - epoch: 178.0000
# Epoch 179/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9757 - loss: 0.0832
# Epoch 179: Test Loss: 0.49579358100891113, Test Accuracy: 0.8568181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9757 - loss: 0.0832 - epoch: 179.0000
# Epoch 180/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9698 - loss: 0.0956
# Epoch 180: Test Loss: 0.4736246168613434, Test Accuracy: 0.8647727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9699 - loss: 0.0955 - epoch: 180.0000
# Epoch 181/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9800 - loss: 0.0724
# Epoch 181: Test Loss: 0.461625874042511, Test Accuracy: 0.8738636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9800 - loss: 0.0725 - epoch: 181.0000
# Epoch 182/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9783 - loss: 0.0789
# Epoch 182: Test Loss: 0.4664483368396759, Test Accuracy: 0.8704545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9783 - loss: 0.0789 - epoch: 182.0000
# Epoch 183/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9791 - loss: 0.0837
# Epoch 183: Test Loss: 0.5099580883979797, Test Accuracy: 0.8522727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9791 - loss: 0.0837 - epoch: 183.0000
# Epoch 184/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9817 - loss: 0.0692
# Epoch 184: Test Loss: 0.4786575436592102, Test Accuracy: 0.8647727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9817 - loss: 0.0693 - epoch: 184.0000
# Epoch 185/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9684 - loss: 0.0994
# Epoch 185: Test Loss: 0.536787211894989, Test Accuracy: 0.8386363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9685 - loss: 0.0991 - epoch: 185.0000
# Epoch 186/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9789 - loss: 0.0744
# Epoch 186: Test Loss: 0.42617180943489075, Test Accuracy: 0.8784090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9789 - loss: 0.0744 - epoch: 186.0000
# Epoch 187/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9783 - loss: 0.0728
# Epoch 187: Test Loss: 0.46880412101745605, Test Accuracy: 0.8647727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9782 - loss: 0.0730 - epoch: 187.0000
# Epoch 188/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9799 - loss: 0.0735
# Epoch 188: Test Loss: 0.4178912043571472, Test Accuracy: 0.8840909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9799 - loss: 0.0736 - epoch: 188.0000
# Epoch 189/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9805 - loss: 0.0724
# Epoch 189: Test Loss: 0.45545005798339844, Test Accuracy: 0.8681818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9805 - loss: 0.0725 - epoch: 189.0000
# Epoch 190/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9801 - loss: 0.0786
# Epoch 190: Test Loss: 0.420188307762146, Test Accuracy: 0.8784090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9801 - loss: 0.0785 - epoch: 190.0000
# Epoch 191/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9807 - loss: 0.0686
# Epoch 191: Test Loss: 0.42492738366127014, Test Accuracy: 0.8818181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9807 - loss: 0.0687 - epoch: 191.0000
# Epoch 192/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 0.0775
# Epoch 192: Test Loss: 0.43265217542648315, Test Accuracy: 0.8795454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9756 - loss: 0.0776 - epoch: 192.0000
# Epoch 193/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 0.0821
# Epoch 193: Test Loss: 0.4285905957221985, Test Accuracy: 0.8829545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9755 - loss: 0.0820 - epoch: 193.0000
# Epoch 194/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9817 - loss: 0.0704
# Epoch 194: Test Loss: 0.44122010469436646, Test Accuracy: 0.8738636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9817 - loss: 0.0703 - epoch: 194.0000
# Epoch 195/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9861 - loss: 0.0653
# Epoch 195: Test Loss: 0.4030199944972992, Test Accuracy: 0.8852272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9860 - loss: 0.0654 - epoch: 195.0000
# Epoch 196/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9758 - loss: 0.0796
# Epoch 196: Test Loss: 0.4357523024082184, Test Accuracy: 0.8715909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9759 - loss: 0.0797 - epoch: 196.0000
# Epoch 197/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9793 - loss: 0.0761
# Epoch 197: Test Loss: 0.4753468334674835, Test Accuracy: 0.8659090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9793 - loss: 0.0760 - epoch: 197.0000
# Epoch 198/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9786 - loss: 0.0656
# Epoch 198: Test Loss: 0.44719359278678894, Test Accuracy: 0.8681818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9786 - loss: 0.0657 - epoch: 198.0000
# Epoch 199/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9761 - loss: 0.0811
# Epoch 199: Test Loss: 0.42789775133132935, Test Accuracy: 0.8829545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9762 - loss: 0.0811 - epoch: 199.0000
# Epoch 200/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9793 - loss: 0.0792
# Epoch 200: Test Loss: 0.44182977080345154, Test Accuracy: 0.875
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9794 - loss: 0.0791 - epoch: 200.0000
# Epoch 201/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9754 - loss: 0.0792
# Epoch 201: Test Loss: 0.42498332262039185, Test Accuracy: 0.8795454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9755 - loss: 0.0791 - epoch: 201.0000
# Epoch 202/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9822 - loss: 0.0654
# Epoch 202: Test Loss: 0.47197532653808594, Test Accuracy: 0.8590909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9821 - loss: 0.0654 - epoch: 202.0000
# Epoch 203/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9757 - loss: 0.0770
# Epoch 203: Test Loss: 0.4520014226436615, Test Accuracy: 0.8738636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9758 - loss: 0.0769 - epoch: 203.0000
# Epoch 204/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9791 - loss: 0.0736
# Epoch 204: Test Loss: 0.5013910531997681, Test Accuracy: 0.8511363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9791 - loss: 0.0737 - epoch: 204.0000
# Epoch 205/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9784 - loss: 0.0699
# Epoch 205: Test Loss: 0.4464111626148224, Test Accuracy: 0.8772727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9784 - loss: 0.0699 - epoch: 205.0000
# Epoch 206/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9801 - loss: 0.0669
# Epoch 206: Test Loss: 0.4363456666469574, Test Accuracy: 0.8772727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9801 - loss: 0.0670 - epoch: 206.0000
# Epoch 207/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9805 - loss: 0.0698
# Epoch 207: Test Loss: 0.4634547233581543, Test Accuracy: 0.8681818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9805 - loss: 0.0698 - epoch: 207.0000
# Epoch 208/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0670
# Epoch 208: Test Loss: 0.42171376943588257, Test Accuracy: 0.8818181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9854 - loss: 0.0670 - epoch: 208.0000
# Epoch 209/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.0606
# Epoch 209: Test Loss: 0.3899594247341156, Test Accuracy: 0.8920454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9842 - loss: 0.0606 - epoch: 209.0000
# Epoch 210/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9784 - loss: 0.0788
# Epoch 210: Test Loss: 0.43987056612968445, Test Accuracy: 0.875
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9785 - loss: 0.0787 - epoch: 210.0000
# Epoch 211/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9830 - loss: 0.0627
# Epoch 211: Test Loss: 0.4122966527938843, Test Accuracy: 0.8829545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9830 - loss: 0.0627 - epoch: 211.0000
# Epoch 212/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9831 - loss: 0.0593
# Epoch 212: Test Loss: 0.3825822174549103, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9831 - loss: 0.0593 - epoch: 212.0000
# Epoch 213/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9791 - loss: 0.0708
# Epoch 213: Test Loss: 0.421703964471817, Test Accuracy: 0.8840909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9791 - loss: 0.0707 - epoch: 213.0000
# Epoch 214/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9834 - loss: 0.0601
# Epoch 214: Test Loss: 0.37903741002082825, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9833 - loss: 0.0601 - epoch: 214.0000
# Epoch 215/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9844 - loss: 0.0578
# Epoch 215: Test Loss: 0.45732229948043823, Test Accuracy: 0.8693181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9843 - loss: 0.0579 - epoch: 215.0000
# Epoch 216/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9757 - loss: 0.0681
# Epoch 216: Test Loss: 0.4524640142917633, Test Accuracy: 0.8727272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9757 - loss: 0.0681 - epoch: 216.0000
# Epoch 217/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9832 - loss: 0.0646
# Epoch 217: Test Loss: 0.3912602961063385, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9831 - loss: 0.0647 - epoch: 217.0000
# Epoch 218/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9796 - loss: 0.0626
# Epoch 218: Test Loss: 0.42382916808128357, Test Accuracy: 0.8886363506317139
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9796 - loss: 0.0626 - epoch: 218.0000
# Epoch 219/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.0616
# Epoch 219: Test Loss: 0.40942317247390747, Test Accuracy: 0.887499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9819 - loss: 0.0615 - epoch: 219.0000
# Epoch 220/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9896 - loss: 0.0528
# Epoch 220: Test Loss: 0.37707430124282837, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9895 - loss: 0.0529 - epoch: 220.0000
# Epoch 221/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9861 - loss: 0.0602
# Epoch 221: Test Loss: 0.4193260669708252, Test Accuracy: 0.8863636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9861 - loss: 0.0603 - epoch: 221.0000
# Epoch 222/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9807 - loss: 0.0663
# Epoch 222: Test Loss: 0.43843376636505127, Test Accuracy: 0.8795454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9807 - loss: 0.0661 - epoch: 222.0000
# Epoch 223/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9852 - loss: 0.0612
# Epoch 223: Test Loss: 0.43207991123199463, Test Accuracy: 0.8818181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9851 - loss: 0.0612 - epoch: 223.0000
# Epoch 224/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9841 - loss: 0.0609
# Epoch 224: Test Loss: 0.40928205847740173, Test Accuracy: 0.8897727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9841 - loss: 0.0609 - epoch: 224.0000
# Epoch 225/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9829 - loss: 0.0581
# Epoch 225: Test Loss: 0.4333525598049164, Test Accuracy: 0.8795454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9830 - loss: 0.0581 - epoch: 225.0000
# Epoch 226/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9864 - loss: 0.0566
# Epoch 226: Test Loss: 0.38825082778930664, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9864 - loss: 0.0566 - epoch: 226.0000
# Epoch 227/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9857 - loss: 0.0603
# Epoch 227: Test Loss: 0.4302109479904175, Test Accuracy: 0.887499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9857 - loss: 0.0602 - epoch: 227.0000
# Epoch 228/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.0530
# Epoch 228: Test Loss: 0.42604750394821167, Test Accuracy: 0.8863636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9819 - loss: 0.0531 - epoch: 228.0000
# Epoch 229/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9814 - loss: 0.0627
# Epoch 229: Test Loss: 0.40475165843963623, Test Accuracy: 0.8863636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9815 - loss: 0.0626 - epoch: 229.0000
# Epoch 230/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9870 - loss: 0.0526
# Epoch 230: Test Loss: 0.35628482699394226, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9870 - loss: 0.0526 - epoch: 230.0000
# Epoch 231/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9852 - loss: 0.0558
# Epoch 231: Test Loss: 0.3731381595134735, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9852 - loss: 0.0557 - epoch: 231.0000
# Epoch 232/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0518
# Epoch 232: Test Loss: 0.41876575350761414, Test Accuracy: 0.887499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9873 - loss: 0.0518 - epoch: 232.0000
# Epoch 233/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9852 - loss: 0.0523
# Epoch 233: Test Loss: 0.418206125497818, Test Accuracy: 0.887499988079071
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9852 - loss: 0.0524 - epoch: 233.0000
# Epoch 234/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9859 - loss: 0.0513
# Epoch 234: Test Loss: 0.38724181056022644, Test Accuracy: 0.8897727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9859 - loss: 0.0513 - epoch: 234.0000
# Epoch 235/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9823 - loss: 0.0591
# Epoch 235: Test Loss: 0.38476958870887756, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9824 - loss: 0.0591 - epoch: 235.0000
# Epoch 236/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9813 - loss: 0.0598
# Epoch 236: Test Loss: 0.38466155529022217, Test Accuracy: 0.8965908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9813 - loss: 0.0598 - epoch: 236.0000
# Epoch 237/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9844 - loss: 0.0508
# Epoch 237: Test Loss: 0.40207380056381226, Test Accuracy: 0.8920454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9844 - loss: 0.0508 - epoch: 237.0000
# Epoch 238/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9816 - loss: 0.0599
# Epoch 238: Test Loss: 0.38765355944633484, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9816 - loss: 0.0598 - epoch: 238.0000
# Epoch 239/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0507
# Epoch 239: Test Loss: 0.43932807445526123, Test Accuracy: 0.8818181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9874 - loss: 0.0507 - epoch: 239.0000
# Epoch 240/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0522
# Epoch 240: Test Loss: 0.4209553897380829, Test Accuracy: 0.8897727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9854 - loss: 0.0522 - epoch: 240.0000
# Epoch 241/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9860 - loss: 0.0546
# Epoch 241: Test Loss: 0.3948928713798523, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9860 - loss: 0.0546 - epoch: 241.0000
# Epoch 242/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9864 - loss: 0.0533
# Epoch 242: Test Loss: 0.3889380991458893, Test Accuracy: 0.8920454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9863 - loss: 0.0534 - epoch: 242.0000
# Epoch 243/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9854 - loss: 0.0524
# Epoch 243: Test Loss: 0.3582865595817566, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9854 - loss: 0.0524 - epoch: 243.0000
# Epoch 244/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9819 - loss: 0.0539
# Epoch 244: Test Loss: 0.3961690366268158, Test Accuracy: 0.8909090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9820 - loss: 0.0539 - epoch: 244.0000
# Epoch 245/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9857 - loss: 0.0500
# Epoch 245: Test Loss: 0.4227120280265808, Test Accuracy: 0.8829545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9857 - loss: 0.0500 - epoch: 245.0000
# Epoch 246/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0520
# Epoch 246: Test Loss: 0.366567462682724, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9856 - loss: 0.0520 - epoch: 246.0000
# Epoch 247/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9860 - loss: 0.0537
# Epoch 247: Test Loss: 0.39198750257492065, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9860 - loss: 0.0537 - epoch: 247.0000
# Epoch 248/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0408
# Epoch 248: Test Loss: 0.40048131346702576, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9909 - loss: 0.0409 - epoch: 248.0000
# Epoch 249/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9908 - loss: 0.0453
# Epoch 249: Test Loss: 0.41504862904548645, Test Accuracy: 0.8897727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9908 - loss: 0.0453 - epoch: 249.0000
# Epoch 250/250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0508
# Epoch 250: Test Loss: 0.3802822232246399, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9855 - loss: 0.0508 - epoch: 250.0000

# %%
# Muat data dari file CSV
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Senin, 12 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ## Training Models_200 - 350

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename, initial_epoch=1):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0 and self.epoch == 2:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename, initial_epoch=1):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.initial_epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_train.csv"
test_log_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_test.csv"
model_filepath_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.9_keras.keras"

# Load the last saved model
try:
    model = tf.keras.models.load_model(model_filepath_v1)
    print("Model loaded from checkpoint.")
except Exception as e:
    print(f"Failed to load model from checkpoint: {e}")

# Determine the last epoch trained
try:
    history_df = pd.read_csv(csv_logger_v1)
    initial_epoch = history_df['epoch'].max()
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
    initial_epoch = 1

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

# Define callbacks
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1, initial_epoch=initial_epoch + 1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1, initial_epoch=initial_epoch + 1)

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    # validation_data=(X_val, y_val),
    epochs=initial_epoch + 100,  # change this to the desired number of total epochs
    batch_size=64,
    initial_epoch=initial_epoch,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Model loaded from checkpoint.
# Epoch 251/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - loss: 0.0553
# Epoch 251: Test Loss: 0.3905472159385681, Test Accuracy: 0.8965908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9836 - loss: 0.0553 - epoch: 251.0000
# Epoch 252/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0493
# Epoch 252: Test Loss: 0.37641099095344543, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9856 - loss: 0.0493 - epoch: 252.0000
# Epoch 253/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9880 - loss: 0.0475
# Epoch 253: Test Loss: 0.34663915634155273, Test Accuracy: 0.9034090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9880 - loss: 0.0475 - epoch: 253.0000
# Epoch 254/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9866 - loss: 0.0460
# Epoch 254: Test Loss: 0.4230762720108032, Test Accuracy: 0.8840909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9865 - loss: 0.0462 - epoch: 254.0000
# Epoch 255/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0517
# Epoch 255: Test Loss: 0.3879278600215912, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9876 - loss: 0.0517 - epoch: 255.0000
# Epoch 256/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9818 - loss: 0.0558
# Epoch 256: Test Loss: 0.37865063548088074, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9819 - loss: 0.0557 - epoch: 256.0000
# Epoch 257/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - loss: 0.0475
# Epoch 257: Test Loss: 0.4028142988681793, Test Accuracy: 0.8909090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9890 - loss: 0.0476 - epoch: 257.0000
# Epoch 258/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9785 - loss: 0.0649
# Epoch 258: Test Loss: 0.3618759214878082, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9786 - loss: 0.0646 - epoch: 258.0000
# Epoch 259/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9836 - loss: 0.0517
# Epoch 259: Test Loss: 0.3855421543121338, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9837 - loss: 0.0516 - epoch: 259.0000
# Epoch 260/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0482
# Epoch 260: Test Loss: 0.356600821018219, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9873 - loss: 0.0481 - epoch: 260.0000
# Epoch 261/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.0510
# Epoch 261: Test Loss: 0.39597731828689575, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9878 - loss: 0.0510 - epoch: 261.0000
# Epoch 262/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0440
# Epoch 262: Test Loss: 0.39492762088775635, Test Accuracy: 0.8965908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9873 - loss: 0.0441 - epoch: 262.0000
# Epoch 263/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.0418
# Epoch 263: Test Loss: 0.40928903222084045, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9893 - loss: 0.0417 - epoch: 263.0000
# Epoch 264/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9908 - loss: 0.0428
# Epoch 264: Test Loss: 0.39456677436828613, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9907 - loss: 0.0429 - epoch: 264.0000
# Epoch 265/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9834 - loss: 0.0540
# Epoch 265: Test Loss: 0.3654588758945465, Test Accuracy: 0.8965908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9834 - loss: 0.0539 - epoch: 265.0000
# Epoch 266/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0490
# Epoch 266: Test Loss: 0.3554531931877136, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9876 - loss: 0.0491 - epoch: 266.0000
# Epoch 267/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9889 - loss: 0.0480
# Epoch 267: Test Loss: 0.3879689872264862, Test Accuracy: 0.8965908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9888 - loss: 0.0480 - epoch: 267.0000
# Epoch 268/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.0460
# Epoch 268: Test Loss: 0.384823739528656, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9893 - loss: 0.0460 - epoch: 268.0000
# Epoch 269/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9854 - loss: 0.0509
# Epoch 269: Test Loss: 0.3690246343612671, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9854 - loss: 0.0510 - epoch: 269.0000
# Epoch 270/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9870 - loss: 0.0478
# Epoch 270: Test Loss: 0.37429478764533997, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9870 - loss: 0.0478 - epoch: 270.0000
# Epoch 271/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0437
# Epoch 271: Test Loss: 0.37530308961868286, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9874 - loss: 0.0437 - epoch: 271.0000
# Epoch 272/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0417
# Epoch 272: Test Loss: 0.3534892201423645, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9907 - loss: 0.0416 - epoch: 272.0000
# Epoch 273/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9884 - loss: 0.0446
# Epoch 273: Test Loss: 0.35665270686149597, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9884 - loss: 0.0446 - epoch: 273.0000
# Epoch 274/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9869 - loss: 0.0466
# Epoch 274: Test Loss: 0.35320839285850525, Test Accuracy: 0.9090909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9869 - loss: 0.0466 - epoch: 274.0000
# Epoch 275/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0426
# Epoch 275: Test Loss: 0.3455103933811188, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9904 - loss: 0.0426 - epoch: 275.0000
# Epoch 276/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9924 - loss: 0.0374
# Epoch 276: Test Loss: 0.3797411024570465, Test Accuracy: 0.8988636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9923 - loss: 0.0375 - epoch: 276.0000
# Epoch 277/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0412
# Epoch 277: Test Loss: 0.3753691017627716, Test Accuracy: 0.8999999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9915 - loss: 0.0412 - epoch: 277.0000
# Epoch 278/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9890 - loss: 0.0426
# Epoch 278: Test Loss: 0.3803557753562927, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9890 - loss: 0.0426 - epoch: 278.0000
# Epoch 279/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0388
# Epoch 279: Test Loss: 0.3673708438873291, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9922 - loss: 0.0389 - epoch: 279.0000
# Epoch 280/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9861 - loss: 0.0452
# Epoch 280: Test Loss: 0.3877866268157959, Test Accuracy: 0.8988636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9861 - loss: 0.0451 - epoch: 280.0000
# Epoch 281/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9900 - loss: 0.0448
# Epoch 281: Test Loss: 0.4047609567642212, Test Accuracy: 0.8909090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9901 - loss: 0.0448 - epoch: 281.0000
# Epoch 282/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0459
# Epoch 282: Test Loss: 0.3576727509498596, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9904 - loss: 0.0459 - epoch: 282.0000
# Epoch 283/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9919 - loss: 0.0358
# Epoch 283: Test Loss: 0.3556008040904999, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9919 - loss: 0.0358 - epoch: 283.0000
# Epoch 284/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0429
# Epoch 284: Test Loss: 0.3524017632007599, Test Accuracy: 0.9034090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9887 - loss: 0.0429 - epoch: 284.0000
# Epoch 285/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9949 - loss: 0.0285
# Epoch 285: Test Loss: 0.3411438465118408, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9949 - loss: 0.0286 - epoch: 285.0000
# Epoch 286/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9877 - loss: 0.0404
# Epoch 286: Test Loss: 0.3534695506095886, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9878 - loss: 0.0404 - epoch: 286.0000
# Epoch 287/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9864 - loss: 0.0436
# Epoch 287: Test Loss: 0.35864347219467163, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9865 - loss: 0.0436 - epoch: 287.0000
# Epoch 288/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0394
# Epoch 288: Test Loss: 0.34190577268600464, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9909 - loss: 0.0394 - epoch: 288.0000
# Epoch 289/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0370
# Epoch 289: Test Loss: 0.39646103978157043, Test Accuracy: 0.8988636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9912 - loss: 0.0371 - epoch: 289.0000
# Epoch 290/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.0501
# Epoch 290: Test Loss: 0.3762657940387726, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9843 - loss: 0.0501 - epoch: 290.0000
# Epoch 291/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0424
# Epoch 291: Test Loss: 0.39592644572257996, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9893 - loss: 0.0424 - epoch: 291.0000
# Epoch 292/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0433
# Epoch 292: Test Loss: 0.3725811243057251, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9887 - loss: 0.0433 - epoch: 292.0000
# Epoch 293/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.0416
# Epoch 293: Test Loss: 0.36874863505363464, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9885 - loss: 0.0416 - epoch: 293.0000
# Epoch 294/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0377
# Epoch 294: Test Loss: 0.3286152482032776, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9920 - loss: 0.0377 - epoch: 294.0000
# Epoch 295/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 0.0460
# Epoch 295: Test Loss: 0.3504159152507782, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9862 - loss: 0.0459 - epoch: 295.0000
# Epoch 296/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0416
# Epoch 296: Test Loss: 0.35060563683509827, Test Accuracy: 0.9034090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9887 - loss: 0.0416 - epoch: 296.0000
# Epoch 297/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0358
# Epoch 297: Test Loss: 0.35939648747444153, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9904 - loss: 0.0359 - epoch: 297.0000
# Epoch 298/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0399
# Epoch 298: Test Loss: 0.36688533425331116, Test Accuracy: 0.8999999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9893 - loss: 0.0399 - epoch: 298.0000
# Epoch 299/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9908 - loss: 0.0406
# Epoch 299: Test Loss: 0.37723493576049805, Test Accuracy: 0.8988636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9907 - loss: 0.0406 - epoch: 299.0000
# Epoch 300/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9906 - loss: 0.0381
# Epoch 300: Test Loss: 0.3598732054233551, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9906 - loss: 0.0381 - epoch: 300.0000
# Epoch 301/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9899 - loss: 0.0333
# Epoch 301: Test Loss: 0.3668900430202484, Test Accuracy: 0.8977272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9899 - loss: 0.0333 - epoch: 301.0000
# Epoch 302/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9902 - loss: 0.0405
# Epoch 302: Test Loss: 0.35453400015830994, Test Accuracy: 0.9034090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9902 - loss: 0.0404 - epoch: 302.0000
# Epoch 303/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0344
# Epoch 303: Test Loss: 0.36775392293930054, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9904 - loss: 0.0344 - epoch: 303.0000
# Epoch 304/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9919 - loss: 0.0356
# Epoch 304: Test Loss: 0.3627718985080719, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9919 - loss: 0.0356 - epoch: 304.0000
# Epoch 305/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9895 - loss: 0.0404
# Epoch 305: Test Loss: 0.3457385003566742, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9895 - loss: 0.0404 - epoch: 305.0000
# Epoch 306/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0428
# Epoch 306: Test Loss: 0.34358978271484375, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9887 - loss: 0.0428 - epoch: 306.0000
# Epoch 307/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0329
# Epoch 307: Test Loss: 0.3601324260234833, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9915 - loss: 0.0329 - epoch: 307.0000
# Epoch 308/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0418
# Epoch 308: Test Loss: 0.3334266245365143, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9911 - loss: 0.0418 - epoch: 308.0000
# Epoch 309/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9940 - loss: 0.0335
# Epoch 309: Test Loss: 0.3226650357246399, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9939 - loss: 0.0336 - epoch: 309.0000
# Epoch 310/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0370
# Epoch 310: Test Loss: 0.3355144262313843, Test Accuracy: 0.9090909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9909 - loss: 0.0370 - epoch: 310.0000
# Epoch 311/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 0.0396
# Epoch 311: Test Loss: 0.31382298469543457, Test Accuracy: 0.9170454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9898 - loss: 0.0396 - epoch: 311.0000
# Epoch 312/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0399
# Epoch 312: Test Loss: 0.3388858735561371, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9905 - loss: 0.0398 - epoch: 312.0000
# Epoch 313/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0432
# Epoch 313: Test Loss: 0.34809812903404236, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9875 - loss: 0.0432 - epoch: 313.0000
# Epoch 314/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9903 - loss: 0.0367
# Epoch 314: Test Loss: 0.3390956521034241, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9903 - loss: 0.0367 - epoch: 314.0000
# Epoch 315/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0341
# Epoch 315: Test Loss: 0.3296116292476654, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9927 - loss: 0.0342 - epoch: 315.0000
# Epoch 316/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9932 - loss: 0.0346
# Epoch 316: Test Loss: 0.30823707580566406, Test Accuracy: 0.9170454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9932 - loss: 0.0346 - epoch: 316.0000
# Epoch 317/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0371
# Epoch 317: Test Loss: 0.3488102853298187, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9907 - loss: 0.0371 - epoch: 317.0000
# Epoch 318/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0377
# Epoch 318: Test Loss: 0.34355056285858154, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9917 - loss: 0.0377 - epoch: 318.0000
# Epoch 319/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0353
# Epoch 319: Test Loss: 0.34984660148620605, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9912 - loss: 0.0354 - epoch: 319.0000
# Epoch 320/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9892 - loss: 0.0389
# Epoch 320: Test Loss: 0.32302936911582947, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9892 - loss: 0.0388 - epoch: 320.0000
# Epoch 321/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0399
# Epoch 321: Test Loss: 0.33312568068504333, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9911 - loss: 0.0399 - epoch: 321.0000
# Epoch 322/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0327
# Epoch 322: Test Loss: 0.32614001631736755, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9915 - loss: 0.0327 - epoch: 322.0000
# Epoch 323/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0322
# Epoch 323: Test Loss: 0.3214161992073059, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9911 - loss: 0.0322 - epoch: 323.0000
# Epoch 324/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0381
# Epoch 324: Test Loss: 0.33297136425971985, Test Accuracy: 0.9125000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9868 - loss: 0.0381 - epoch: 324.0000
# Epoch 325/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0311
# Epoch 325: Test Loss: 0.3363085687160492, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9917 - loss: 0.0311 - epoch: 325.0000
# Epoch 326/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9875 - loss: 0.0464
# Epoch 326: Test Loss: 0.3411494493484497, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9875 - loss: 0.0462 - epoch: 326.0000
# Epoch 327/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9903 - loss: 0.0331
# Epoch 327: Test Loss: 0.33487623929977417, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9903 - loss: 0.0332 - epoch: 327.0000
# Epoch 328/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9906 - loss: 0.0375
# Epoch 328: Test Loss: 0.3314298093318939, Test Accuracy: 0.9125000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9906 - loss: 0.0374 - epoch: 328.0000
# Epoch 329/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9910 - loss: 0.0339
# Epoch 329: Test Loss: 0.33124688267707825, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9910 - loss: 0.0339 - epoch: 329.0000
# Epoch 330/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9929 - loss: 0.0321
# Epoch 330: Test Loss: 0.31035149097442627, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9929 - loss: 0.0321 - epoch: 330.0000
# Epoch 331/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0311
# Epoch 331: Test Loss: 0.34210288524627686, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9925 - loss: 0.0311 - epoch: 331.0000
# Epoch 332/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9891 - loss: 0.0340
# Epoch 332: Test Loss: 0.34782862663269043, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9891 - loss: 0.0340 - epoch: 332.0000
# Epoch 333/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9932 - loss: 0.0258
# Epoch 333: Test Loss: 0.35090476274490356, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9932 - loss: 0.0259 - epoch: 333.0000
# Epoch 334/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0315
# Epoch 334: Test Loss: 0.3392398953437805, Test Accuracy: 0.9090909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9933 - loss: 0.0315 - epoch: 334.0000
# Epoch 335/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9930 - loss: 0.0345
# Epoch 335: Test Loss: 0.3481070399284363, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9930 - loss: 0.0345 - epoch: 335.0000
# Epoch 336/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0330
# Epoch 336: Test Loss: 0.34085482358932495, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9927 - loss: 0.0330 - epoch: 336.0000
# Epoch 337/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0298
# Epoch 337: Test Loss: 0.3495788872241974, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9945 - loss: 0.0298 - epoch: 337.0000
# Epoch 338/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0333
# Epoch 338: Test Loss: 0.3346722424030304, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9927 - loss: 0.0333 - epoch: 338.0000
# Epoch 339/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9924 - loss: 0.0284
# Epoch 339: Test Loss: 0.32513052225112915, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9924 - loss: 0.0284 - epoch: 339.0000
# Epoch 340/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.0303
# Epoch 340: Test Loss: 0.3255813717842102, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9939 - loss: 0.0303 - epoch: 340.0000
# Epoch 341/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0330
# Epoch 341: Test Loss: 0.3443666696548462, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9922 - loss: 0.0329 - epoch: 341.0000
# Epoch 342/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9937 - loss: 0.0269
# Epoch 342: Test Loss: 0.3494183421134949, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9937 - loss: 0.0270 - epoch: 342.0000
# Epoch 343/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0341
# Epoch 343: Test Loss: 0.32377320528030396, Test Accuracy: 0.9159091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9913 - loss: 0.0341 - epoch: 343.0000
# Epoch 344/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.0313
# Epoch 344: Test Loss: 0.34679603576660156, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9928 - loss: 0.0313 - epoch: 344.0000
# Epoch 345/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0357
# Epoch 345: Test Loss: 0.347575843334198, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9911 - loss: 0.0356 - epoch: 345.0000
# Epoch 346/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0320
# Epoch 346: Test Loss: 0.32788416743278503, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9905 - loss: 0.0321 - epoch: 346.0000
# Epoch 347/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0301
# Epoch 347: Test Loss: 0.3240630328655243, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9946 - loss: 0.0302 - epoch: 347.0000
# Epoch 348/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.0274
# Epoch 348: Test Loss: 0.3397379517555237, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9927 - loss: 0.0275 - epoch: 348.0000
# Epoch 349/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0336
# Epoch 349: Test Loss: 0.33374688029289246, Test Accuracy: 0.9090909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9911 - loss: 0.0336 - epoch: 349.0000
# Epoch 350/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.0434
# Epoch 350: Test Loss: 0.331992506980896, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9885 - loss: 0.0432 - epoch: 350.0000

# %%
# Muat data dari file CSV
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Sabtu, 10 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# # Evaluate Model

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Muat data dari file CSV
csv_logger_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_train.csv"
test_log_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.9_log_test.csv"

try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot Akurasi
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Testing Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('History of Accuracy', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

    # Plot Loss
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Testing Loss', color='red')  # Plot Test Loss per epoch
    plt.title('History of Loss', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
import tensorflow as tf

# Filepath model yang disimpan
model_filepath_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.9_keras.keras"

# Load the last saved model
model = tf.keras.models.load_model(model_filepath_v1)

# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, log_loss, accuracy_score, classification_report, confusion_matrix

# Prediksi menggunakan model pada data uji
y_pred = model.predict(X_test)
y_pred_probabilities = tf.nn.softmax(y_pred).numpy() 
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Hitung metrik evaluasi
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
log_loss_value = log_loss(y_true_classes, y_pred_probabilities)

# Print metrik evaluasi
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Log Loss: {log_loss_value:.2f}")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step
# Accuracy: 0.91
# Precision: 0.92
# Recall: 0.91
# F1 Score: 0.91
# Log Loss: 2.18

# %%
# Tampilkan classification report yang lengkap
report = classification_report(y_true_classes, y_pred_classes, target_names=AKSARA)
print(report)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Normalisasi confusion matrix untuk mendapatkan persentase
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Tampilkan confusion matrix sebagai heatmap
plt.figure(figsize=(18, 15))
# sns.heatmap(conf_matrix_normalized, annot=True, fmt=".2%", cmap="YlGnBu", xticklabels=AKSARA, yticklabels=AKSARA)
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=AKSARA, yticklabels=AKSARA)

plt.xlabel("Actual Aksara", fontsize=15)
plt.ylabel("Predicted Aksara", fontsize=15)
# plt.title("Confusion Matrix (Percentage)")
plt.title("Confusion Matrix", fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           ba       0.91      0.91      0.91        43
#           ca       1.00      0.70      0.82        46
#           da       0.98      0.91      0.94        45
#          dha       0.81      0.91      0.86        47
#           ga       0.97      0.88      0.92        40
#           ha       0.83      0.96      0.89        47
#           ja       1.00      0.95      0.97        38
#           ka       1.00      0.98      0.99        45
#           la       0.87      0.96      0.91        50
#           ma       0.98      0.88      0.93        51
#           na       0.84      0.97      0.90        37
#          nga       0.86      0.92      0.89        52
#          nya       0.93      0.98      0.95        41
#           pa       0.69      0.98      0.81        45
#           ra       0.98      1.00      0.99        45
#           sa       0.97      0.90      0.93        39
#           ta       1.00      0.83      0.91        41
#          tha       1.00      0.87      0.93        45
#           wa       0.97      0.72      0.82        46
#           ya       0.82      0.97      0.89        37
#
#     accuracy                           0.91       880
#    macro avg       0.92      0.91      0.91       880
# weighted avg       0.92      0.91      0.91       880

# %%
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from sklearn.metrics import classification_report, confusion_matrix

# # Definisikan kelas Aksara
# AKSARA = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma', 
#           'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Muat model dari checkpoint
# try:
#     model = tf.keras.models.load_model(model_filepath_v1)
#     print("Model loaded from checkpoint.")
# except Exception as e:
#     print(f"Failed to load model from checkpoint: {e}")

# # Prediksi menggunakan model pada data uji
# y_pred = model.predict(X_test)
# y_pred_probabilities = tf.nn.softmax(y_pred).numpy()  # Terapkan softmax secara eksplisit jika perlu
# y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
# y_true_classes = np.argmax(y_test, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# # Normalisasi confusion matrix untuk mendapatkan persentase
# conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# # Kelas untuk setiap subset
# subset1_classes = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma']
# subset2_classes = ['na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Dapatkan indeks untuk setiap subset
# subset1_indices = [AKSARA.index(cls) for cls in subset1_classes]
# subset2_indices = [AKSARA.index(cls) for cls in subset2_classes]

# # Pisahkan confusion matrix untuk dua subset kelas
# conf_matrix_subset1 = conf_matrix_normalized[np.ix_(subset1_indices, subset1_indices)]
# conf_matrix_subset2 = conf_matrix_normalized[np.ix_(subset2_indices, subset2_indices)]

# # Simpan confusion matrix subset 1 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset1, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset1_classes, yticklabels=subset1_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 1 (Percentage)")
# plt.title("Confusion Matrix - Subset 1", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\v4.4.9_subset1.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# # Simpan confusion matrix subset 2 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset2, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset2_classes, yticklabels=subset2_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 2 (Percentage)")
# plt.title("Confusion Matrix - Subset 2", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\v4.4.9_subset2.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# %% [markdown]
# # Predictive Model

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the function to display images with predictions
def display_images_with_predictions(images, true_labels, predictions, labels, max_images=10):
    num_images = min(len(images), max_images)
    cols = 5
    rows = (num_images + cols - 1) // cols  # Compute number of rows needed

    plt.figure(figsize=(15, 3 * rows))
    
    for i in range(num_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        
        # Check if prediction is correct
        correct = true_labels[i] == predictions[i]
        result = "Correct" if correct else "Incorrect"
        color = "green" if correct else "red"
        
        # Adjust title to avoid overlapping
        plt.title(
            f"True: {labels[true_labels[i]]} || Pred: {labels[predictions[i]]}\n{result}",
            color=color,
            fontsize=12,  # Set font size
            pad=5  # Add padding to title
        )
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Load the trained model
model = load_model(model_filepath_v1)

# Perform predictions
y_pred_probabilities = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)

# Convert one-hot encoded y_test to class indices if needed
if y_test.ndim == 2:
    y_test_classes = np.argmax(y_test, axis=1)
else:
    y_test_classes = y_test

# Display some test images with predictions
display_images_with_predictions(X_test, y_test_classes, y_pred_classes, AKSARA)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the function to display images with predictions
def display_images_with_predictions(images, true_labels, predictions, labels, max_images=30):
    num_images = min(len(images), max_images)
    cols = 5
    rows = (num_images + cols - 1) // cols  # Compute number of rows needed

    plt.figure(figsize=(15, 3 * rows))
    
    for i in range(num_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        
        # Check if prediction is correct
        correct = true_labels[i] == predictions[i]
        result = "Correct" if correct else "Incorrect"
        color = "green" if correct else "red"
        
        # Adjust title to avoid overlapping
        plt.title(
            f"True: {labels[true_labels[i]]} || Pred: {labels[predictions[i]]}\n{result}",
            color=color,
            fontsize=12,  # Set font size
            pad=5  # Add padding to title
        )
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Load the trained model
model = load_model(model_filepath_v1)

# Perform predictions
y_pred_probabilities = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)

# Convert one-hot encoded y_test to class indices if needed
if y_test.ndim == 2:
    y_test_classes = np.argmax(y_test, axis=1)
else:
    y_test_classes = y_test

# Display some test images with predictions
display_images_with_predictions(X_test, y_test_classes, y_pred_classes, AKSARA)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed

# Load the trained model
model = load_model(model_filepath_v1)  # Replace with your model path

# Path to the test image
test_image_path = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ba49.mine2.png"
image_size = IMAGE_SIZE

# Preprocess the image
preprocessed_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
pos = np.argmax(output)

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", output[0][pos])

# Define a variable to store the predicted label
predicted_label = ""

# Print the class based on the position using if-elif
if pos == 0:
    predicted_label = "ba"
elif pos == 1:
    predicted_label = 'ca'
elif pos == 2:
    predicted_label = 'da'
elif pos == 3:
    predicted_label = 'dha'
elif pos == 4:
    predicted_label = 'ga'
elif pos == 5:
    predicted_label = 'ha'
elif pos == 6:
    predicted_label = 'ja'
elif pos == 7:
    predicted_label = 'ka'
elif pos == 8:
    predicted_label = 'la'
elif pos == 9:
    predicted_label = 'ma'
elif pos == 10:
    predicted_label = 'na'
elif pos == 11:
    predicted_label = 'nga'
elif pos == 12:
    predicted_label = 'nya'
elif pos == 13:
    predicted_label = 'pa'
elif pos == 14:
    predicted_label = 'ra'
elif pos == 15:
    predicted_label = 'sa'
elif pos == 16:
    predicted_label = 'ta'
elif pos == 17:
    predicted_label = 'tha'
elif pos == 18:
    predicted_label = 'wa'
elif pos == 19:
    predicted_label = 'ya'

# Print the predicted label
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(image.img_to_array(image.load_img(test_image_path, target_size=image_size, color_mode='grayscale')))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
# plt.title(f"Predicted: {predicted_label} || Score: {output[0][pos]:.8f}")
plt.title(f"Predicted: {predicted_label}", fontsize=15)
plt.axis('on')

plt.show()

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) 
    # Apply Laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed, img_array_resized  # Return both images if needed

# Load the trained model
model = load_model(model_filepath_v1)

# Path to the test image
test_image_path = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ra3.png"
image_size = IMAGE_SIZE

# Preprocess the image
preprocessed_image, original_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
max_val = output[0][0]
pos = 0
for i in range(1, len(output[0])):
    if output[0][i] > max_val:
        max_val = output[0][i]
        pos = i

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", max_val)

# Define labels
labels = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 
          'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']
predicted_label = labels[pos]
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(cv2.resize(image.img_to_array(image.load_img(test_image_path, color_mode='grayscale')), image_size, interpolation=cv2.INTER_AREA))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
plt.title(f"Predicted: {predicted_label}")
plt.axis('on')

plt.show()
