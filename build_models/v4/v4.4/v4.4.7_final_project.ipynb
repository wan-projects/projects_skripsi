# %% [markdown]
# # Note
# 1. Melakukan percobaan build_models v4.0
# 2. Dilakukan pada hari Sabtu, 10 Agustus 2024
# 3. Tempat di Kost
# 4. Data menggunakan Dataset yang dari Roboflow
# 4. Meliputi Class: 20 Kelas Aksara Jawa:
# - Ba, Ca, Da, Dha, Ga, Ha, Ja, Ka, La, Ma,
# - Na, Nga, Nya, Pa, Ra, Sa, Ta, Tha, Wa, Ya

# %% [markdown]
# # Setup Environment

# %%
# pip install tensorflow

# %%
# pip install keras

# %%
# pip install opencv-python

# %%
# pip install imutils

# %%
# pip install matplotlib

# %%
# pip install seaborn

# %%
# pip install scikit-learn

# %% [markdown]
# # Import Library

# %%
# import pandas as pd
# import matplotlib.pyplot as plt  
# import os
# from os.path import join
# import random
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from tensorflow.keras.utils import to_categorical
# from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
# from keras.models import Sequential
# from tensorflow.keras import layers, models
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization , Activation,Conv2D
# from keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# from sklearn.metrics import roc_curve, auc, roc_auc_score
# from sklearn.metrics import classification_report
# import seaborn as sns
# from sklearn.metrics import classification_report, accuracy_score,roc_curve,confusion_matrix

# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
import cv2

def convert_to_png(image_path, output_path):
    # Read the image using OpenCV
    image = cv2.imread(image_path)
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    # Save the image as PNG
    cv2.imwrite(output_path, image)

def get_last_n_parts(path, n):
    return os.path.join(*path.split(os.sep)[-n:])

def create_labels_csv(data_collection, output_csv, path_output):
    # Check if the CSV file already exists
    if os.path.exists(output_csv):
        print(f'Label CSV already exists at: {output_csv}')
        return  # Exit the function if the file already exists
    
    # List to store image file paths and their corresponding labels and dimensions
    data = []

    # Traverse the dataset directory
    for root, dirs, files in os.walk(data_collection):
        for file in files:
            if file.endswith(('.jpg', '.jpeg', '.png')):
                # Get the class label from the subdirectory name
                label = os.path.basename(root)
                # Get the full file path
                file_path = os.path.join(root, file)
                
                # Create a new file path for the PNG image
                relative_path = os.path.relpath(file_path, data_collection)
                png_file_path = os.path.join(path_output, os.path.splitext(relative_path)[0] + '.png')
                
                # Convert the image to PNG
                convert_to_png(file_path, png_file_path)
                
                # Get image dimensions
                img = cv2.imread(file_path)
                height, width, _ = img.shape
                
                # Get only the last 3 parts of the path for CSV
                csv_path = get_last_n_parts(png_file_path, 2)
                
                # Append to the data list including dimensions
                data.append([csv_path, width, height, label])
    
    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=['file_path', 'width', 'height', 'label'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, index=False)
    print(f'Labels CSV file created at: {output_csv}')

# Define the paths for the two datasets and their respective output directories
data_collection = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\Four_Data_Sources\\"
output_csv = "C:\\Users\\M S I\\W\\projects_skripsi\\data\\data_preprocessing\\v3.7_data_collection\\labels.csv"
path_output = "C:\\Users\\M S I\\W\\projects_skripsi\\data\\data_preprocessing\\v3.7_data_collection\\"

# Process the dataset
create_labels_csv(data_collection, output_csv, path_output)
# Out:
# Label CSV already exists at: C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\labels.csv

# %%
import pandas as pd

# Path main
PATH_MAIN = path_output
file = PATH_MAIN + "labels.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                                      file_path  width  height label
# 0  ba\002798ad-631c-4f0c-b899-aa66fb5c2ac1.png    239     167    ba
# 1  ba\040ab1c7-bffa-4a93-8c42-54e5597f2243.png     96      67    ba
# 2  ba\0789a0d8-e129-48ec-b74e-2e53f4a7ece9.png    235     166    ba
# 3  ba\11f6c317-635a-4e64-8552-05bf8b7b3a95.png     96      67    ba
# 4  ba\13469389-6f9b-43dc-be99-8dfbfaae51cb.png    235     165    ba

# %%
import matplotlib.pyplot as plt
import os

# Define an empty list
file_counts = []
aksara_categories = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na',
                     'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

def countFile(link):
    path = link
    num_files = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
    file_counts.append(num_files)
    print(f"Jumlah File {link} is ", num_files)

# Define the input path
base_path = PATH_MAIN

# Count files for each category
for category in aksara_categories:
    countFile(os.path.join(base_path, category))

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'pink', 'indigo', 'purple', 
          'cyan', 'magenta', 'lime', 'maroon', 'navy', 'olive', 'orchid', 'peru', 
          'salmon', 'sienna', 'skyblue', 'tan']  # Colors for each bar

# Create bar chart
plt.figure(figsize=(13, 6))
bars = plt.bar(aksara_categories, file_counts, color=colors)
plt.xlabel('Kategori Aksara', fontsize=15)
plt.ylabel('Jumlah Gambar', fontsize=15)
plt.title('Jumlah Gambar Aksara Jawa', fontsize=17)
plt.xticks(fontsize=15, rotation=13)
plt.tight_layout()

# Add text labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Show the plot
plt.show()
# Out:
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ba is  225
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ca is  218
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\da is  220
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\dha is  218
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ga is  219
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ha is  215
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ja is  218
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ka is  219
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\la is  219
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ma is  218
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\na is  219
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\nga is  211
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\nya is  215
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\pa is  216
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ra is  217
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\sa is  219
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ta is  216
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\tha is  217
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\wa is  220
# Jumlah File C:\Users\M S I\W\projects_skripsi\data\data_preprocessing\v3.7_data_collection\ya is  218

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Define the input path and aksaraJowo
INPUT_PATH = PATH_MAIN  
AKSARA = aksara_categories

# Define the target image size
IMAGE_SIZE = (96, 96)
INPUT_SHAPE = (96, 96, 1)

def apply_custom_preprocessing(image):
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

def create_image_generator(input_path, aksaraJowo, image_size):
    for index, jowo in enumerate(aksaraJowo):
        aksara_path = os.path.join(input_path, jowo)
        
        for filename in os.listdir(aksara_path):
            image_path = os.path.join(aksara_path, filename)
            original_image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)  # Baca dan ubah warna asli
            original_image_resized = cv2.resize(original_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar asli
            grayscale_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Baca gambar sebagai grayscale
            grayscale_image_resized = cv2.resize(grayscale_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar grayscale
            image_filtered = apply_custom_preprocessing(grayscale_image_resized)
            
            yield original_image_resized, grayscale_image_resized, image_filtered, index

# tranform list to numpy array
def load_images(input_path, aksaraJowo, image_size):
    X_original, X_grayscale, X_filtered, y_label = [], [], [], []
    
    for original_image, grayscale_image, image_filtered, label in create_image_generator(input_path, aksaraJowo, image_size):
        X_original.append(original_image)
        X_grayscale.append(grayscale_image)
        X_filtered.append(image_filtered)
        y_label.append(label)
        
    X_original = np.array(X_original)
    X_grayscale = np.array(X_grayscale)
    X_filtered = np.array(X_filtered)
    y_label = to_categorical(np.array(y_label))
    
    return X_original, X_grayscale, X_filtered, y_label

# Load images with custom preprocessing applied
X_original, X_grayscale, X_filtered, y_label = load_images(INPUT_PATH, AKSARA, IMAGE_SIZE)

# %%
# Select one image to display
index_to_display = 100

# Display the original image, grayscale image, and filtered image
original_image = X_original[index_to_display]
grayscale_image = X_grayscale[index_to_display]
filtered_image = X_filtered[index_to_display]

# Plot the images
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(original_image)
plt.axis('on')

plt.subplot(1, 3, 2)
plt.title('Grayscale Image')
plt.imshow(grayscale_image)
plt.axis('on')

plt.subplot(1, 3, 3)
plt.title('Filtered Image')
# plt.imshow(filtered_image, cmap='gray')
plt.imshow(filtered_image, cmap='gray')
plt.axis('on')

plt.show()

# %%
# Reshape X_filtered
X_filtered_reshaped = X_filtered.reshape(-1, 96, 96, 1) / 255  # Reshape dan normalisasi

print("X_filtered shape after reshape:", X_filtered_reshaped.shape)
# Out:
# X_filtered shape after reshape: (4357, 96, 96, 1)

# %%
from sklearn.model_selection import train_test_split

# Tahap pertama: Membagi data menjadi data pelatihan (80%) dan data pengujian (20%)
X_train, X_test, y_train, y_test = train_test_split(X_filtered_reshaped, y_label, test_size=0.2, random_state=54)

# Verifikasi ukuran data
print("Ukuran data pelatihan:", X_train.shape, y_train.shape)
print("Ukuran data pengujian:", X_test.shape, y_test.shape)
# Out:
# Ukuran data pelatihan: (3485, 96, 96, 1) (3485, 20)
# Ukuran data pengujian: (872, 96, 96, 1) (872, 20)

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_train[0], cmap='gray')
plt.title("Sample Image in Class {} from Training Data !!!".format(AKSARA[np.argmax(y_train[0])]))
plt.axis('on')
plt.show()

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_test[0], cmap='gray')
plt.title("Sample Image in Class {} from Testing Data !!!".format(AKSARA[np.argmax(y_test[0])]))
plt.axis('on')
plt.show()

# %% [markdown]
# # Build the Model

# %% [markdown]
# ## Training Models_1 - 350

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras import optimizers

# Set hyperparameters tuning
optimizer = 'SGD'
learning_rate = 0.0001
dropout_rate = 0.2
weight_decay = 0.0001
momentum = 0.9
clip_norm = 0.0
num_classes = 20
input_shape = INPUT_SHAPE

def create_model(input_shape, num_classes, optimizer_name, learning_rate, dropout_rate, weight_decay, momentum, clip_norm):
    model = Sequential()

    # Block 1
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 3
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 4
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 5
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Flatten
    model.add(Flatten())

    # Dense layers
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))

    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    # Define optimizer with hyperparameters
    if optimizer_name == 'SGD':
        optimizer = optimizers.SGD(learning_rate=learning_rate, decay=weight_decay, momentum=momentum, clipnorm=clip_norm)
    elif optimizer_name == 'Adam':
        optimizer = optimizers.Adam(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    elif optimizer_name == 'RMSprop':
        optimizer = optimizers.RMSprop(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    else:
        raise ValueError("Optimizer not supported. Choose from 'SGD', 'Adam', or 'RMSprop'.")

    # Compile model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Create the model
model = create_model(input_shape=input_shape, num_classes=num_classes, optimizer_name=optimizer, learning_rate=learning_rate, 
                     dropout_rate=dropout_rate, weight_decay=weight_decay, momentum=momentum, clip_norm=clip_norm)

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 20)             │        10,260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,081,460 (49.90 MB)
#  Trainable params: 13,072,628 (49.87 MB)
#  Non-trainable params: 8,832 (34.50 KB)

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import numpy as np

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = 1

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.test_loss = []
        self.test_accuracy = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        self.test_loss.append(test_loss)
        self.test_accuracy.append(test_accuracy)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_train_v1.csv"
test_log_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_test_v1.csv"
model_filepath_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.7_keras_v1.keras"

# Define callbacks
# early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1)

# Initialize test log file with header
with open(test_log_v1, 'w') as f:
    f.write("epoch,test_loss,test_accuracy\n")

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    epochs=350,
    batch_size=64,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Epoch 1/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0556 - loss: 3.9985
# Epoch 1: Test Loss: 3.082620859146118, Test Accuracy: 0.04931192845106125
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.0556 - loss: 3.9980 - epoch: 1.0000
# Epoch 2/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0566 - loss: 3.9214
# Epoch 2: Test Loss: 3.2138772010803223, Test Accuracy: 0.04816513881087303
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.0567 - loss: 3.9204 - epoch: 2.0000
# Epoch 3/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0827 - loss: 3.6428
# Epoch 3: Test Loss: 3.4237170219421387, Test Accuracy: 0.04816513881087303
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.0826 - loss: 3.6430 - epoch: 3.0000
# Epoch 4/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1015 - loss: 3.5258
# Epoch 4: Test Loss: 3.8447415828704834, Test Accuracy: 0.04816513881087303
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.1016 - loss: 3.5249 - epoch: 4.0000
# Epoch 5/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1411 - loss: 3.2679
# Epoch 5: Test Loss: 4.4913763999938965, Test Accuracy: 0.04013761505484581
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.1412 - loss: 3.2681 - epoch: 5.0000
# Epoch 6/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1720 - loss: 3.0386
# Epoch 6: Test Loss: 5.0684614181518555, Test Accuracy: 0.05045871436595917
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.1723 - loss: 3.0381 - epoch: 6.0000
# Epoch 7/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2017 - loss: 2.8666
# Epoch 7: Test Loss: 5.340062618255615, Test Accuracy: 0.0527522936463356
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.2021 - loss: 2.8651 - epoch: 7.0000
# Epoch 8/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2676 - loss: 2.6134
# Epoch 8: Test Loss: 5.686656475067139, Test Accuracy: 0.05045871436595917
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.2678 - loss: 2.6121 - epoch: 8.0000
# Epoch 9/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3226 - loss: 2.3791
# Epoch 9: Test Loss: 5.578205585479736, Test Accuracy: 0.0527522936463356
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3227 - loss: 2.3784 - epoch: 9.0000
# Epoch 10/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3742 - loss: 2.2174
# Epoch 10: Test Loss: 6.460092544555664, Test Accuracy: 0.06536697596311569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.3743 - loss: 2.2166 - epoch: 10.0000
# Epoch 11/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4024 - loss: 2.0969
# Epoch 11: Test Loss: 6.213073253631592, Test Accuracy: 0.07110092043876648
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.4027 - loss: 2.0954 - epoch: 11.0000
# Epoch 12/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4340 - loss: 1.9490
# Epoch 12: Test Loss: 6.361138343811035, Test Accuracy: 0.08830275386571884
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4341 - loss: 1.9482 - epoch: 12.0000
# Epoch 13/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4728 - loss: 1.7597
# Epoch 13: Test Loss: 5.9902448654174805, Test Accuracy: 0.09288990497589111
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4730 - loss: 1.7593 - epoch: 13.0000
# Epoch 14/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5044 - loss: 1.6020
# Epoch 14: Test Loss: 4.99612283706665, Test Accuracy: 0.10321100801229477
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.5046 - loss: 1.6018 - epoch: 14.0000
# Epoch 15/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5635 - loss: 1.4832
# Epoch 15: Test Loss: 4.232486724853516, Test Accuracy: 0.12155963480472565
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.5634 - loss: 1.4838 - epoch: 15.0000
# Epoch 16/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5711 - loss: 1.4204
# Epoch 16: Test Loss: 4.249142646789551, Test Accuracy: 0.12614679336547852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.5711 - loss: 1.4204 - epoch: 16.0000
# Epoch 17/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5773 - loss: 1.3870
# Epoch 17: Test Loss: 4.129650115966797, Test Accuracy: 0.15596330165863037
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.5774 - loss: 1.3864 - epoch: 17.0000
# Epoch 18/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6036 - loss: 1.2550
# Epoch 18: Test Loss: 3.8905863761901855, Test Accuracy: 0.16628439724445343
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6035 - loss: 1.2554 - epoch: 18.0000
# Epoch 19/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6234 - loss: 1.2388
# Epoch 19: Test Loss: 3.7365407943725586, Test Accuracy: 0.1834862381219864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6235 - loss: 1.2385 - epoch: 19.0000
# Epoch 20/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6287 - loss: 1.1848
# Epoch 20: Test Loss: 3.7634055614471436, Test Accuracy: 0.18922019004821777
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6289 - loss: 1.1845 - epoch: 20.0000
# Epoch 21/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6591 - loss: 1.0979
# Epoch 21: Test Loss: 3.4713258743286133, Test Accuracy: 0.2167431265115738
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6591 - loss: 1.0982 - epoch: 21.0000
# Epoch 22/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6784 - loss: 1.0440
# Epoch 22: Test Loss: 3.432518720626831, Test Accuracy: 0.22018349170684814
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6784 - loss: 1.0440 - epoch: 22.0000
# Epoch 23/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6788 - loss: 0.9994
# Epoch 23: Test Loss: 3.112844467163086, Test Accuracy: 0.2637614607810974
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6790 - loss: 0.9991 - epoch: 23.0000
# Epoch 24/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7222 - loss: 0.9198
# Epoch 24: Test Loss: 3.058777093887329, Test Accuracy: 0.2637614607810974
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7221 - loss: 0.9204 - epoch: 24.0000
# Epoch 25/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7066 - loss: 0.9444
# Epoch 25: Test Loss: 3.324096918106079, Test Accuracy: 0.2373853176832199
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7068 - loss: 0.9440 - epoch: 25.0000
# Epoch 26/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7108 - loss: 0.9108
# Epoch 26: Test Loss: 2.7920851707458496, Test Accuracy: 0.3107798099517822
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7109 - loss: 0.9104 - epoch: 26.0000
# Epoch 27/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7454 - loss: 0.8324
# Epoch 27: Test Loss: 2.6206870079040527, Test Accuracy: 0.3302752375602722
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7453 - loss: 0.8328 - epoch: 27.0000
# Epoch 28/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7494 - loss: 0.8251
# Epoch 28: Test Loss: 2.1646628379821777, Test Accuracy: 0.42316514253616333
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7494 - loss: 0.8252 - epoch: 28.0000
# Epoch 29/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7513 - loss: 0.7912
# Epoch 29: Test Loss: 2.238088369369507, Test Accuracy: 0.4013761579990387
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7514 - loss: 0.7911 - epoch: 29.0000
# Epoch 30/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7474 - loss: 0.7977
# Epoch 30: Test Loss: 2.472989797592163, Test Accuracy: 0.36467888951301575
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7476 - loss: 0.7972 - epoch: 30.0000
# Epoch 31/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7827 - loss: 0.6959
# Epoch 31: Test Loss: 1.8115297555923462, Test Accuracy: 0.5114678740501404
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7825 - loss: 0.6963 - epoch: 31.0000
# Epoch 32/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7716 - loss: 0.7170
# Epoch 32: Test Loss: 2.1858623027801514, Test Accuracy: 0.4334862530231476
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7717 - loss: 0.7165 - epoch: 32.0000
# Epoch 33/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7733 - loss: 0.6961
# Epoch 33: Test Loss: 2.118734836578369, Test Accuracy: 0.45183485746383667
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7736 - loss: 0.6957 - epoch: 33.0000
# Epoch 34/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7925 - loss: 0.6582
# Epoch 34: Test Loss: 2.313326358795166, Test Accuracy: 0.4013761579990387
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7924 - loss: 0.6582 - epoch: 34.0000
# Epoch 35/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7993 - loss: 0.6430
# Epoch 35: Test Loss: 1.96943998336792, Test Accuracy: 0.4667431116104126
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7993 - loss: 0.6430 - epoch: 35.0000
# Epoch 36/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8011 - loss: 0.6377
# Epoch 36: Test Loss: 1.9646159410476685, Test Accuracy: 0.4678899049758911
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8011 - loss: 0.6377 - epoch: 36.0000
# Epoch 37/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7972 - loss: 0.6298
# Epoch 37: Test Loss: 1.45801842212677, Test Accuracy: 0.5974770784378052
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.7973 - loss: 0.6294 - epoch: 37.0000
# Epoch 38/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8307 - loss: 0.5534
# Epoch 38: Test Loss: 1.7883446216583252, Test Accuracy: 0.5183486342430115
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8305 - loss: 0.5538 - epoch: 38.0000
# Epoch 39/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8220 - loss: 0.5796
# Epoch 39: Test Loss: 1.6849260330200195, Test Accuracy: 0.5458715558052063
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8220 - loss: 0.5795 - epoch: 39.0000
# Epoch 40/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8212 - loss: 0.5650
# Epoch 40: Test Loss: 1.876965045928955, Test Accuracy: 0.5034403800964355
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8212 - loss: 0.5650 - epoch: 40.0000
# Epoch 41/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8490 - loss: 0.5064
# Epoch 41: Test Loss: 1.5530314445495605, Test Accuracy: 0.5791284441947937
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8487 - loss: 0.5067 - epoch: 41.0000
# Epoch 42/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8327 - loss: 0.5270
# Epoch 42: Test Loss: 1.6145323514938354, Test Accuracy: 0.5665137767791748
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8326 - loss: 0.5272 - epoch: 42.0000
# Epoch 43/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8514 - loss: 0.4907
# Epoch 43: Test Loss: 2.0485711097717285, Test Accuracy: 0.4667431116104126
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8513 - loss: 0.4911 - epoch: 43.0000
# Epoch 44/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8354 - loss: 0.5066
# Epoch 44: Test Loss: 1.789185881614685, Test Accuracy: 0.5160550475120544
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8355 - loss: 0.5065 - epoch: 44.0000
# Epoch 45/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8529 - loss: 0.4846
# Epoch 45: Test Loss: 1.6453030109405518, Test Accuracy: 0.5596330165863037
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8528 - loss: 0.4848 - epoch: 45.0000
# Epoch 46/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8647 - loss: 0.4610
# Epoch 46: Test Loss: 1.893354058265686, Test Accuracy: 0.5103210806846619
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8646 - loss: 0.4611 - epoch: 46.0000
# Epoch 47/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8523 - loss: 0.4515
# Epoch 47: Test Loss: 1.3132612705230713, Test Accuracy: 0.6192660331726074
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8523 - loss: 0.4517 - epoch: 47.0000
# Epoch 48/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8621 - loss: 0.4490
# Epoch 48: Test Loss: 1.274725079536438, Test Accuracy: 0.6341742873191833
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8621 - loss: 0.4489 - epoch: 48.0000
# Epoch 49/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8661 - loss: 0.4460
# Epoch 49: Test Loss: 1.44130277633667, Test Accuracy: 0.5951834917068481
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8661 - loss: 0.4460 - epoch: 49.0000
# Epoch 50/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8659 - loss: 0.4352
# Epoch 50: Test Loss: 1.1229395866394043, Test Accuracy: 0.6766055226325989
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8659 - loss: 0.4352 - epoch: 50.0000
# Epoch 51/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8604 - loss: 0.4395
# Epoch 51: Test Loss: 1.4791756868362427, Test Accuracy: 0.5997706651687622
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8605 - loss: 0.4393 - epoch: 51.0000
# Epoch 52/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8794 - loss: 0.3971
# Epoch 52: Test Loss: 1.675357699394226, Test Accuracy: 0.5493119359016418
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8793 - loss: 0.3973 - epoch: 52.0000
# Epoch 53/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8750 - loss: 0.4012
# Epoch 53: Test Loss: 1.703641653060913, Test Accuracy: 0.5504587292671204
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8751 - loss: 0.4011 - epoch: 53.0000
# Epoch 54/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8861 - loss: 0.3644
# Epoch 54: Test Loss: 1.4149417877197266, Test Accuracy: 0.6135321259498596
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8860 - loss: 0.3648 - epoch: 54.0000
# Epoch 55/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.4062
# Epoch 55: Test Loss: 1.2353845834732056, Test Accuracy: 0.6513761281967163
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8732 - loss: 0.4060 - epoch: 55.0000
# Epoch 56/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8862 - loss: 0.3741
# Epoch 56: Test Loss: 1.310276985168457, Test Accuracy: 0.6341742873191833
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8862 - loss: 0.3741 - epoch: 56.0000
# Epoch 57/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8813 - loss: 0.3957
# Epoch 57: Test Loss: 1.1948753595352173, Test Accuracy: 0.6628440618515015
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8814 - loss: 0.3954 - epoch: 57.0000
# Epoch 58/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8797 - loss: 0.3703
# Epoch 58: Test Loss: 1.3952354192733765, Test Accuracy: 0.6204128265380859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8797 - loss: 0.3703 - epoch: 58.0000
# Epoch 59/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8947 - loss: 0.3502
# Epoch 59: Test Loss: 1.4049651622772217, Test Accuracy: 0.6330274939537048
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8945 - loss: 0.3503 - epoch: 59.0000
# Epoch 60/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8981 - loss: 0.3426
# Epoch 60: Test Loss: 0.9629712104797363, Test Accuracy: 0.7247706651687622
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8981 - loss: 0.3427 - epoch: 60.0000
# Epoch 61/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8890 - loss: 0.3525
# Epoch 61: Test Loss: 1.1520403623580933, Test Accuracy: 0.6777523159980774
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8889 - loss: 0.3526 - epoch: 61.0000
# Epoch 62/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8988 - loss: 0.3389
# Epoch 62: Test Loss: 1.0852090120315552, Test Accuracy: 0.6926605701446533
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8989 - loss: 0.3387 - epoch: 62.0000
# Epoch 63/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8923 - loss: 0.3525
# Epoch 63: Test Loss: 1.153272271156311, Test Accuracy: 0.6731651425361633
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8923 - loss: 0.3524 - epoch: 63.0000
# Epoch 64/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8963 - loss: 0.3279
# Epoch 64: Test Loss: 1.1386232376098633, Test Accuracy: 0.6674311757087708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8964 - loss: 0.3278 - epoch: 64.0000
# Epoch 65/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8926 - loss: 0.3287
# Epoch 65: Test Loss: 1.1908979415893555, Test Accuracy: 0.6628440618515015
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8928 - loss: 0.3286 - epoch: 65.0000
# Epoch 66/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9054 - loss: 0.3060
# Epoch 66: Test Loss: 1.0420719385147095, Test Accuracy: 0.6915137767791748
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9054 - loss: 0.3062 - epoch: 66.0000
# Epoch 67/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9101 - loss: 0.2964
# Epoch 67: Test Loss: 1.013486623764038, Test Accuracy: 0.7064220309257507
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9100 - loss: 0.2965 - epoch: 67.0000
# Epoch 68/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9006 - loss: 0.3126
# Epoch 68: Test Loss: 1.056577444076538, Test Accuracy: 0.6961008906364441
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9006 - loss: 0.3125 - epoch: 68.0000
# Epoch 69/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9039 - loss: 0.2984
# Epoch 69: Test Loss: 0.8467403054237366, Test Accuracy: 0.7568807601928711
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9039 - loss: 0.2986 - epoch: 69.0000
# Epoch 70/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9132 - loss: 0.2842
# Epoch 70: Test Loss: 1.2658352851867676, Test Accuracy: 0.6582568883895874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9131 - loss: 0.2844 - epoch: 70.0000
# Epoch 71/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9143 - loss: 0.2817
# Epoch 71: Test Loss: 0.9924180507659912, Test Accuracy: 0.7247706651687622
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9142 - loss: 0.2819 - epoch: 71.0000
# Epoch 72/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9093 - loss: 0.2991
# Epoch 72: Test Loss: 0.8909667134284973, Test Accuracy: 0.75
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9093 - loss: 0.2989 - epoch: 72.0000
# Epoch 73/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9202 - loss: 0.2702
# Epoch 73: Test Loss: 1.087162733078003, Test Accuracy: 0.7064220309257507
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9202 - loss: 0.2703 - epoch: 73.0000
# Epoch 74/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9240 - loss: 0.2494
# Epoch 74: Test Loss: 1.135985255241394, Test Accuracy: 0.6880733966827393
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9239 - loss: 0.2500 - epoch: 74.0000
# Epoch 75/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9189 - loss: 0.2691
# Epoch 75: Test Loss: 0.8778377175331116, Test Accuracy: 0.7488532066345215
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9190 - loss: 0.2691 - epoch: 75.0000
# Epoch 76/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9222 - loss: 0.2604
# Epoch 76: Test Loss: 0.8851154446601868, Test Accuracy: 0.7534403800964355
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9222 - loss: 0.2604 - epoch: 76.0000
# Epoch 77/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9147 - loss: 0.2736
# Epoch 77: Test Loss: 0.9291525483131409, Test Accuracy: 0.7316513657569885
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9147 - loss: 0.2734 - epoch: 77.0000
# Epoch 78/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9123 - loss: 0.2726
# Epoch 78: Test Loss: 0.882293701171875, Test Accuracy: 0.7408257126808167
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9125 - loss: 0.2723 - epoch: 78.0000
# Epoch 79/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9205 - loss: 0.2578
# Epoch 79: Test Loss: 0.8727059364318848, Test Accuracy: 0.7454128265380859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9206 - loss: 0.2576 - epoch: 79.0000
# Epoch 80/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9216 - loss: 0.2637
# Epoch 80: Test Loss: 1.1460723876953125, Test Accuracy: 0.6823394298553467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9216 - loss: 0.2635 - epoch: 80.0000
# Epoch 81/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9212 - loss: 0.2551
# Epoch 81: Test Loss: 1.0223463773727417, Test Accuracy: 0.7144495248794556
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9212 - loss: 0.2551 - epoch: 81.0000
# Epoch 82/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9295 - loss: 0.2318
# Epoch 82: Test Loss: 0.9636126160621643, Test Accuracy: 0.73050457239151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9294 - loss: 0.2320 - epoch: 82.0000
# Epoch 83/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9267 - loss: 0.2345
# Epoch 83: Test Loss: 0.9025336503982544, Test Accuracy: 0.7442660331726074
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9267 - loss: 0.2347 - epoch: 83.0000
# Epoch 84/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9270 - loss: 0.2214
# Epoch 84: Test Loss: 0.8177770376205444, Test Accuracy: 0.7752293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9271 - loss: 0.2215 - epoch: 84.0000
# Epoch 85/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9224 - loss: 0.2412
# Epoch 85: Test Loss: 0.8406817317008972, Test Accuracy: 0.76949542760849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9223 - loss: 0.2415 - epoch: 85.0000
# Epoch 86/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9340 - loss: 0.2324
# Epoch 86: Test Loss: 0.9882864952087402, Test Accuracy: 0.7224770784378052
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9340 - loss: 0.2325 - epoch: 86.0000
# Epoch 87/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9341 - loss: 0.2133
# Epoch 87: Test Loss: 1.1087045669555664, Test Accuracy: 0.6938073635101318
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9340 - loss: 0.2135 - epoch: 87.0000
# Epoch 88/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9298 - loss: 0.2246
# Epoch 88: Test Loss: 0.8910595774650574, Test Accuracy: 0.7442660331726074
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9299 - loss: 0.2245 - epoch: 88.0000
# Epoch 89/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9411 - loss: 0.1947
# Epoch 89: Test Loss: 0.976738691329956, Test Accuracy: 0.7270641922950745
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9410 - loss: 0.1950 - epoch: 89.0000
# Epoch 90/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9347 - loss: 0.2216
# Epoch 90: Test Loss: 0.8010378479957581, Test Accuracy: 0.7844036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9346 - loss: 0.2216 - epoch: 90.0000
# Epoch 91/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9337 - loss: 0.2167
# Epoch 91: Test Loss: 0.7692538499832153, Test Accuracy: 0.786697268486023
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9337 - loss: 0.2167 - epoch: 91.0000
# Epoch 92/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9277 - loss: 0.2111
# Epoch 92: Test Loss: 0.822453498840332, Test Accuracy: 0.7809633016586304
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9279 - loss: 0.2111 - epoch: 92.0000
# Epoch 93/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9394 - loss: 0.1922
# Epoch 93: Test Loss: 0.9177796244621277, Test Accuracy: 0.75
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9393 - loss: 0.1924 - epoch: 93.0000
# Epoch 94/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9362 - loss: 0.1970
# Epoch 94: Test Loss: 0.7152329683303833, Test Accuracy: 0.7935779690742493
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9362 - loss: 0.1972 - epoch: 94.0000
# Epoch 95/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9428 - loss: 0.1824
# Epoch 95: Test Loss: 0.8275541067123413, Test Accuracy: 0.7683486342430115
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9428 - loss: 0.1827 - epoch: 95.0000
# Epoch 96/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9420 - loss: 0.1971
# Epoch 96: Test Loss: 0.7107948064804077, Test Accuracy: 0.8061926364898682
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9420 - loss: 0.1971 - epoch: 96.0000
# Epoch 97/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9375 - loss: 0.1992
# Epoch 97: Test Loss: 0.889938235282898, Test Accuracy: 0.7580274939537048
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9375 - loss: 0.1991 - epoch: 97.0000
# Epoch 98/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9370 - loss: 0.1992
# Epoch 98: Test Loss: 0.8808974623680115, Test Accuracy: 0.7557339668273926
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9370 - loss: 0.1992 - epoch: 98.0000
# Epoch 99/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9376 - loss: 0.1960
# Epoch 99: Test Loss: 0.8133196234703064, Test Accuracy: 0.7775229215621948
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9375 - loss: 0.1960 - epoch: 99.0000
# Epoch 100/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9492 - loss: 0.1803
# Epoch 100: Test Loss: 0.8215569257736206, Test Accuracy: 0.7729358077049255
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9492 - loss: 0.1802 - epoch: 100.0000
# Epoch 101/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9355 - loss: 0.1893
# Epoch 101: Test Loss: 0.6929236054420471, Test Accuracy: 0.8016055226325989
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9354 - loss: 0.1894 - epoch: 101.0000
# Epoch 102/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9441 - loss: 0.1875
# Epoch 102: Test Loss: 0.709308385848999, Test Accuracy: 0.8016055226325989
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9441 - loss: 0.1874 - epoch: 102.0000
# Epoch 103/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9475 - loss: 0.1811
# Epoch 103: Test Loss: 0.8514331579208374, Test Accuracy: 0.7614678740501404
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9476 - loss: 0.1810 - epoch: 103.0000
# Epoch 104/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9410 - loss: 0.1833
# Epoch 104: Test Loss: 0.7837265729904175, Test Accuracy: 0.7775229215621948
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9409 - loss: 0.1835 - epoch: 104.0000
# Epoch 105/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9480 - loss: 0.1688
# Epoch 105: Test Loss: 0.9152342677116394, Test Accuracy: 0.747706413269043
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9480 - loss: 0.1688 - epoch: 105.0000
# Epoch 106/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9433 - loss: 0.1799
# Epoch 106: Test Loss: 0.7326334118843079, Test Accuracy: 0.8061926364898682
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9434 - loss: 0.1799 - epoch: 106.0000
# Epoch 107/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9496 - loss: 0.1523
# Epoch 107: Test Loss: 0.6916990876197815, Test Accuracy: 0.8119266033172607
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9496 - loss: 0.1523 - epoch: 107.0000
# Epoch 108/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9509 - loss: 0.1609
# Epoch 108: Test Loss: 0.685863196849823, Test Accuracy: 0.8130733966827393
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9509 - loss: 0.1609 - epoch: 108.0000
# Epoch 109/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9493 - loss: 0.1724
# Epoch 109: Test Loss: 0.713398277759552, Test Accuracy: 0.8050458431243896
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9493 - loss: 0.1722 - epoch: 109.0000
# Epoch 110/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9540 - loss: 0.1663
# Epoch 110: Test Loss: 0.7455816864967346, Test Accuracy: 0.786697268486023
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9540 - loss: 0.1662 - epoch: 110.0000
# Epoch 111/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9486 - loss: 0.1725
# Epoch 111: Test Loss: 0.6858943104743958, Test Accuracy: 0.8130733966827393
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9485 - loss: 0.1724 - epoch: 111.0000
# Epoch 112/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9600 - loss: 0.1391
# Epoch 112: Test Loss: 0.8971666693687439, Test Accuracy: 0.7545871734619141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9599 - loss: 0.1393 - epoch: 112.0000
# Epoch 113/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9442 - loss: 0.1705
# Epoch 113: Test Loss: 0.8341373205184937, Test Accuracy: 0.7740825414657593
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9443 - loss: 0.1704 - epoch: 113.0000
# Epoch 114/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9566 - loss: 0.1497
# Epoch 114: Test Loss: 0.7847088575363159, Test Accuracy: 0.7855504751205444
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9566 - loss: 0.1498 - epoch: 114.0000
# Epoch 115/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9532 - loss: 0.1482
# Epoch 115: Test Loss: 0.719977080821991, Test Accuracy: 0.8016055226325989
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9532 - loss: 0.1482 - epoch: 115.0000
# Epoch 116/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9555 - loss: 0.1457
# Epoch 116: Test Loss: 0.7288807034492493, Test Accuracy: 0.8004587292671204
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9555 - loss: 0.1457 - epoch: 116.0000
# Epoch 117/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9577 - loss: 0.1462
# Epoch 117: Test Loss: 0.7215089797973633, Test Accuracy: 0.7993119359016418
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9576 - loss: 0.1463 - epoch: 117.0000
# Epoch 118/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9545 - loss: 0.1500
# Epoch 118: Test Loss: 0.7369071841239929, Test Accuracy: 0.7981651425361633
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9544 - loss: 0.1501 - epoch: 118.0000
# Epoch 119/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9566 - loss: 0.1485
# Epoch 119: Test Loss: 0.583203911781311, Test Accuracy: 0.8337156176567078
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9566 - loss: 0.1487 - epoch: 119.0000
# Epoch 120/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9468 - loss: 0.1679
# Epoch 120: Test Loss: 0.5299456715583801, Test Accuracy: 0.8451834917068481
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9469 - loss: 0.1676 - epoch: 120.0000
# Epoch 121/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.1401
# Epoch 121: Test Loss: 0.6965574622154236, Test Accuracy: 0.8130733966827393
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9606 - loss: 0.1402 - epoch: 121.0000
# Epoch 122/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9549 - loss: 0.1537
# Epoch 122: Test Loss: 0.595763623714447, Test Accuracy: 0.83600914478302
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9550 - loss: 0.1536 - epoch: 122.0000
# Epoch 123/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9608 - loss: 0.1515
# Epoch 123: Test Loss: 0.724217414855957, Test Accuracy: 0.7970183491706848
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9607 - loss: 0.1514 - epoch: 123.0000
# Epoch 124/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9628 - loss: 0.1441
# Epoch 124: Test Loss: 0.6606110334396362, Test Accuracy: 0.8211008906364441
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9628 - loss: 0.1440 - epoch: 124.0000
# Epoch 125/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9549 - loss: 0.1518
# Epoch 125: Test Loss: 0.6898359656333923, Test Accuracy: 0.8061926364898682
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9550 - loss: 0.1516 - epoch: 125.0000
# Epoch 126/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9581 - loss: 0.1393
# Epoch 126: Test Loss: 0.7051082253456116, Test Accuracy: 0.8084862232208252
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9581 - loss: 0.1391 - epoch: 126.0000
# Epoch 127/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9522 - loss: 0.1458
# Epoch 127: Test Loss: 0.673255443572998, Test Accuracy: 0.8176605701446533
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9523 - loss: 0.1457 - epoch: 127.0000
# Epoch 128/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9596 - loss: 0.1373
# Epoch 128: Test Loss: 0.6035488247871399, Test Accuracy: 0.8337156176567078
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9596 - loss: 0.1373 - epoch: 128.0000
# Epoch 129/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9533 - loss: 0.1475
# Epoch 129: Test Loss: 0.6702828407287598, Test Accuracy: 0.8107798099517822
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9534 - loss: 0.1474 - epoch: 129.0000
# Epoch 130/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9615 - loss: 0.1270
# Epoch 130: Test Loss: 0.6165062189102173, Test Accuracy: 0.8291284441947937
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9615 - loss: 0.1271 - epoch: 130.0000
# Epoch 131/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9717 - loss: 0.1132
# Epoch 131: Test Loss: 0.5883172154426575, Test Accuracy: 0.8337156176567078
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9716 - loss: 0.1135 - epoch: 131.0000
# Epoch 132/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9659 - loss: 0.1264
# Epoch 132: Test Loss: 0.6101034879684448, Test Accuracy: 0.8291284441947937
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9659 - loss: 0.1264 - epoch: 132.0000
# Epoch 133/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9616 - loss: 0.1226
# Epoch 133: Test Loss: 0.6127235293388367, Test Accuracy: 0.8302752375602722
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9615 - loss: 0.1227 - epoch: 133.0000
# Epoch 134/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9644 - loss: 0.1193
# Epoch 134: Test Loss: 0.6163151860237122, Test Accuracy: 0.8256880640983582
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9643 - loss: 0.1194 - epoch: 134.0000
# Epoch 135/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9641 - loss: 0.1215
# Epoch 135: Test Loss: 0.593076765537262, Test Accuracy: 0.8302752375602722
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9641 - loss: 0.1215 - epoch: 135.0000
# Epoch 136/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9689 - loss: 0.1216
# Epoch 136: Test Loss: 0.5786226987838745, Test Accuracy: 0.83600914478302
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9689 - loss: 0.1216 - epoch: 136.0000
# Epoch 137/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.1303
# Epoch 137: Test Loss: 0.6474412083625793, Test Accuracy: 0.8199541568756104
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9607 - loss: 0.1303 - epoch: 137.0000
# Epoch 138/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9662 - loss: 0.1244
# Epoch 138: Test Loss: 0.6246033310890198, Test Accuracy: 0.8222476840019226
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9662 - loss: 0.1244 - epoch: 138.0000
# Epoch 139/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9627 - loss: 0.1332
# Epoch 139: Test Loss: 0.6996741890907288, Test Accuracy: 0.8107798099517822
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9628 - loss: 0.1329 - epoch: 139.0000
# Epoch 140/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9677 - loss: 0.1106
# Epoch 140: Test Loss: 0.5270817875862122, Test Accuracy: 0.8600917458534241
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9677 - loss: 0.1107 - epoch: 140.0000
# Epoch 141/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9641 - loss: 0.1182
# Epoch 141: Test Loss: 0.5568526983261108, Test Accuracy: 0.8451834917068481
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9641 - loss: 0.1182 - epoch: 141.0000
# Epoch 142/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9673 - loss: 0.1146
# Epoch 142: Test Loss: 0.5406366586685181, Test Accuracy: 0.8520641922950745
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9672 - loss: 0.1147 - epoch: 142.0000
# Epoch 143/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9609 - loss: 0.1222
# Epoch 143: Test Loss: 0.5567460656166077, Test Accuracy: 0.8440366983413696
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9609 - loss: 0.1222 - epoch: 143.0000
# Epoch 144/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9687 - loss: 0.1148
# Epoch 144: Test Loss: 0.6024200916290283, Test Accuracy: 0.8348624110221863
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9686 - loss: 0.1149 - epoch: 144.0000
# Epoch 145/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9717 - loss: 0.1050
# Epoch 145: Test Loss: 0.7181885838508606, Test Accuracy: 0.8073394298553467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9716 - loss: 0.1051 - epoch: 145.0000
# Epoch 146/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9682 - loss: 0.1121
# Epoch 146: Test Loss: 0.5487508773803711, Test Accuracy: 0.8543577790260315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9682 - loss: 0.1121 - epoch: 146.0000
# Epoch 147/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9636 - loss: 0.1216
# Epoch 147: Test Loss: 0.6525821089744568, Test Accuracy: 0.8211008906364441
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9637 - loss: 0.1215 - epoch: 147.0000
# Epoch 148/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9673 - loss: 0.1147
# Epoch 148: Test Loss: 0.5830583572387695, Test Accuracy: 0.8440366983413696
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9673 - loss: 0.1146 - epoch: 148.0000
# Epoch 149/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9678 - loss: 0.1032
# Epoch 149: Test Loss: 0.5338989496231079, Test Accuracy: 0.8520641922950745
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9677 - loss: 0.1033 - epoch: 149.0000
# Epoch 150/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9702 - loss: 0.1083
# Epoch 150: Test Loss: 0.6410768628120422, Test Accuracy: 0.8188073635101318
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9702 - loss: 0.1082 - epoch: 150.0000
# Epoch 151/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9592 - loss: 0.1262
# Epoch 151: Test Loss: 0.5709307193756104, Test Accuracy: 0.8463302850723267
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9594 - loss: 0.1259 - epoch: 151.0000
# Epoch 152/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9734 - loss: 0.0965
# Epoch 152: Test Loss: 0.570392370223999, Test Accuracy: 0.8486238718032837
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9732 - loss: 0.0969 - epoch: 152.0000
# Epoch 153/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9727 - loss: 0.1103
# Epoch 153: Test Loss: 0.6289284229278564, Test Accuracy: 0.8245412707328796
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9726 - loss: 0.1103 - epoch: 153.0000
# Epoch 154/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9671 - loss: 0.1049
# Epoch 154: Test Loss: 0.6397756338119507, Test Accuracy: 0.8222476840019226
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9671 - loss: 0.1049 - epoch: 154.0000
# Epoch 155/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9716 - loss: 0.1037
# Epoch 155: Test Loss: 0.4813080132007599, Test Accuracy: 0.8658257126808167
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9715 - loss: 0.1037 - epoch: 155.0000
# Epoch 156/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9735 - loss: 0.0892
# Epoch 156: Test Loss: 0.5098943114280701, Test Accuracy: 0.8612385392189026
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9734 - loss: 0.0894 - epoch: 156.0000
# Epoch 157/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9744 - loss: 0.0973
# Epoch 157: Test Loss: 0.5306178331375122, Test Accuracy: 0.8566513657569885
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9743 - loss: 0.0974 - epoch: 157.0000
# Epoch 158/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9674 - loss: 0.1090
# Epoch 158: Test Loss: 0.6018869280815125, Test Accuracy: 0.8314220309257507
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9675 - loss: 0.1089 - epoch: 158.0000
# Epoch 159/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9712 - loss: 0.0985
# Epoch 159: Test Loss: 0.5562825798988342, Test Accuracy: 0.8474770784378052
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9712 - loss: 0.0984 - epoch: 159.0000
# Epoch 160/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9715 - loss: 0.0910
# Epoch 160: Test Loss: 0.5793430209159851, Test Accuracy: 0.838302731513977
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9715 - loss: 0.0911 - epoch: 160.0000
# Epoch 161/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9657 - loss: 0.1069
# Epoch 161: Test Loss: 0.5468807816505432, Test Accuracy: 0.8543577790260315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9658 - loss: 0.1068 - epoch: 161.0000
# Epoch 162/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9712 - loss: 0.1009
# Epoch 162: Test Loss: 0.5337667465209961, Test Accuracy: 0.8623853325843811
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9712 - loss: 0.1009 - epoch: 162.0000
# Epoch 163/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9734 - loss: 0.0925
# Epoch 163: Test Loss: 0.5781088471412659, Test Accuracy: 0.8428899049758911
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9735 - loss: 0.0924 - epoch: 163.0000
# Epoch 164/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9747 - loss: 0.0922
# Epoch 164: Test Loss: 0.545545220375061, Test Accuracy: 0.8543577790260315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9747 - loss: 0.0922 - epoch: 164.0000
# Epoch 165/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9628 - loss: 0.1055
# Epoch 165: Test Loss: 0.48563072085380554, Test Accuracy: 0.8715596199035645
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9630 - loss: 0.1054 - epoch: 165.0000
# Epoch 166/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9726 - loss: 0.0994
# Epoch 166: Test Loss: 0.5098361372947693, Test Accuracy: 0.8681192398071289
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9726 - loss: 0.0994 - epoch: 166.0000
# Epoch 167/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9719 - loss: 0.0953
# Epoch 167: Test Loss: 0.5645079016685486, Test Accuracy: 0.8451834917068481
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9718 - loss: 0.0953 - epoch: 167.0000
# Epoch 168/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9683 - loss: 0.1002
# Epoch 168: Test Loss: 0.5486472845077515, Test Accuracy: 0.8543577790260315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9684 - loss: 0.1000 - epoch: 168.0000
# Epoch 169/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9722 - loss: 0.0995
# Epoch 169: Test Loss: 0.5067310929298401, Test Accuracy: 0.8623853325843811
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9722 - loss: 0.0995 - epoch: 169.0000
# Epoch 170/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9686 - loss: 0.0999
# Epoch 170: Test Loss: 0.44400593638420105, Test Accuracy: 0.8807339668273926
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9687 - loss: 0.0998 - epoch: 170.0000
# Epoch 171/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9720 - loss: 0.0897
# Epoch 171: Test Loss: 0.4896150231361389, Test Accuracy: 0.8715596199035645
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9720 - loss: 0.0897 - epoch: 171.0000
# Epoch 172/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9723 - loss: 0.0910
# Epoch 172: Test Loss: 0.49698203802108765, Test Accuracy: 0.872706413269043
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9723 - loss: 0.0910 - epoch: 172.0000
# Epoch 173/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9769 - loss: 0.0772
# Epoch 173: Test Loss: 0.5878883004188538, Test Accuracy: 0.8394495248794556
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9769 - loss: 0.0773 - epoch: 173.0000
# Epoch 174/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9776 - loss: 0.0807
# Epoch 174: Test Loss: 0.5441953539848328, Test Accuracy: 0.8486238718032837
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9775 - loss: 0.0808 - epoch: 174.0000
# Epoch 175/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9781 - loss: 0.0820
# Epoch 175: Test Loss: 0.5206143856048584, Test Accuracy: 0.8623853325843811
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9781 - loss: 0.0821 - epoch: 175.0000
# Epoch 176/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9803 - loss: 0.0815
# Epoch 176: Test Loss: 0.5607612133026123, Test Accuracy: 0.8486238718032837
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9803 - loss: 0.0816 - epoch: 176.0000
# Epoch 177/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 0.0847
# Epoch 177: Test Loss: 0.45265498757362366, Test Accuracy: 0.8818807601928711
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9754 - loss: 0.0849 - epoch: 177.0000
# Epoch 178/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9724 - loss: 0.0903
# Epoch 178: Test Loss: 0.4828667640686035, Test Accuracy: 0.8715596199035645
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9724 - loss: 0.0903 - epoch: 178.0000
# Epoch 179/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9804 - loss: 0.0741
# Epoch 179: Test Loss: 0.5012707710266113, Test Accuracy: 0.8669725060462952
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9804 - loss: 0.0742 - epoch: 179.0000
# Epoch 180/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9775 - loss: 0.0807
# Epoch 180: Test Loss: 0.5350523591041565, Test Accuracy: 0.85550457239151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9775 - loss: 0.0807 - epoch: 180.0000
# Epoch 181/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9736 - loss: 0.0906
# Epoch 181: Test Loss: 0.4849641025066376, Test Accuracy: 0.8715596199035645
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9736 - loss: 0.0905 - epoch: 181.0000
# Epoch 182/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9793 - loss: 0.0763
# Epoch 182: Test Loss: 0.5364103317260742, Test Accuracy: 0.8566513657569885
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9792 - loss: 0.0764 - epoch: 182.0000
# Epoch 183/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9797 - loss: 0.0726
# Epoch 183: Test Loss: 0.5144296884536743, Test Accuracy: 0.8692660331726074
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9797 - loss: 0.0727 - epoch: 183.0000
# Epoch 184/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9736 - loss: 0.0877
# Epoch 184: Test Loss: 0.5204443335533142, Test Accuracy: 0.8669725060462952
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9736 - loss: 0.0876 - epoch: 184.0000
# Epoch 185/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9799 - loss: 0.0751
# Epoch 185: Test Loss: 0.5332044959068298, Test Accuracy: 0.8600917458534241
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9799 - loss: 0.0751 - epoch: 185.0000
# Epoch 186/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9794 - loss: 0.0766
# Epoch 186: Test Loss: 0.5056268572807312, Test Accuracy: 0.8681192398071289
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9794 - loss: 0.0766 - epoch: 186.0000
# Epoch 187/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9780 - loss: 0.0761
# Epoch 187: Test Loss: 0.5243011116981506, Test Accuracy: 0.8658257126808167
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9780 - loss: 0.0761 - epoch: 187.0000
# Epoch 188/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9832 - loss: 0.0681
# Epoch 188: Test Loss: 0.5041459798812866, Test Accuracy: 0.8681192398071289
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9832 - loss: 0.0682 - epoch: 188.0000
# Epoch 189/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9751 - loss: 0.0753
# Epoch 189: Test Loss: 0.5014046430587769, Test Accuracy: 0.8646789193153381
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9751 - loss: 0.0755 - epoch: 189.0000
# Epoch 190/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9756 - loss: 0.0810
# Epoch 190: Test Loss: 0.47136110067367554, Test Accuracy: 0.875
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9756 - loss: 0.0808 - epoch: 190.0000
# Epoch 191/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9772 - loss: 0.0820
# Epoch 191: Test Loss: 0.4645334780216217, Test Accuracy: 0.8784403800964355
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9772 - loss: 0.0819 - epoch: 191.0000
# Epoch 192/350
# ...
# Epoch 288/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9896 - loss: 0.0408
# Epoch 288: Test Loss: 0.39624398946762085, Test Accuracy: 0.8979358077049255
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9896 - loss: 0.0408 - epoch: 288.0000
# Epoch 289/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.0459
# Epoch 289: Test Loss: 0.3980036973953247, Test Accuracy: 0.8979358077049255
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9879 - loss: 0.0458 - epoch: 289.0000
# Epoch 290/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.0533
# Epoch 290: Test Loss: 0.41477108001708984, Test Accuracy: 0.8933486342430115
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9885 - loss: 0.0531 - epoch: 290.0000
# Epoch 291/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9878 - loss: 0.0435
# Epoch 291: Test Loss: 0.4180460274219513, Test Accuracy: 0.8876146674156189
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9878 - loss: 0.0435 - epoch: 291.0000
# Epoch 292/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0342
# Epoch 292: Test Loss: 0.4081384241580963, Test Accuracy: 0.8899082541465759
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9916 - loss: 0.0343 - epoch: 292.0000
# Epoch 293/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9914 - loss: 0.0345
# Epoch 293: Test Loss: 0.4165215790271759, Test Accuracy: 0.8864678740501404
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9914 - loss: 0.0345 - epoch: 293.0000
# Epoch 294/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0379
# Epoch 294: Test Loss: 0.38380956649780273, Test Accuracy: 0.9048165082931519
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9933 - loss: 0.0379 - epoch: 294.0000
# Epoch 295/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9883 - loss: 0.0420
# Epoch 295: Test Loss: 0.36829420924186707, Test Accuracy: 0.9094036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9883 - loss: 0.0419 - epoch: 295.0000
# Epoch 296/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9908 - loss: 0.0345
# Epoch 296: Test Loss: 0.3715342879295349, Test Accuracy: 0.9094036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9907 - loss: 0.0346 - epoch: 296.0000
# Epoch 297/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0391
# Epoch 297: Test Loss: 0.3880250155925751, Test Accuracy: 0.9025229215621948
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9909 - loss: 0.0391 - epoch: 297.0000
# Epoch 298/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 0.0353
# Epoch 298: Test Loss: 0.40036919713020325, Test Accuracy: 0.896789014339447
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9907 - loss: 0.0353 - epoch: 298.0000
# Epoch 299/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0355
# Epoch 299: Test Loss: 0.425744891166687, Test Accuracy: 0.8887614607810974
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9912 - loss: 0.0355 - epoch: 299.0000
# Epoch 300/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9897 - loss: 0.0376
# Epoch 300: Test Loss: 0.43247127532958984, Test Accuracy: 0.8910550475120544
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9897 - loss: 0.0376 - epoch: 300.0000
# Epoch 301/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - loss: 0.0356
# Epoch 301: Test Loss: 0.40363195538520813, Test Accuracy: 0.896789014339447
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9935 - loss: 0.0357 - epoch: 301.0000
# Epoch 302/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0388
# Epoch 302: Test Loss: 0.39771175384521484, Test Accuracy: 0.9048165082931519
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9904 - loss: 0.0388 - epoch: 302.0000
# Epoch 303/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9901 - loss: 0.0372
# Epoch 303: Test Loss: 0.41983917355537415, Test Accuracy: 0.89449542760849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9901 - loss: 0.0372 - epoch: 303.0000
# Epoch 304/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 0.0377
# Epoch 304: Test Loss: 0.43205782771110535, Test Accuracy: 0.8910550475120544
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9898 - loss: 0.0377 - epoch: 304.0000
# Epoch 305/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9883 - loss: 0.0396
# Epoch 305: Test Loss: 0.4089897572994232, Test Accuracy: 0.8956422209739685
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9883 - loss: 0.0396 - epoch: 305.0000
# Epoch 306/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0350
# Epoch 306: Test Loss: 0.4055398404598236, Test Accuracy: 0.896789014339447
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9922 - loss: 0.0350 - epoch: 306.0000
# Epoch 307/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0450
# Epoch 307: Test Loss: 0.41390153765678406, Test Accuracy: 0.8979358077049255
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9911 - loss: 0.0449 - epoch: 307.0000
# Epoch 308/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0324
# Epoch 308: Test Loss: 0.36868661642074585, Test Accuracy: 0.91399085521698
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9925 - loss: 0.0325 - epoch: 308.0000
# Epoch 309/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0437
# Epoch 309: Test Loss: 0.412756085395813, Test Accuracy: 0.9002293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9913 - loss: 0.0436 - epoch: 309.0000
# Epoch 310/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9937 - loss: 0.0333
# Epoch 310: Test Loss: 0.39682167768478394, Test Accuracy: 0.9002293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9937 - loss: 0.0333 - epoch: 310.0000
# Epoch 311/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.0304
# Epoch 311: Test Loss: 0.3947898745536804, Test Accuracy: 0.9013761281967163
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9928 - loss: 0.0304 - epoch: 311.0000
# Epoch 312/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0355
# Epoch 312: Test Loss: 0.4257008135318756, Test Accuracy: 0.89449542760849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9920 - loss: 0.0355 - epoch: 312.0000
# Epoch 313/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0342
# Epoch 313: Test Loss: 0.41932153701782227, Test Accuracy: 0.8956422209739685
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9920 - loss: 0.0342 - epoch: 313.0000
# Epoch 314/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9867 - loss: 0.0487
# Epoch 314: Test Loss: 0.397582083940506, Test Accuracy: 0.9036697149276733
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9867 - loss: 0.0485 - epoch: 314.0000
# Epoch 315/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0388
# Epoch 315: Test Loss: 0.3855496048927307, Test Accuracy: 0.9048165082931519
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9887 - loss: 0.0388 - epoch: 315.0000
# Epoch 316/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9938 - loss: 0.0301
# Epoch 316: Test Loss: 0.39484643936157227, Test Accuracy: 0.9025229215621948
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9938 - loss: 0.0301 - epoch: 316.0000
# Epoch 317/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9883 - loss: 0.0409
# Epoch 317: Test Loss: 0.4001239836215973, Test Accuracy: 0.9025229215621948
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9883 - loss: 0.0409 - epoch: 317.0000
# Epoch 318/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9913 - loss: 0.0362
# Epoch 318: Test Loss: 0.37658122181892395, Test Accuracy: 0.9071100950241089
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9913 - loss: 0.0362 - epoch: 318.0000
# Epoch 319/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - loss: 0.0312
# Epoch 319: Test Loss: 0.3759627342224121, Test Accuracy: 0.9059633016586304
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9934 - loss: 0.0313 - epoch: 319.0000
# Epoch 320/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0406
# Epoch 320: Test Loss: 0.35294073820114136, Test Accuracy: 0.9162843823432922
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9893 - loss: 0.0406 - epoch: 320.0000
# Epoch 321/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0375
# Epoch 321: Test Loss: 0.3618651330471039, Test Accuracy: 0.9151375889778137
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9915 - loss: 0.0375 - epoch: 321.0000
# Epoch 322/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0383
# Epoch 322: Test Loss: 0.3799547255039215, Test Accuracy: 0.9105504751205444
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9912 - loss: 0.0383 - epoch: 322.0000
# Epoch 323/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9884 - loss: 0.0394
# Epoch 323: Test Loss: 0.39608559012413025, Test Accuracy: 0.9036697149276733
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9884 - loss: 0.0394 - epoch: 323.0000
# Epoch 324/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0368
# Epoch 324: Test Loss: 0.4552026689052582, Test Accuracy: 0.8887614607810974
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9893 - loss: 0.0367 - epoch: 324.0000
# Epoch 325/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0418
# Epoch 325: Test Loss: 0.4285617470741272, Test Accuracy: 0.8990825414657593
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9921 - loss: 0.0417 - epoch: 325.0000
# Epoch 326/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0300
# Epoch 326: Test Loss: 0.3912878930568695, Test Accuracy: 0.9048165082931519
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9924 - loss: 0.0300 - epoch: 326.0000
# Epoch 327/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9936 - loss: 0.0266
# Epoch 327: Test Loss: 0.3617902994155884, Test Accuracy: 0.9128440618515015
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9936 - loss: 0.0267 - epoch: 327.0000
# Epoch 328/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9864 - loss: 0.0430
# Epoch 328: Test Loss: 0.39287641644477844, Test Accuracy: 0.9082568883895874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9864 - loss: 0.0429 - epoch: 328.0000
# Epoch 329/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0335
# Epoch 329: Test Loss: 0.3860434293746948, Test Accuracy: 0.9071100950241089
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9922 - loss: 0.0334 - epoch: 329.0000
# Epoch 330/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9953 - loss: 0.0266
# Epoch 330: Test Loss: 0.3831692337989807, Test Accuracy: 0.9094036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9953 - loss: 0.0267 - epoch: 330.0000
# Epoch 331/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - loss: 0.0328
# Epoch 331: Test Loss: 0.42508476972579956, Test Accuracy: 0.8933486342430115
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9935 - loss: 0.0327 - epoch: 331.0000
# Epoch 332/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0343
# Epoch 332: Test Loss: 0.423691064119339, Test Accuracy: 0.8933486342430115
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9923 - loss: 0.0343 - epoch: 332.0000
# Epoch 333/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.0303
# Epoch 333: Test Loss: 0.38010603189468384, Test Accuracy: 0.9105504751205444
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9951 - loss: 0.0303 - epoch: 333.0000
# Epoch 334/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9916 - loss: 0.0312
# Epoch 334: Test Loss: 0.38820090889930725, Test Accuracy: 0.9094036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9916 - loss: 0.0313 - epoch: 334.0000
# Epoch 335/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9941 - loss: 0.0290
# Epoch 335: Test Loss: 0.3791349530220032, Test Accuracy: 0.9128440618515015
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9940 - loss: 0.0290 - epoch: 335.0000
# Epoch 336/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0373
# Epoch 336: Test Loss: 0.39956316351890564, Test Accuracy: 0.9013761281967163
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9917 - loss: 0.0373 - epoch: 336.0000
# Epoch 337/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9938 - loss: 0.0276
# Epoch 337: Test Loss: 0.38034695386886597, Test Accuracy: 0.9071100950241089
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9938 - loss: 0.0276 - epoch: 337.0000
# Epoch 338/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9910 - loss: 0.0322
# Epoch 338: Test Loss: 0.38677430152893066, Test Accuracy: 0.9071100950241089
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9910 - loss: 0.0322 - epoch: 338.0000
# Epoch 339/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0278
# Epoch 339: Test Loss: 0.40557608008384705, Test Accuracy: 0.9002293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9945 - loss: 0.0278 - epoch: 339.0000
# Epoch 340/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0349
# Epoch 340: Test Loss: 0.39352330565452576, Test Accuracy: 0.9002293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9925 - loss: 0.0349 - epoch: 340.0000
# Epoch 341/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.0303
# Epoch 341: Test Loss: 0.3973711431026459, Test Accuracy: 0.9036697149276733
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9945 - loss: 0.0303 - epoch: 341.0000
# Epoch 342/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9917 - loss: 0.0339
# Epoch 342: Test Loss: 0.412005752325058, Test Accuracy: 0.896789014339447
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9917 - loss: 0.0339 - epoch: 342.0000
# Epoch 343/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9919 - loss: 0.0297
# Epoch 343: Test Loss: 0.40564993023872375, Test Accuracy: 0.9002293348312378
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9919 - loss: 0.0297 - epoch: 343.0000
# Epoch 344/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0309
# Epoch 344: Test Loss: 0.38321563601493835, Test Accuracy: 0.9082568883895874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9921 - loss: 0.0309 - epoch: 344.0000
# Epoch 345/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9871 - loss: 0.0395
# Epoch 345: Test Loss: 0.38334840536117554, Test Accuracy: 0.9094036817550659
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9872 - loss: 0.0394 - epoch: 345.0000
# Epoch 346/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0322
# Epoch 346: Test Loss: 0.40028247237205505, Test Accuracy: 0.9059633016586304
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9909 - loss: 0.0322 - epoch: 346.0000
# Epoch 347/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0350
# Epoch 347: Test Loss: 0.3858574330806732, Test Accuracy: 0.9082568883895874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9923 - loss: 0.0351 - epoch: 347.0000
# Epoch 348/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9886 - loss: 0.0351
# Epoch 348: Test Loss: 0.35343313217163086, Test Accuracy: 0.9162843823432922
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9886 - loss: 0.0350 - epoch: 348.0000
# Epoch 349/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0315
# Epoch 349: Test Loss: 0.38263827562332153, Test Accuracy: 0.9082568883895874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9925 - loss: 0.0315 - epoch: 349.0000
# Epoch 350/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9925 - loss: 0.0307
# Epoch 350: Test Loss: 0.4201276898384094, Test Accuracy: 0.9036697149276733
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9925 - loss: 0.0307 - epoch: 350.0000

# %%
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Sabtu, 10 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ## Training Models_

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# import tensorflow as tf

# # Callback for logging to CSV
# class CustomCSVLogger(Callback):
#     def __init__(self, filename, initial_epoch=1):
#         super(CustomCSVLogger, self).__init__()
#         self.filename = filename
#         self.epoch = initial_epoch

#     def on_epoch_end(self, epoch, logs=None):
#         logs = logs or {}
#         logs['epoch'] = self.epoch
#         self.epoch += 1
#         df = pd.DataFrame([logs])
#         if epoch == 0 and self.epoch == 2:
#             df.to_csv(self.filename, mode='w', index=False)
#         else:
#             df.to_csv(self.filename, mode='a', header=False, index=False)

# # Callback for testing evaluation
# class TestEvaluationCallback(Callback):
#     def __init__(self, test_data, test_log_filename, initial_epoch=1):
#         self.test_data = test_data
#         self.test_log_filename = test_log_filename
#         self.initial_epoch = initial_epoch

#     def on_epoch_end(self, epoch, logs=None):
#         test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
#         print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
#         # Save test evaluation to CSV
#         with open(self.test_log_filename, 'a') as f:
#             f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# # Define paths
# csv_logger_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_train_v1.csv"
# test_log_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_test_v1.csv"
# model_filepath_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_keras\\v4.4.7_keras_v1.keras"

# # Load the last saved model
# try:
#     model = tf.keras.models.load_model(model_filepath_v1)
#     print("Model loaded from checkpoint.")
# except Exception as e:
#     print(f"Failed to load model from checkpoint: {e}")

# # Determine the last epoch trained
# try:
#     history_df = pd.read_csv(csv_logger_v1)
#     initial_epoch = history_df['epoch'].max()
# except FileNotFoundError:
#     print(f"File tidak ditemukan di path: {csv_logger_v1}")
#     history_df = None
#     initial_epoch = 1

# try:
#     test_history_df = pd.read_csv(test_log_v1)
# except FileNotFoundError:
#     print(f"File tidak ditemukan di path: {test_log_v1}")
#     test_history_df = None

# # Define callbacks
# # early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
# # reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
# csv_logger = CustomCSVLogger(csv_logger_v1, initial_epoch=initial_epoch + 1)
# model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
# test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1, initial_epoch=initial_epoch + 1)

# # Train the model and save the logs to CSV
# hist_v1 = model.fit(
#     X_train, y_train,
#     # validation_data=(X_val, y_val),
#     epochs=initial_epoch + 100,  # change this to the desired number of total epochs
#     batch_size=64,
#     initial_epoch=initial_epoch,
#     callbacks=[
#         # early_stopping,
#         # reduce_lr,
#         model_checkpoint,
#         csv_logger,
#         test_eval_callback
#     ]
# )

# %%
# # Muat data dari file CSV
# try:
#     history_df = pd.read_csv(csv_logger_v1)
# except FileNotFoundError:
#     print(f"File tidak ditemukan di path: {csv_logger_v1}")
#     history_df = None

# try:
#     test_history_df = pd.read_csv(test_log_v1)
# except FileNotFoundError:
#     print(f"File tidak ditemukan di path: {test_log_v1}")
#     test_history_df = None

# if history_df is not None and test_history_df is not None:
#     # Dapatkan jumlah epoch dari panjang data
#     epochs = range(1, len(history_df) + 1)

#     # Plot akurasi dan loss
#     plt.figure(figsize=(15, 6))
#     plt.suptitle("Jum'at, 09 Agustus - Training Model", fontsize=20)

#     # Plot Akurasi Training, Validasi & Testing
#     plt.subplot(1, 2, 1)
#     plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
#     # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
#     plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
#     plt.title('Model Accuracy', fontsize=15)
#     plt.xlabel('Epochs', fontsize=12)
#     plt.ylabel('Accuracy', fontsize=12)
#     plt.legend(loc='best')
#     plt.grid(True)

#     # Plot Loss Training, Validasi & Testing
#     plt.subplot(1, 2, 2)
#     plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
#     # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
#     plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
#     plt.title('Model Loss', fontsize=15)
#     plt.xlabel('Epochs', fontsize=12)
#     plt.ylabel('Loss', fontsize=12)
#     plt.legend(loc='best')
#     plt.grid(True)

#     plt.tight_layout(rect=[0, 0, 1, 0.96])
#     plt.show()

# %% [markdown]
# # Evaluate Model

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Muat data dari file CSV
csv_logger_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_train_v1.csv"
test_log_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.7_log_test_v1.csv"

try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot Akurasi
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Testing Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('History of Accuracy', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

    # Plot Loss
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Testing Loss', color='red')  # Plot Test Loss per epoch
    plt.title('History of Loss', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
import tensorflow as tf

# Filepath model yang disimpan
model_filepath_v1 = "C:\\Users\\M S I\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.7_keras_v1.keras"

# Load the last saved model
model = tf.keras.models.load_model(model_filepath_v1)

# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, log_loss, accuracy_score, classification_report, confusion_matrix

# Prediksi menggunakan model pada data uji
y_pred = model.predict(X_test)
y_pred_probabilities = tf.nn.softmax(y_pred).numpy() 
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Hitung metrik evaluasi
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
log_loss_value = log_loss(y_true_classes, y_pred_probabilities)

# Print metrik evaluasi
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Log Loss: {log_loss_value:.2f}")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step
# Accuracy: 0.91
# Precision: 0.92
# Recall: 0.91
# F1 Score: 0.91
# Log Loss: 2.18

# %%
# Tampilkan classification report yang lengkap
report = classification_report(y_true_classes, y_pred_classes, target_names=AKSARA)
print(report)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Normalisasi confusion matrix untuk mendapatkan persentase
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Tampilkan confusion matrix sebagai heatmap
plt.figure(figsize=(18, 15))
# sns.heatmap(conf_matrix_normalized, annot=True, fmt=".2%", cmap="YlGnBu", xticklabels=AKSARA, yticklabels=AKSARA)
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=AKSARA, yticklabels=AKSARA)

plt.xlabel("Actual Aksara", fontsize=15)
plt.ylabel("Predicted Aksara", fontsize=15)
# plt.title("Confusion Matrix (Percentage)")
plt.title("Confusion Matrix", fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           ba       0.97      0.90      0.94        42
#           ca       1.00      0.81      0.89        42
#           da       0.93      0.95      0.94        44
#          dha       0.89      0.89      0.89        47
#           ga       0.97      0.90      0.94        42
#           ha       0.79      0.93      0.85        41
#           ja       1.00      1.00      1.00        37
#           ka       0.97      0.90      0.94        42
#           la       0.90      0.95      0.93        40
#           ma       0.98      0.98      0.98        53
#           na       0.93      0.98      0.95        43
#          nga       0.84      0.98      0.91        54
#          nya       1.00      0.92      0.96        38
#           pa       0.66      1.00      0.80        45
#           ra       0.98      0.98      0.98        44
#           sa       0.91      0.87      0.89        47
#           ta       0.97      0.73      0.83        48
#          tha       0.97      0.79      0.87        43
#           wa       0.82      0.77      0.80        43
#           ya       0.92      0.95      0.93        37
#
#     accuracy                           0.91       872
#    macro avg       0.92      0.91      0.91       872
# weighted avg       0.92      0.91      0.91       872

# %%
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from sklearn.metrics import classification_report, confusion_matrix

# # Definisikan kelas Aksara
# AKSARA = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma', 
#           'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Muat model dari checkpoint
# try:
#     model = tf.keras.models.load_model(model_filepath_v1)
#     print("Model loaded from checkpoint.")
# except Exception as e:
#     print(f"Failed to load model from checkpoint: {e}")

# # Prediksi menggunakan model pada data uji
# y_pred = model.predict(X_test)
# y_pred_probabilities = tf.nn.softmax(y_pred).numpy()  # Terapkan softmax secara eksplisit jika perlu
# y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
# y_true_classes = np.argmax(y_test, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# # Normalisasi confusion matrix untuk mendapatkan persentase
# conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# # Kelas untuk setiap subset
# subset1_classes = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma']
# subset2_classes = ['na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Dapatkan indeks untuk setiap subset
# subset1_indices = [AKSARA.index(cls) for cls in subset1_classes]
# subset2_indices = [AKSARA.index(cls) for cls in subset2_classes]

# # Pisahkan confusion matrix untuk dua subset kelas
# conf_matrix_subset1 = conf_matrix_normalized[np.ix_(subset1_indices, subset1_indices)]
# conf_matrix_subset2 = conf_matrix_normalized[np.ix_(subset2_indices, subset2_indices)]

# # Simpan confusion matrix subset 1 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset1, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset1_classes, yticklabels=subset1_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 1 (Percentage)")
# plt.title("Confusion Matrix - Subset 1", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\08Agu_subset1.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# # Simpan confusion matrix subset 2 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset2, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset2_classes, yticklabels=subset2_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 2 (Percentage)")
# plt.title("Confusion Matrix - Subset 2", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\08Agu_subset2.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# %% [markdown]
# # Predictive Model

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the function to display images with predictions
def display_images_with_predictions(images, true_labels, predictions, labels, max_images=100):
    num_images = min(len(images), max_images)
    cols = 5
    rows = (num_images + cols - 1) // cols  # Compute number of rows needed

    plt.figure(figsize=(15, 3 * rows))
    
    for i in range(num_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        
        # Check if prediction is correct
        correct = true_labels[i] == predictions[i]
        result = "Correct" if correct else "Incorrect"
        color = "green" if correct else "red"
        
        # Adjust title to avoid overlapping
        plt.title(
            f"True: {labels[true_labels[i]]} || Pred: {labels[predictions[i]]}\n{result}",
            color=color,
            fontsize=12,  # Set font size
            pad=5  # Add padding to title
        )
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Load the trained model
model = load_model(model_filepath_v1)

# Perform predictions
y_pred_probabilities = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)

# Convert one-hot encoded y_test to class indices if needed
if y_test.ndim == 2:
    y_test_classes = np.argmax(y_test, axis=1)
else:
    y_test_classes = y_test

# Display some test images with predictions
display_images_with_predictions(X_test, y_test_classes, y_pred_classes, AKSARA)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step

# %% [markdown]
# sesuai prediksi

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed

# Load the trained model
model = load_model(model_filepath_v1)  # Replace with your model path

# Path to the test image
test_image_path = "C:\\Users\\M S I\\W\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\tha18.png"
image_size = IMAGE_SIZE

# Preprocess the image
preprocessed_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
pos = np.argmax(output)

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", output[0][pos])

# Define a variable to store the predicted label
predicted_label = ""

# Print the class based on the position using if-elif
if pos == 0:
    predicted_label = "ba"
elif pos == 1:
    predicted_label = 'ca'
elif pos == 2:
    predicted_label = 'da'
elif pos == 3:
    predicted_label = 'dha'
elif pos == 4:
    predicted_label = 'ga'
elif pos == 5:
    predicted_label = 'ha'
elif pos == 6:
    predicted_label = 'ja'
elif pos == 7:
    predicted_label = 'ka'
elif pos == 8:
    predicted_label = 'la'
elif pos == 9:
    predicted_label = 'ma'
elif pos == 10:
    predicted_label = 'na'
elif pos == 11:
    predicted_label = 'nga'
elif pos == 12:
    predicted_label = 'nya'
elif pos == 13:
    predicted_label = 'pa'
elif pos == 14:
    predicted_label = 'ra'
elif pos == 15:
    predicted_label = 'sa'
elif pos == 16:
    predicted_label = 'ta'
elif pos == 17:
    predicted_label = 'tha'
elif pos == 18:
    predicted_label = 'wa'
elif pos == 19:
    predicted_label = 'ya'

# Print the predicted label
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(image.img_to_array(image.load_img(test_image_path, target_size=image_size, color_mode='grayscale')))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
# plt.title(f"Predicted: {predicted_label} || Score: {output[0][pos]:.8f}")
plt.title(f"Predicted: {predicted_label}", fontsize=15)
plt.axis('on')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Prediction output:
#  [[1.3096387e-05 1.1086170e-06 4.8887316e-05 5.2404662e-06 4.8409640e-07
#   6.5029820e-07 2.0687485e-05 3.7587048e-07 3.6394991e-07 4.4818394e-06
#   1.0792291e-05 3.5781653e-03 6.8779987e-06 4.6774589e-05 7.4938034e-06
#   4.2878008e-07 5.5894674e-07 9.9625093e-01 2.6844928e-06 5.3101278e-08]]
# Score:  0.9962509
# Aksara:  tha

# %% [markdown]
# sesuai prediksi

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) 
    # Apply Laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed, img_array_resized  # Return both images if needed

# Load the trained model
model = load_model(model_filepath_v1)

# Path to the test image
test_image_path = "C:\\Users\\M S I\\W\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ya13.png"
image_size = (96, 96)  # Define your image size

# Preprocess the image
preprocessed_image, original_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
max_val = output[0][0]
pos = 0
for i in range(1, len(output[0])):
    if output[0][i] > max_val:
        max_val = output[0][i]
        pos = i

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", max_val)

# Define labels
labels = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 
          'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']
predicted_label = labels[pos]
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(cv2.resize(image.img_to_array(image.load_img(test_image_path, color_mode='grayscale')), image_size, interpolation=cv2.INTER_AREA))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
plt.title(f"Predicted: {predicted_label}")
plt.axis('on')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 31 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028FA1E98180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Prediction output:
#  [[7.0523191e-07 7.6078334e-07 2.9021985e-05 2.0953003e-06 1.3268772e-03
#   1.3801011e-03 2.2152561e-05 3.5266759e-05 1.7189917e-01 1.1677885e-06
#   5.3336838e-04 1.2618568e-06 1.9061485e-04 1.2217788e-02 4.7670896e-05
#   9.2245406e-05 2.3364009e-05 5.9622897e-07 2.3816317e-06 8.1219333e-01]]
# Score:  0.81219333
# Aksara:  ya

# %% [markdown]
# tidak sesuai prediksi

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) 
    # Apply Laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed, img_array_resized  # Return both images if needed

# Load the trained model
model = load_model(model_filepath_v1)

# Path to the test image
test_image_path = "C:\\Users\\M S I\\W\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ka4.png"
image_size = (96, 96)  # Define your image size

# Preprocess the image
preprocessed_image, original_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
max_val = output[0][0]
pos = 0
for i in range(1, len(output[0])):
    if output[0][i] > max_val:
        max_val = output[0][i]
        pos = i

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", max_val)

# Define labels
labels = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 
          'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']
predicted_label = labels[pos]
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(cv2.resize(image.img_to_array(image.load_img(test_image_path, color_mode='grayscale')), image_size, interpolation=cv2.INTER_AREA))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
plt.title(f"Predicted: {predicted_label}")
plt.axis('on')

plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 32 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000028F9AE6A980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Prediction output:
#  [[9.8618648e-07 8.8955966e-07 4.8010634e-06 2.7494866e-07 2.8837262e-06
#   2.0779401e-06 8.1206150e-07 3.0027288e-01 1.9532602e-06 1.2057666e-07
#   6.9963914e-01 3.3444363e-07 2.8107850e-06 2.5332409e-07 1.0426908e-06
#   1.5436632e-05 4.4696648e-05 1.2618069e-07 2.1255376e-08 8.5204629e-06]]
# Score:  0.69963914
# Aksara:  na
