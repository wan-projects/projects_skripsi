# %% [markdown]
# # Note
# 1. Melakukan percobaan build_models v4.0
# 2. Dilakukan pada hari Sabtu, 10 Agustus 2024
# 3. Tempat di Lab
# 4. Data menggunakan Dataset yang dari Roboflow
# 4. Meliputi Class: 20 Kelas Aksara Jawa:
# - Ba, Ca, Da, Dha, Ga, Ha, Ja, Ka, La, Ma,
# - Na, Nga, Nya, Pa, Ra, Sa, Ta, Tha, Wa, Ya

# %% [markdown]
# # Setup Environment

# %%
# pip install tensorflow

# %%
# pip install keras

# %%
# pip install opencv-python

# %%
# pip install imutils

# %%
# pip install matplotlib

# %%
# pip install seaborn

# %%
# pip install scikit-learn

# %% [markdown]
# # Import Library

# %%
# import pandas as pd
# import matplotlib.pyplot as plt  
# import os
# from os.path import join
# import random
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from tensorflow.keras.utils import to_categorical
# from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
# from keras.models import Sequential
# from tensorflow.keras import layers, models
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
# from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization , Activation,Conv2D
# from keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# from sklearn.metrics import roc_curve, auc, roc_auc_score
# from sklearn.metrics import classification_report
# import seaborn as sns
# from sklearn.metrics import classification_report, accuracy_score,roc_curve,confusion_matrix

# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
import cv2

def convert_to_png(image_path, output_path):
    # Read the image using OpenCV
    image = cv2.imread(image_path)
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    # Save the image as PNG
    cv2.imwrite(output_path, image)

def get_last_n_parts(path, n):
    return os.path.join(*path.split(os.sep)[-n:])

def create_labels_csv(data_collection, output_csv, path_output):
    # Check if the CSV file already exists
    if os.path.exists(output_csv):
        print(f'Label CSV already exists at: {output_csv}')
        return  # Exit the function if the file already exists
    
    # List to store image file paths and their corresponding labels and dimensions
    data = []

    # Traverse the dataset directory
    for root, dirs, files in os.walk(data_collection):
        for file in files:
            if file.endswith(('.jpg', '.jpeg', '.png')):
                # Get the class label from the subdirectory name
                label = os.path.basename(root)
                # Get the full file path
                file_path = os.path.join(root, file)
                
                # Create a new file path for the PNG image
                relative_path = os.path.relpath(file_path, data_collection)
                png_file_path = os.path.join(path_output, os.path.splitext(relative_path)[0] + '.png')
                
                # Convert the image to PNG
                convert_to_png(file_path, png_file_path)
                
                # Get image dimensions
                img = cv2.imread(file_path)
                height, width, _ = img.shape
                
                # Get only the last 3 parts of the path for CSV
                csv_path = get_last_n_parts(png_file_path, 2)
                
                # Append to the data list including dimensions
                data.append([csv_path, width, height, label])
    
    # Create a DataFrame from the data list
    df = pd.DataFrame(data, columns=['file_path', 'width', 'height', 'label'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(output_csv, index=False)
    print(f'Labels CSV file created at: {output_csv}')

# Define the paths for the two datasets and their respective output directories
data_collection = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\Four_Data_Sources\\"
output_csv = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_preprocessing\\v3.4_data_custom\\labels.csv"
path_output = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_preprocessing\\v3.4_data_custom\\"

# Process the dataset
create_labels_csv(data_collection, output_csv, path_output)
# Out:
# Label CSV already exists at: C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\labels.csv

# %%
import pandas as pd

# Path main
PATH_MAIN = path_output
file = PATH_MAIN + "labels.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                                      file_path  width  height label
# 0  ba\002798ad-631c-4f0c-b899-aa66fb5c2ac1.png    239     167    ba
# 1  ba\040ab1c7-bffa-4a93-8c42-54e5597f2243.png     96      67    ba
# 2  ba\0789a0d8-e129-48ec-b74e-2e53f4a7ece9.png    235     166    ba
# 3  ba\11f6c317-635a-4e64-8552-05bf8b7b3a95.png     96      67    ba
# 4  ba\13469389-6f9b-43dc-be99-8dfbfaae51cb.png    235     165    ba

# %%
import matplotlib.pyplot as plt
import os

# Define an empty list
file_counts = []
aksara_categories = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 'na',
                     'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

def countFile(link):
    path = link
    num_files = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
    file_counts.append(num_files)
    print(f"Jumlah File {link} is ", num_files)

# Define the input path
base_path = PATH_MAIN

# Count files for each category
for category in aksara_categories:
    countFile(os.path.join(base_path, category))

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'pink', 'indigo', 'purple', 
          'cyan', 'magenta', 'lime', 'maroon', 'navy', 'olive', 'orchid', 'peru', 
          'salmon', 'sienna', 'skyblue', 'tan']  # Colors for each bar

# Create bar chart
plt.figure(figsize=(13, 6))
bars = plt.bar(aksara_categories, file_counts, color=colors)
plt.xlabel('Kategori Aksara', fontsize=15)
plt.ylabel('Jumlah Gambar', fontsize=15)
plt.title('Jumlah Gambar Aksara Jawa', fontsize=17)
plt.xticks(fontsize=15, rotation=13)
plt.tight_layout()

# Add text labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{height}', ha='center', va='bottom', fontsize=12)

# Show the plot
plt.show()
# Out:
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ba is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ca is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\da is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\dha is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ga is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ha is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ja is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ka is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\la is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ma is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\na is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\nga is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\nya is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\pa is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ra is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\sa is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ta is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\tha is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\wa is  220
# Jumlah File C:\Users\USER-03\W\projects_skripsi\data\data_preprocessing\v3.4_data_custom\ya is  220

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Define the input path and aksaraJowo
INPUT_PATH = PATH_MAIN  
AKSARA = aksara_categories

# Define the target image size
IMAGE_SIZE = (96, 96)
INPUT_SHAPE = (96, 96, 1)

def apply_custom_preprocessing(image):
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

def create_image_generator(input_path, aksaraJowo, image_size):
    for index, jowo in enumerate(aksaraJowo):
        aksara_path = os.path.join(input_path, jowo)
        
        for filename in os.listdir(aksara_path):
            image_path = os.path.join(aksara_path, filename)
            original_image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)  # Baca dan ubah warna asli
            original_image_resized = cv2.resize(original_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar asli
            grayscale_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Baca gambar sebagai grayscale
            grayscale_image_resized = cv2.resize(grayscale_image, image_size, interpolation=cv2.INTER_AREA)  # Resize gambar grayscale
            image_filtered = apply_custom_preprocessing(grayscale_image_resized)
            
            yield original_image_resized, grayscale_image_resized, image_filtered, index

# tranform list to numpy array
def load_images(input_path, aksaraJowo, image_size):
    X_original, X_grayscale, X_filtered, y_label = [], [], [], []
    
    for original_image, grayscale_image, image_filtered, label in create_image_generator(input_path, aksaraJowo, image_size):
        X_original.append(original_image)
        X_grayscale.append(grayscale_image)
        X_filtered.append(image_filtered)
        y_label.append(label)
        
    X_original = np.array(X_original)
    X_grayscale = np.array(X_grayscale)
    X_filtered = np.array(X_filtered)
    y_label = to_categorical(np.array(y_label))
    
    return X_original, X_grayscale, X_filtered, y_label

# Load images with custom preprocessing applied
X_original, X_grayscale, X_filtered, y_label = load_images(INPUT_PATH, AKSARA, IMAGE_SIZE)

# %%
# Select one image to display
index_to_display = 100

# Display the original image, grayscale image, and filtered image
original_image = X_original[index_to_display]
grayscale_image = X_grayscale[index_to_display]
filtered_image = X_filtered[index_to_display]

# Plot the images
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(original_image)
plt.axis('on')

plt.subplot(1, 3, 2)
plt.title('Grayscale Image')
plt.imshow(grayscale_image)
plt.axis('on')

plt.subplot(1, 3, 3)
plt.title('Filtered Image')
# plt.imshow(filtered_image, cmap='gray')
plt.imshow(filtered_image, cmap='gray')
plt.axis('on')

plt.show()

# %%
# Reshape X_filtered
X_filtered_reshaped = X_filtered.reshape(-1, 96, 96, 1) / 255  # Reshape dan normalisasi

print("X_filtered shape after reshape:", X_filtered_reshaped.shape)
# Out:
# X_filtered shape after reshape: (4400, 96, 96, 1)

# %%
from sklearn.model_selection import train_test_split

# Tahap pertama: Membagi data menjadi data pelatihan (80%) dan data pengujian (20%)
X_train, X_test, y_train, y_test = train_test_split(X_filtered_reshaped, y_label, test_size=0.2, random_state=54)

# Verifikasi ukuran data
print("Ukuran data pelatihan:", X_train.shape, y_train.shape)
print("Ukuran data pengujian:", X_test.shape, y_test.shape)
# Out:
# Ukuran data pelatihan: (3520, 96, 96, 1) (3520, 20)
# Ukuran data pengujian: (880, 96, 96, 1) (880, 20)

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_train[100], cmap='gray')
plt.title("Sample Image in Class {} from Training Data !!!".format(AKSARA[np.argmax(y_train[100])]))
plt.axis('on')
plt.show()

# %%
# Menampilkan salah satu gambar dari data pelatihan
plt.imshow(X_test[150], cmap='gray')
plt.title("Sample Image in Class {} from Testing Data !!!".format(AKSARA[np.argmax(y_test[150])]))
plt.axis('on')
plt.show()

# %% [markdown]
# # Build the Model

# %% [markdown]
# ## Training Models_1 - 50

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras import optimizers

# Set hyperparameters tuning
optimizer = 'SGD'
learning_rate = 0.0001
dropout_rate = 0.2
weight_decay = 0.0001
momentum = 0.9
clip_norm = 0.0
num_classes = 20
input_shape = INPUT_SHAPE

def create_model(input_shape, num_classes, optimizer_name, learning_rate, dropout_rate, weight_decay, momentum, clip_norm):
    model = Sequential()

    # Block 1
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 3
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 4
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Block 5
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_rate))

    # Flatten
    model.add(Flatten())

    # Dense layers
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))

    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    # Define optimizer with hyperparameters
    if optimizer_name == 'SGD':
        optimizer = optimizers.SGD(learning_rate=learning_rate, decay=weight_decay, momentum=momentum, clipnorm=clip_norm)
    elif optimizer_name == 'Adam':
        optimizer = optimizers.Adam(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    elif optimizer_name == 'RMSprop':
        optimizer = optimizers.RMSprop(learning_rate=learning_rate, decay=weight_decay, clipnorm=clip_norm)
    else:
        raise ValueError("Optimizer not supported. Choose from 'SGD', 'Adam', or 'RMSprop'.")

    # Compile model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Create the model
model = create_model(input_shape=input_shape, num_classes=num_classes, optimizer_name=optimizer, learning_rate=learning_rate, 
                     dropout_rate=dropout_rate, weight_decay=weight_decay, momentum=momentum, clip_norm=clip_norm)

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 96, 96, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 96, 96, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 96, 96, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 20)             │        10,260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,081,460 (49.90 MB)
#  Trainable params: 13,072,628 (49.87 MB)
#  Non-trainable params: 8,832 (34.50 KB)

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import numpy as np

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = 1

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.test_loss = []
        self.test_accuracy = []

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        self.test_loss.append(test_loss)
        self.test_accuracy.append(test_accuracy)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_train_v1.csv"
test_log_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_test_v1.csv"
model_filepath_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_keras\\v4.4.8_keras_v1.keras"

# Define callbacks
# early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1)

# Initialize test log file with header
with open(test_log_v1, 'w') as f:
    f.write("epoch,test_loss,test_accuracy\n")

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=64,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.0483 - loss: 3.9903
# Epoch 1: Test Loss: 3.1494569778442383, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 644s 11s/step - accuracy: 0.0483 - loss: 3.9898 - epoch: 1.0000
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.0556 - loss: 3.9404
# Epoch 2: Test Loss: 3.3702051639556885, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 552s 10s/step - accuracy: 0.0557 - loss: 3.9391 - epoch: 2.0000
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.0788 - loss: 3.7519
# Epoch 3: Test Loss: 3.55391001701355, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 912s 16s/step - accuracy: 0.0788 - loss: 3.7512 - epoch: 3.0000
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.0932 - loss: 3.5661
# Epoch 4: Test Loss: 3.9455771446228027, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 609s 11s/step - accuracy: 0.0933 - loss: 3.5657 - epoch: 4.0000
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.1178 - loss: 3.4606
# Epoch 5: Test Loss: 4.714083671569824, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 676s 12s/step - accuracy: 0.1178 - loss: 3.4602 - epoch: 5.0000
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.1465 - loss: 3.2856
# Epoch 6: Test Loss: 4.591423988342285, Test Accuracy: 0.04545454680919647
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 597s 11s/step - accuracy: 0.1466 - loss: 3.2852 - epoch: 6.0000
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.1712 - loss: 3.1075
# Epoch 7: Test Loss: 5.216981410980225, Test Accuracy: 0.05681818351149559
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 524s 10s/step - accuracy: 0.1715 - loss: 3.1060 - epoch: 7.0000
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.1955 - loss: 2.9087
# Epoch 8: Test Loss: 6.118672847747803, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 429s 8s/step - accuracy: 0.1958 - loss: 2.9075 - epoch: 8.0000
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.2442 - loss: 2.7002
# Epoch 9: Test Loss: 6.2592267990112305, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 473s 9s/step - accuracy: 0.2444 - loss: 2.6992 - epoch: 9.0000
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.2923 - loss: 2.4821
# Epoch 10: Test Loss: 6.031024932861328, Test Accuracy: 0.053409092128276825
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 611s 11s/step - accuracy: 0.2924 - loss: 2.4817 - epoch: 10.0000
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.3010 - loss: 2.3643
# Epoch 11: Test Loss: 5.502547264099121, Test Accuracy: 0.05454545468091965
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 576s 10s/step - accuracy: 0.3012 - loss: 2.3638 - epoch: 11.0000
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.3454 - loss: 2.2121
# Epoch 12: Test Loss: 5.473686218261719, Test Accuracy: 0.05454545468091965
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 528s 9s/step - accuracy: 0.3458 - loss: 2.2110 - epoch: 12.0000
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4057 - loss: 2.0181
# Epoch 13: Test Loss: 4.555891513824463, Test Accuracy: 0.06704545766115189
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 543s 10s/step - accuracy: 0.4057 - loss: 2.0182 - epoch: 13.0000
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4210 - loss: 1.9408
# Epoch 14: Test Loss: 3.9177517890930176, Test Accuracy: 0.09318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 554s 10s/step - accuracy: 0.4211 - loss: 1.9400 - epoch: 14.0000
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.4489 - loss: 1.8123
# Epoch 15: Test Loss: 3.829916000366211, Test Accuracy: 0.1090909093618393
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 535s 10s/step - accuracy: 0.4488 - loss: 1.8124 - epoch: 15.0000
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4997 - loss: 1.6774
# Epoch 16: Test Loss: 3.4705116748809814, Test Accuracy: 0.15000000596046448
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 489s 8s/step - accuracy: 0.4997 - loss: 1.6775 - epoch: 16.0000
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.4909 - loss: 1.6433
# Epoch 17: Test Loss: 3.1042227745056152, Test Accuracy: 0.2136363685131073
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 481s 8s/step - accuracy: 0.4912 - loss: 1.6427 - epoch: 17.0000
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5351 - loss: 1.5416
# Epoch 18: Test Loss: 2.5148470401763916, Test Accuracy: 0.30000001192092896
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 528s 9s/step - accuracy: 0.5353 - loss: 1.5411 - epoch: 18.0000
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.5550 - loss: 1.4683
# Epoch 19: Test Loss: 2.483402967453003, Test Accuracy: 0.3284091055393219
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 474s 9s/step - accuracy: 0.5550 - loss: 1.4679 - epoch: 19.0000
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.5674 - loss: 1.3941
# Epoch 20: Test Loss: 2.4636049270629883, Test Accuracy: 0.33068183064460754
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 510s 9s/step - accuracy: 0.5673 - loss: 1.3941 - epoch: 20.0000
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.5977 - loss: 1.2921
# Epoch 21: Test Loss: 2.3842716217041016, Test Accuracy: 0.35227271914482117
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 582s 11s/step - accuracy: 0.5978 - loss: 1.2925 - epoch: 21.0000
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.6217 - loss: 1.1972
# Epoch 22: Test Loss: 2.184708833694458, Test Accuracy: 0.39318183064460754
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 540s 9s/step - accuracy: 0.6217 - loss: 1.1977 - epoch: 22.0000
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.6221 - loss: 1.1974
# Epoch 23: Test Loss: 2.0877370834350586, Test Accuracy: 0.4056818187236786
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 441s 8s/step - accuracy: 0.6221 - loss: 1.1972 - epoch: 23.0000
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6472 - loss: 1.1133
# Epoch 24: Test Loss: 2.1349270343780518, Test Accuracy: 0.3852272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 409s 7s/step - accuracy: 0.6471 - loss: 1.1135 - epoch: 24.0000
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6499 - loss: 1.1049
# Epoch 25: Test Loss: 2.111177921295166, Test Accuracy: 0.3954545557498932
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 437s 7s/step - accuracy: 0.6500 - loss: 1.1048 - epoch: 25.0000
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6819 - loss: 1.0251
# Epoch 26: Test Loss: 2.0091967582702637, Test Accuracy: 0.41818180680274963
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 462s 8s/step - accuracy: 0.6818 - loss: 1.0253 - epoch: 26.0000
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6748 - loss: 1.0069
# Epoch 27: Test Loss: 1.8751952648162842, Test Accuracy: 0.44545453786849976
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 424s 7s/step - accuracy: 0.6750 - loss: 1.0068 - epoch: 27.0000
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6977 - loss: 0.9501
# Epoch 28: Test Loss: 1.9361469745635986, Test Accuracy: 0.4329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 405s 7s/step - accuracy: 0.6977 - loss: 0.9503 - epoch: 28.0000
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7071 - loss: 0.9376
# Epoch 29: Test Loss: 1.8864610195159912, Test Accuracy: 0.44090908765792847
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 403s 7s/step - accuracy: 0.7071 - loss: 0.9375 - epoch: 29.0000
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7128 - loss: 0.9062
# Epoch 30: Test Loss: 1.6567779779434204, Test Accuracy: 0.48750001192092896
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.7129 - loss: 0.9060 - epoch: 30.0000
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7192 - loss: 0.8779
# Epoch 31: Test Loss: 1.583045244216919, Test Accuracy: 0.5045454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - accuracy: 0.7192 - loss: 0.8779 - epoch: 31.0000
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7277 - loss: 0.8464
# Epoch 32: Test Loss: 1.5575282573699951, Test Accuracy: 0.5045454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.7279 - loss: 0.8459 - epoch: 32.0000
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7477 - loss: 0.8046
# Epoch 33: Test Loss: 1.507659673690796, Test Accuracy: 0.5284090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 409s 7s/step - accuracy: 0.7478 - loss: 0.8044 - epoch: 33.0000
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7634 - loss: 0.7655
# Epoch 34: Test Loss: 1.6110483407974243, Test Accuracy: 0.5068181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 437s 7s/step - accuracy: 0.7634 - loss: 0.7655 - epoch: 34.0000
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7607 - loss: 0.7546
# Epoch 35: Test Loss: 1.5806831121444702, Test Accuracy: 0.5068181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 444s 7s/step - accuracy: 0.7606 - loss: 0.7547 - epoch: 35.0000
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7771 - loss: 0.7054
# Epoch 36: Test Loss: 1.6350764036178589, Test Accuracy: 0.49772727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 404s 7s/step - accuracy: 0.7771 - loss: 0.7057 - epoch: 36.0000
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7754 - loss: 0.7061
# Epoch 37: Test Loss: 1.308637022972107, Test Accuracy: 0.5772727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.7754 - loss: 0.7063 - epoch: 37.0000
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7916 - loss: 0.6522
# Epoch 38: Test Loss: 1.3194113969802856, Test Accuracy: 0.5772727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 444s 7s/step - accuracy: 0.7916 - loss: 0.6523 - epoch: 38.0000
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7955 - loss: 0.6442
# Epoch 39: Test Loss: 1.245431900024414, Test Accuracy: 0.5863636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 402s 7s/step - accuracy: 0.7954 - loss: 0.6444 - epoch: 39.0000
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7988 - loss: 0.6256
# Epoch 40: Test Loss: 1.299155354499817, Test Accuracy: 0.5693181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 404s 7s/step - accuracy: 0.7988 - loss: 0.6257 - epoch: 40.0000
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8050 - loss: 0.6080
# Epoch 41: Test Loss: 1.3245123624801636, Test Accuracy: 0.5681818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 407s 7s/step - accuracy: 0.8050 - loss: 0.6082 - epoch: 41.0000
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8051 - loss: 0.6309
# Epoch 42: Test Loss: 1.0707794427871704, Test Accuracy: 0.6409090757369995
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 403s 7s/step - accuracy: 0.8053 - loss: 0.6304 - epoch: 42.0000
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8116 - loss: 0.5696
# Epoch 43: Test Loss: 1.1203818321228027, Test Accuracy: 0.6272727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - accuracy: 0.8116 - loss: 0.5698 - epoch: 43.0000
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8153 - loss: 0.5708
# Epoch 44: Test Loss: 1.1409413814544678, Test Accuracy: 0.6215909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 406s 7s/step - accuracy: 0.8154 - loss: 0.5707 - epoch: 44.0000
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8135 - loss: 0.5674
# Epoch 45: Test Loss: 0.9458354711532593, Test Accuracy: 0.6806818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 404s 7s/step - accuracy: 0.8137 - loss: 0.5672 - epoch: 45.0000
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8171 - loss: 0.5823
# Epoch 46: Test Loss: 0.9342137575149536, Test Accuracy: 0.6875
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.8174 - loss: 0.5816 - epoch: 46.0000
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8469 - loss: 0.5041
# Epoch 47: Test Loss: 1.1419321298599243, Test Accuracy: 0.625
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 406s 7s/step - accuracy: 0.8467 - loss: 0.5044 - epoch: 47.0000
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8378 - loss: 0.5345
# Epoch 48: Test Loss: 1.0767430067062378, Test Accuracy: 0.6477272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 441s 7s/step - accuracy: 0.8379 - loss: 0.5341 - epoch: 48.0000
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8545 - loss: 0.4654
# Epoch 49: Test Loss: 0.9880437850952148, Test Accuracy: 0.6761363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 441s 7s/step - accuracy: 0.8544 - loss: 0.4658 - epoch: 49.0000
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8346 - loss: 0.5016
# Epoch 50: Test Loss: 0.9799595475196838, Test Accuracy: 0.6784090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 446s 7s/step - accuracy: 0.8347 - loss: 0.5012 - epoch: 50.0000

# %%
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Sabtu, 10 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ## Training Models_50 - 65

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename, initial_epoch=1):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0 and self.epoch == 2:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename, initial_epoch=1):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.initial_epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_train_v1.csv"
test_log_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_test_v1.csv"
model_filepath_v1 = "C:\\Users\\wawn1\\projects_skripsi\\save_models\\save_models_keras\\v4.4.8_keras_v1.keras"

# Load the last saved model
try:
    model = tf.keras.models.load_model(model_filepath_v1)
    print("Model loaded from checkpoint.")
except Exception as e:
    print(f"Failed to load model from checkpoint: {e}")

# Determine the last epoch trained
try:
    history_df = pd.read_csv(csv_logger_v1)
    initial_epoch = history_df['epoch'].max()
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
    initial_epoch = 1

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

# Define callbacks
# early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1, initial_epoch=initial_epoch + 1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1, initial_epoch=initial_epoch + 1)

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    # validation_data=(X_val, y_val),
    epochs=initial_epoch + 15,  # change this to the desired number of total epochs
    batch_size=64,
    initial_epoch=initial_epoch,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Model loaded from checkpoint.
# Epoch 51/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8381 - loss: 0.4937
# Epoch 51: Test Loss: 0.9213051795959473, Test Accuracy: 0.6954545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 395s 7s/step - accuracy: 0.8381 - loss: 0.4935 - epoch: 51.0000
# Epoch 52/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8549 - loss: 0.4701
# Epoch 52: Test Loss: 0.9811779260635376, Test Accuracy: 0.6670454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 444s 7s/step - accuracy: 0.8548 - loss: 0.4702 - epoch: 52.0000
# Epoch 53/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8529 - loss: 0.4652
# Epoch 53: Test Loss: 0.87601637840271, Test Accuracy: 0.7102272510528564
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 386s 7s/step - accuracy: 0.8529 - loss: 0.4651 - epoch: 53.0000
# Epoch 54/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8635 - loss: 0.4382
# Epoch 54: Test Loss: 0.8615652322769165, Test Accuracy: 0.7170454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - accuracy: 0.8636 - loss: 0.4379 - epoch: 54.0000
# Epoch 55/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8589 - loss: 0.4390
# Epoch 55: Test Loss: 0.8750420212745667, Test Accuracy: 0.7170454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 389s 7s/step - accuracy: 0.8590 - loss: 0.4389 - epoch: 55.0000
# Epoch 56/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8644 - loss: 0.4487
# Epoch 56: Test Loss: 0.9256395101547241, Test Accuracy: 0.6886363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 388s 7s/step - accuracy: 0.8646 - loss: 0.4482 - epoch: 56.0000
# Epoch 57/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8652 - loss: 0.4228
# Epoch 57: Test Loss: 0.8293303847312927, Test Accuracy: 0.7238636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 441s 7s/step - accuracy: 0.8654 - loss: 0.4227 - epoch: 57.0000
# Epoch 58/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8899 - loss: 0.3789
# Epoch 58: Test Loss: 0.7886923551559448, Test Accuracy: 0.737500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 447s 7s/step - accuracy: 0.8897 - loss: 0.3794 - epoch: 58.0000
# Epoch 59/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8822 - loss: 0.3973
# Epoch 59: Test Loss: 0.824166476726532, Test Accuracy: 0.7227272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 438s 7s/step - accuracy: 0.8822 - loss: 0.3973 - epoch: 59.0000
# Epoch 60/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8833 - loss: 0.3890
# Epoch 60: Test Loss: 0.8330608010292053, Test Accuracy: 0.7204545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - accuracy: 0.8832 - loss: 0.3891 - epoch: 60.0000
# Epoch 61/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8906 - loss: 0.3586
# Epoch 61: Test Loss: 0.784386157989502, Test Accuracy: 0.7397727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.8906 - loss: 0.3588 - epoch: 61.0000
# Epoch 62/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8769 - loss: 0.3829
# Epoch 62: Test Loss: 0.6717535257339478, Test Accuracy: 0.7715908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.8770 - loss: 0.3828 - epoch: 62.0000
# Epoch 63/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8762 - loss: 0.3888
# Epoch 63: Test Loss: 0.6713770627975464, Test Accuracy: 0.7761363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 387s 7s/step - accuracy: 0.8763 - loss: 0.3887 - epoch: 63.0000
# Epoch 64/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8962 - loss: 0.3394
# Epoch 64: Test Loss: 0.6291165947914124, Test Accuracy: 0.7875000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 442s 7s/step - accuracy: 0.8961 - loss: 0.3396 - epoch: 64.0000
# Epoch 65/65
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8938 - loss: 0.3447
# Epoch 65: Test Loss: 0.6670163869857788, Test Accuracy: 0.7715908885002136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 387s 7s/step - accuracy: 0.8938 - loss: 0.3447 - epoch: 65.0000

# %%
# Muat data dari file CSV
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Sabtu, 10 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ## Training Models_150 - 350

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Callback for logging to CSV
class CustomCSVLogger(Callback):
    def __init__(self, filename, initial_epoch=1):
        super(CustomCSVLogger, self).__init__()
        self.filename = filename
        self.epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['epoch'] = self.epoch
        self.epoch += 1
        df = pd.DataFrame([logs])
        if epoch == 0 and self.epoch == 2:
            df.to_csv(self.filename, mode='w', index=False)
        else:
            df.to_csv(self.filename, mode='a', header=False, index=False)

# Callback for testing evaluation
class TestEvaluationCallback(Callback):
    def __init__(self, test_data, test_log_filename, initial_epoch=1):
        self.test_data = test_data
        self.test_log_filename = test_log_filename
        self.initial_epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        test_loss, test_accuracy = self.model.evaluate(self.test_data[0], self.test_data[1], verbose=0)
        print(f'\nEpoch {epoch+1}: Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
        # Save test evaluation to CSV
        with open(self.test_log_filename, 'a') as f:
            f.write(f"{epoch+1},{test_loss},{test_accuracy}\n")

# Define paths
csv_logger_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_train_v1.csv"
test_log_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_test_v1.csv"
model_filepath_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.8_keras_v1.keras"

# Load the last saved model
try:
    model = tf.keras.models.load_model(model_filepath_v1)
    print("Model loaded from checkpoint.")
except Exception as e:
    print(f"Failed to load model from checkpoint: {e}")

# Determine the last epoch trained
try:
    history_df = pd.read_csv(csv_logger_v1)
    initial_epoch = history_df['epoch'].max()
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None
    initial_epoch = 1

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

# Define callbacks
# early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
# reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=25, min_lr=0.0001)
csv_logger = CustomCSVLogger(csv_logger_v1, initial_epoch=initial_epoch + 1)
model_checkpoint = ModelCheckpoint(filepath=model_filepath_v1, monitor='accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')
test_eval_callback = TestEvaluationCallback((X_test, y_test), test_log_v1, initial_epoch=initial_epoch + 1)

# Train the model and save the logs to CSV
hist_v1 = model.fit(
    X_train, y_train,
    # validation_data=(X_val, y_val),
    epochs=initial_epoch + 285,  # change this to the desired number of total epochs
    batch_size=64,
    initial_epoch=initial_epoch,
    callbacks=[
        # early_stopping,
        # reduce_lr,
        model_checkpoint,
        csv_logger,
        test_eval_callback
    ]
)
# Out:
# Model loaded from checkpoint.
# Epoch 66/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8940 - loss: 0.3296
# Epoch 66: Test Loss: 0.6302801370620728, Test Accuracy: 0.7863636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.8939 - loss: 0.3298 - epoch: 66.0000
# Epoch 67/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8962 - loss: 0.3293
# Epoch 67: Test Loss: 0.6284631490707397, Test Accuracy: 0.7943181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8961 - loss: 0.3295 - epoch: 67.0000
# Epoch 68/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8858 - loss: 0.3542
# Epoch 68: Test Loss: 0.6278857588768005, Test Accuracy: 0.7920454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.8859 - loss: 0.3540 - epoch: 68.0000
# Epoch 69/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9017 - loss: 0.3175
# Epoch 69: Test Loss: 0.658782422542572, Test Accuracy: 0.7738636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9016 - loss: 0.3178 - epoch: 69.0000
# Epoch 70/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8943 - loss: 0.3353
# Epoch 70: Test Loss: 0.6739810109138489, Test Accuracy: 0.7738636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8944 - loss: 0.3351 - epoch: 70.0000
# Epoch 71/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9036 - loss: 0.3016
# Epoch 71: Test Loss: 0.6605559587478638, Test Accuracy: 0.7772727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9035 - loss: 0.3017 - epoch: 71.0000
# Epoch 72/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9113 - loss: 0.2837
# Epoch 72: Test Loss: 0.6270248889923096, Test Accuracy: 0.7909091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9112 - loss: 0.2840 - epoch: 72.0000
# Epoch 73/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9043 - loss: 0.3091
# Epoch 73: Test Loss: 0.5597405433654785, Test Accuracy: 0.8193181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9045 - loss: 0.3089 - epoch: 73.0000
# Epoch 74/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8985 - loss: 0.3152
# Epoch 74: Test Loss: 0.6040441989898682, Test Accuracy: 0.793181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.8987 - loss: 0.3149 - epoch: 74.0000
# Epoch 75/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9049 - loss: 0.3002
# Epoch 75: Test Loss: 0.6027869582176208, Test Accuracy: 0.7954545617103577
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9049 - loss: 0.3000 - epoch: 75.0000
# Epoch 76/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9256 - loss: 0.2576
# Epoch 76: Test Loss: 0.5744854807853699, Test Accuracy: 0.8113636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9254 - loss: 0.2581 - epoch: 76.0000
# Epoch 77/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9069 - loss: 0.2850
# Epoch 77: Test Loss: 0.5207750201225281, Test Accuracy: 0.8363636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9070 - loss: 0.2849 - epoch: 77.0000
# Epoch 78/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9099 - loss: 0.2899
# Epoch 78: Test Loss: 0.5771666169166565, Test Accuracy: 0.8147727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9099 - loss: 0.2897 - epoch: 78.0000
# Epoch 79/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9190 - loss: 0.2603
# Epoch 79: Test Loss: 0.5984285473823547, Test Accuracy: 0.7988636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9189 - loss: 0.2605 - epoch: 79.0000
# Epoch 80/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9109 - loss: 0.2774
# Epoch 80: Test Loss: 0.5408222079277039, Test Accuracy: 0.8238636255264282
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9108 - loss: 0.2774 - epoch: 80.0000
# Epoch 81/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9147 - loss: 0.2630
# Epoch 81: Test Loss: 0.5029880404472351, Test Accuracy: 0.8477272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9148 - loss: 0.2629 - epoch: 81.0000
# Epoch 82/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9196 - loss: 0.2488
# Epoch 82: Test Loss: 0.505748450756073, Test Accuracy: 0.8420454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9195 - loss: 0.2489 - epoch: 82.0000
# Epoch 83/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9140 - loss: 0.2557
# Epoch 83: Test Loss: 0.535206139087677, Test Accuracy: 0.8295454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9141 - loss: 0.2555 - epoch: 83.0000
# Epoch 84/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9213 - loss: 0.2540
# Epoch 84: Test Loss: 0.5024500489234924, Test Accuracy: 0.8500000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9212 - loss: 0.2541 - epoch: 84.0000
# Epoch 85/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9207 - loss: 0.2534
# Epoch 85: Test Loss: 0.526223361492157, Test Accuracy: 0.8329545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9207 - loss: 0.2534 - epoch: 85.0000
# Epoch 86/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9287 - loss: 0.2238
# Epoch 86: Test Loss: 0.5190326571464539, Test Accuracy: 0.8295454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9286 - loss: 0.2240 - epoch: 86.0000
# Epoch 87/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9303 - loss: 0.2219
# Epoch 87: Test Loss: 0.5314913988113403, Test Accuracy: 0.831818163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9303 - loss: 0.2220 - epoch: 87.0000
# Epoch 88/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9234 - loss: 0.2366
# Epoch 88: Test Loss: 0.5014594197273254, Test Accuracy: 0.8443182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9234 - loss: 0.2365 - epoch: 88.0000
# Epoch 89/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9259 - loss: 0.2470
# Epoch 89: Test Loss: 0.46790915727615356, Test Accuracy: 0.8545454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9259 - loss: 0.2468 - epoch: 89.0000
# Epoch 90/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9305 - loss: 0.2199
# Epoch 90: Test Loss: 0.43828561902046204, Test Accuracy: 0.8738636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9305 - loss: 0.2200 - epoch: 90.0000
# Epoch 91/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9204 - loss: 0.2398
# Epoch 91: Test Loss: 0.4551229178905487, Test Accuracy: 0.8636363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9206 - loss: 0.2393 - epoch: 91.0000
# Epoch 92/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9223 - loss: 0.2386
# Epoch 92: Test Loss: 0.42006558179855347, Test Accuracy: 0.8795454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9224 - loss: 0.2385 - epoch: 92.0000
# Epoch 93/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9210 - loss: 0.2311
# Epoch 93: Test Loss: 0.4315352141857147, Test Accuracy: 0.8704545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9211 - loss: 0.2309 - epoch: 93.0000
# Epoch 94/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9317 - loss: 0.2214
# Epoch 94: Test Loss: 0.46853265166282654, Test Accuracy: 0.8534091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9316 - loss: 0.2215 - epoch: 94.0000
# Epoch 95/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9385 - loss: 0.1996
# Epoch 95: Test Loss: 0.4633791744709015, Test Accuracy: 0.8613636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9384 - loss: 0.1998 - epoch: 95.0000
# Epoch 96/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9299 - loss: 0.2139
# Epoch 96: Test Loss: 0.45992833375930786, Test Accuracy: 0.8647727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9299 - loss: 0.2138 - epoch: 96.0000
# Epoch 97/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9354 - loss: 0.2062
# Epoch 97: Test Loss: 0.4417111575603485, Test Accuracy: 0.8659090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9355 - loss: 0.2063 - epoch: 97.0000
# Epoch 98/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9459 - loss: 0.1888
# Epoch 98: Test Loss: 0.4403567314147949, Test Accuracy: 0.8727272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9457 - loss: 0.1890 - epoch: 98.0000
# Epoch 99/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9337 - loss: 0.1997
# Epoch 99: Test Loss: 0.4710279405117035, Test Accuracy: 0.855681836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9338 - loss: 0.1996 - epoch: 99.0000
# Epoch 100/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9504 - loss: 0.1864
# Epoch 100: Test Loss: 0.46896687150001526, Test Accuracy: 0.862500011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9503 - loss: 0.1865 - epoch: 100.0000
# Epoch 101/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9499 - loss: 0.1763
# Epoch 101: Test Loss: 0.4618837237358093, Test Accuracy: 0.8636363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9498 - loss: 0.1765 - epoch: 101.0000
# Epoch 102/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9396 - loss: 0.1847
# Epoch 102: Test Loss: 0.43875569105148315, Test Accuracy: 0.8693181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9396 - loss: 0.1847 - epoch: 102.0000
# Epoch 103/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9329 - loss: 0.2028
# Epoch 103: Test Loss: 0.4634086489677429, Test Accuracy: 0.8579545617103577
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9330 - loss: 0.2027 - epoch: 103.0000
# Epoch 104/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9420 - loss: 0.1957
# Epoch 104: Test Loss: 0.418000191450119, Test Accuracy: 0.875
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9420 - loss: 0.1955 - epoch: 104.0000
# Epoch 105/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9451 - loss: 0.1788
# Epoch 105: Test Loss: 0.4330693185329437, Test Accuracy: 0.8761363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9451 - loss: 0.1789 - epoch: 105.0000
# Epoch 106/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9425 - loss: 0.1676
# Epoch 106: Test Loss: 0.41512539982795715, Test Accuracy: 0.8840909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9425 - loss: 0.1679 - epoch: 106.0000
# Epoch 107/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9526 - loss: 0.1710
# Epoch 107: Test Loss: 0.3957827091217041, Test Accuracy: 0.8829545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9526 - loss: 0.1710 - epoch: 107.0000
# Epoch 108/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9523 - loss: 0.1798
# Epoch 108: Test Loss: 0.3856828212738037, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9522 - loss: 0.1798 - epoch: 108.0000
# Epoch 109/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9418 - loss: 0.1832
# Epoch 109: Test Loss: 0.3943769037723541, Test Accuracy: 0.8852272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9419 - loss: 0.1832 - epoch: 109.0000
# Epoch 110/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9529 - loss: 0.1709
# Epoch 110: Test Loss: 0.3842816650867462, Test Accuracy: 0.8897727131843567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9528 - loss: 0.1709 - epoch: 110.0000
# Epoch 111/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9516 - loss: 0.1644
# Epoch 111: Test Loss: 0.4200159013271332, Test Accuracy: 0.8761363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9516 - loss: 0.1645 - epoch: 111.0000
# Epoch 112/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9532 - loss: 0.1780
# Epoch 112: Test Loss: 0.4190914034843445, Test Accuracy: 0.8693181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9531 - loss: 0.1780 - epoch: 112.0000
# Epoch 113/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9537 - loss: 0.1498
# Epoch 113: Test Loss: 0.416251003742218, Test Accuracy: 0.8715909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9537 - loss: 0.1500 - epoch: 113.0000
# Epoch 114/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9476 - loss: 0.1757
# Epoch 114: Test Loss: 0.38513728976249695, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9476 - loss: 0.1756 - epoch: 114.0000
# Epoch 115/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9455 - loss: 0.1693
# Epoch 115: Test Loss: 0.39539721608161926, Test Accuracy: 0.8886363506317139
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9455 - loss: 0.1692 - epoch: 115.0000
# Epoch 116/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9522 - loss: 0.1518
# Epoch 116: Test Loss: 0.39963212609291077, Test Accuracy: 0.8852272629737854
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9522 - loss: 0.1518 - epoch: 116.0000
# Epoch 117/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9545 - loss: 0.1479
# Epoch 117: Test Loss: 0.377908319234848, Test Accuracy: 0.8920454382896423
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9545 - loss: 0.1480 - epoch: 117.0000
# Epoch 118/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9605 - loss: 0.1454
# Epoch 118: Test Loss: 0.38114094734191895, Test Accuracy: 0.8931818008422852
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9604 - loss: 0.1455 - epoch: 118.0000
# Epoch 119/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9540 - loss: 0.1645
# Epoch 119: Test Loss: 0.3566686809062958, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9540 - loss: 0.1643 - epoch: 119.0000
# Epoch 120/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9588 - loss: 0.1472
# Epoch 120: Test Loss: 0.3649635910987854, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9588 - loss: 0.1472 - epoch: 120.0000
# Epoch 121/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9560 - loss: 0.1424
# Epoch 121: Test Loss: 0.35517093539237976, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9560 - loss: 0.1424 - epoch: 121.0000
# Epoch 122/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9498 - loss: 0.1611
# Epoch 122: Test Loss: 0.34735071659088135, Test Accuracy: 0.9090909361839294
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9498 - loss: 0.1611 - epoch: 122.0000
# Epoch 123/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9603 - loss: 0.1458
# Epoch 123: Test Loss: 0.3531646728515625, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9602 - loss: 0.1458 - epoch: 123.0000
# Epoch 124/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9578 - loss: 0.1440
# Epoch 124: Test Loss: 0.3626035153865814, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9578 - loss: 0.1440 - epoch: 124.0000
# Epoch 125/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9576 - loss: 0.1482
# Epoch 125: Test Loss: 0.3604954183101654, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9575 - loss: 0.1482 - epoch: 125.0000
# Epoch 126/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9593 - loss: 0.1451
# Epoch 126: Test Loss: 0.38314715027809143, Test Accuracy: 0.8954545259475708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9593 - loss: 0.1450 - epoch: 126.0000
# Epoch 127/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9501 - loss: 0.1490
# Epoch 127: Test Loss: 0.38202500343322754, Test Accuracy: 0.894318163394928
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9502 - loss: 0.1489 - epoch: 127.0000
# Epoch 128/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9633 - loss: 0.1172
# Epoch 128: Test Loss: 0.3781804144382477, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9632 - loss: 0.1173 - epoch: 128.0000
# Epoch 129/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9612 - loss: 0.1340
# Epoch 129: Test Loss: 0.37659555673599243, Test Accuracy: 0.8988636136054993
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9612 - loss: 0.1340 - epoch: 129.0000
# Epoch 130/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9591 - loss: 0.1357
# Epoch 130: Test Loss: 0.3666260540485382, Test Accuracy: 0.8999999761581421
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9591 - loss: 0.1357 - epoch: 130.0000
# Epoch 131/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9600 - loss: 0.1390
# Epoch 131: Test Loss: 0.36074715852737427, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9600 - loss: 0.1390 - epoch: 131.0000
# Epoch 132/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9547 - loss: 0.1285
# Epoch 132: Test Loss: 0.36553889513015747, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9547 - loss: 0.1285 - epoch: 132.0000
# Epoch 133/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9520 - loss: 0.1379
# Epoch 133: Test Loss: 0.3658476173877716, Test Accuracy: 0.9022727012634277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9521 - loss: 0.1377 - epoch: 133.0000
# Epoch 134/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9649 - loss: 0.1190
# Epoch 134: Test Loss: 0.34946975111961365, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9649 - loss: 0.1190 - epoch: 134.0000
# Epoch 135/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9523 - loss: 0.1477
# Epoch 135: Test Loss: 0.3388069272041321, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9524 - loss: 0.1475 - epoch: 135.0000
# Epoch 136/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9558 - loss: 0.1364
# Epoch 136: Test Loss: 0.3312765955924988, Test Accuracy: 0.9125000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9557 - loss: 0.1365 - epoch: 136.0000
# Epoch 137/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9587 - loss: 0.1324
# Epoch 137: Test Loss: 0.34925949573516846, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9587 - loss: 0.1323 - epoch: 137.0000
# Epoch 138/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9735 - loss: 0.1135
# Epoch 138: Test Loss: 0.3591645061969757, Test Accuracy: 0.9045454263687134
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9734 - loss: 0.1136 - epoch: 138.0000
# Epoch 139/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9630 - loss: 0.1276
# Epoch 139: Test Loss: 0.34504324197769165, Test Accuracy: 0.9125000238418579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9630 - loss: 0.1277 - epoch: 139.0000
# Epoch 140/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9605 - loss: 0.1365
# Epoch 140: Test Loss: 0.3616121709346771, Test Accuracy: 0.9011363387107849
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9605 - loss: 0.1364 - epoch: 140.0000
# Epoch 141/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9634 - loss: 0.1287
# Epoch 141: Test Loss: 0.3452644348144531, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9634 - loss: 0.1286 - epoch: 141.0000
# Epoch 142/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9656 - loss: 0.1247
# Epoch 142: Test Loss: 0.3402535915374756, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9656 - loss: 0.1246 - epoch: 142.0000
# Epoch 143/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9589 - loss: 0.1254
# Epoch 143: Test Loss: 0.3540365397930145, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9590 - loss: 0.1252 - epoch: 143.0000
# Epoch 144/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9627 - loss: 0.1203
# Epoch 144: Test Loss: 0.3446907699108124, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9627 - loss: 0.1203 - epoch: 144.0000
# Epoch 145/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9637 - loss: 0.1293
# Epoch 145: Test Loss: 0.34106945991516113, Test Accuracy: 0.9068182110786438
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9637 - loss: 0.1291 - epoch: 145.0000
# Epoch 146/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9592 - loss: 0.1314
# Epoch 146: Test Loss: 0.34121569991111755, Test Accuracy: 0.9102272987365723
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9593 - loss: 0.1312 - epoch: 146.0000
# Epoch 147/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9640 - loss: 0.1127
# Epoch 147: Test Loss: 0.3565536141395569, Test Accuracy: 0.9034090638160706
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9641 - loss: 0.1127 - epoch: 147.0000
# Epoch 148/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9671 - loss: 0.1046
# Epoch 148: Test Loss: 0.33175644278526306, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9671 - loss: 0.1047 - epoch: 148.0000
# Epoch 149/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9674 - loss: 0.1150
# Epoch 149: Test Loss: 0.3195735514163971, Test Accuracy: 0.9193181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9675 - loss: 0.1150 - epoch: 149.0000
# Epoch 150/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9640 - loss: 0.1173
# Epoch 150: Test Loss: 0.3199276626110077, Test Accuracy: 0.918181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9641 - loss: 0.1173 - epoch: 150.0000
# Epoch 151/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9633 - loss: 0.1127
# Epoch 151: Test Loss: 0.31786543130874634, Test Accuracy: 0.9170454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9633 - loss: 0.1128 - epoch: 151.0000
# Epoch 152/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9633 - loss: 0.1160
# Epoch 152: Test Loss: 0.3444376587867737, Test Accuracy: 0.9079545736312866
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9633 - loss: 0.1159 - epoch: 152.0000
# Epoch 153/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9709 - loss: 0.1018
# Epoch 153: Test Loss: 0.3273986876010895, Test Accuracy: 0.9056817889213562
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9708 - loss: 0.1020 - epoch: 153.0000
# Epoch 154/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9588 - loss: 0.1177
# Epoch 154: Test Loss: 0.3127208948135376, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9589 - loss: 0.1176 - epoch: 154.0000
# Epoch 155/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9736 - loss: 0.0954
# Epoch 155: Test Loss: 0.30875006318092346, Test Accuracy: 0.9136363863945007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9735 - loss: 0.0956 - epoch: 155.0000
# Epoch 156/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9650 - loss: 0.1107
# Epoch 156: Test Loss: 0.31162765622138977, Test Accuracy: 0.9170454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9650 - loss: 0.1107 - epoch: 156.0000
# Epoch 157/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9692 - loss: 0.1028
# Epoch 157: Test Loss: 0.315677672624588, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9692 - loss: 0.1027 - epoch: 157.0000
# Epoch 158/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9728 - loss: 0.0953
# Epoch 158: Test Loss: 0.32807308435440063, Test Accuracy: 0.9113636612892151
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9728 - loss: 0.0953 - epoch: 158.0000
# Epoch 159/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9768 - loss: 0.0893
# Epoch 159: Test Loss: 0.3220623731613159, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9768 - loss: 0.0893 - epoch: 159.0000
# Epoch 160/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9699 - loss: 0.0952
# Epoch 160: Test Loss: 0.3150142431259155, Test Accuracy: 0.9147727489471436
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9699 - loss: 0.0953 - epoch: 160.0000
# Epoch 161/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9675 - loss: 0.1144
# Epoch 161: Test Loss: 0.30441683530807495, Test Accuracy: 0.9159091114997864
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9676 - loss: 0.1143 - epoch: 161.0000
# Epoch 162/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9683 - loss: 0.1036
# Epoch 162: Test Loss: 0.3097529709339142, Test Accuracy: 0.918181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9684 - loss: 0.1036 - epoch: 162.0000
# Epoch 163/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9608 - loss: 0.1162
# Epoch 163: Test Loss: 0.32200098037719727, Test Accuracy: 0.9170454740524292
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9609 - loss: 0.1161 - epoch: 163.0000
# Epoch 164/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9716 - loss: 0.1036
# Epoch 164: Test Loss: 0.2963794767856598, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9716 - loss: 0.1036 - epoch: 164.0000
# Epoch 165/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9672 - loss: 0.1066
# Epoch 165: Test Loss: 0.29727038741111755, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9672 - loss: 0.1066 - epoch: 165.0000
# Epoch 166/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9656 - loss: 0.1005
# Epoch 166: Test Loss: 0.3009715676307678, Test Accuracy: 0.918181836605072
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9657 - loss: 0.1006 - epoch: 166.0000
# Epoch 167/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9700 - loss: 0.0932
# Epoch 167: Test Loss: 0.30039316415786743, Test Accuracy: 0.9215909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9700 - loss: 0.0932 - epoch: 167.0000
# Epoch 168/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9756 - loss: 0.0915
# Epoch 168: Test Loss: 0.3066868185997009, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9756 - loss: 0.0916 - epoch: 168.0000
# Epoch 169/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9824 - loss: 0.0781
# Epoch 169: Test Loss: 0.3071744740009308, Test Accuracy: 0.9193181991577148
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9823 - loss: 0.0783 - epoch: 169.0000
# Epoch 170/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9776 - loss: 0.0928
# Epoch 170: Test Loss: 0.29819348454475403, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9775 - loss: 0.0929 - epoch: 170.0000
# Epoch 171/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9733 - loss: 0.0924
# Epoch 171: Test Loss: 0.3013532757759094, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9733 - loss: 0.0924 - epoch: 171.0000
# Epoch 172/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9761 - loss: 0.0843
# Epoch 172: Test Loss: 0.29494521021842957, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9760 - loss: 0.0845 - epoch: 172.0000
# Epoch 173/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9736 - loss: 0.1005
# Epoch 173: Test Loss: 0.2999298870563507, Test Accuracy: 0.9238636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9737 - loss: 0.1003 - epoch: 173.0000
# Epoch 174/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9766 - loss: 0.0856
# Epoch 174: Test Loss: 0.3070533871650696, Test Accuracy: 0.9215909242630005
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9765 - loss: 0.0856 - epoch: 174.0000
# Epoch 175/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9751 - loss: 0.0885
# Epoch 175: Test Loss: 0.2938741147518158, Test Accuracy: 0.9238636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9750 - loss: 0.0886 - epoch: 175.0000
# Epoch 176/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9730 - loss: 0.0845
# Epoch 176: Test Loss: 0.30767199397087097, Test Accuracy: 0.9261363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9730 - loss: 0.0846 - epoch: 176.0000
# Epoch 177/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9799 - loss: 0.0800
# Epoch 177: Test Loss: 0.3080688714981079, Test Accuracy: 0.925000011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9799 - loss: 0.0800 - epoch: 177.0000
# Epoch 178/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9778 - loss: 0.0890
# Epoch 178: Test Loss: 0.30252161622047424, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9778 - loss: 0.0889 - epoch: 178.0000
# Epoch 179/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9739 - loss: 0.0893
# Epoch 179: Test Loss: 0.28364819288253784, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9739 - loss: 0.0893 - epoch: 179.0000
# Epoch 180/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9759 - loss: 0.0818
# Epoch 180: Test Loss: 0.29118603467941284, Test Accuracy: 0.925000011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9759 - loss: 0.0817 - epoch: 180.0000
# Epoch 181/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9748 - loss: 0.0819
# Epoch 181: Test Loss: 0.3038271963596344, Test Accuracy: 0.9227272868156433
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9748 - loss: 0.0819 - epoch: 181.0000
# Epoch 182/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9772 - loss: 0.0779
# Epoch 182: Test Loss: 0.2934688925743103, Test Accuracy: 0.9261363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9772 - loss: 0.0780 - epoch: 182.0000
# Epoch 183/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9817 - loss: 0.0769
# Epoch 183: Test Loss: 0.2877940833568573, Test Accuracy: 0.9261363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9816 - loss: 0.0769 - epoch: 183.0000
# Epoch 184/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9739 - loss: 0.0852
# Epoch 184: Test Loss: 0.284361332654953, Test Accuracy: 0.9238636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9739 - loss: 0.0851 - epoch: 184.0000
# Epoch 185/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9781 - loss: 0.0772
# Epoch 185: Test Loss: 0.28632932901382446, Test Accuracy: 0.9295454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9782 - loss: 0.0772 - epoch: 185.0000
# Epoch 186/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9831 - loss: 0.0698
# Epoch 186: Test Loss: 0.2911960184574127, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9831 - loss: 0.0699 - epoch: 186.0000
# Epoch 187/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9751 - loss: 0.0887
# Epoch 187: Test Loss: 0.29420867562294006, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9751 - loss: 0.0887 - epoch: 187.0000
# Epoch 188/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9731 - loss: 0.0860
# Epoch 188: Test Loss: 0.29619964957237244, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9731 - loss: 0.0859 - epoch: 188.0000
# Epoch 189/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9802 - loss: 0.0772
# Epoch 189: Test Loss: 0.29795122146606445, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9802 - loss: 0.0771 - epoch: 189.0000
# Epoch 190/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9824 - loss: 0.0647
# Epoch 190: Test Loss: 0.29890406131744385, Test Accuracy: 0.9295454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9824 - loss: 0.0649 - epoch: 190.0000
# Epoch 191/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9741 - loss: 0.0798
# Epoch 191: Test Loss: 0.2889741361141205, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9741 - loss: 0.0799 - epoch: 191.0000
# Epoch 192/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9766 - loss: 0.0797
# Epoch 192: Test Loss: 0.28168800473213196, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9766 - loss: 0.0797 - epoch: 192.0000
# Epoch 193/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9806 - loss: 0.0699
# Epoch 193: Test Loss: 0.27550292015075684, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9806 - loss: 0.0700 - epoch: 193.0000
# Epoch 194/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9797 - loss: 0.0776
# Epoch 194: Test Loss: 0.2818654775619507, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9797 - loss: 0.0776 - epoch: 194.0000
# Epoch 195/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9765 - loss: 0.0808
# Epoch 195: Test Loss: 0.28979039192199707, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9765 - loss: 0.0807 - epoch: 195.0000
# Epoch 196/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9792 - loss: 0.0738
# Epoch 196: Test Loss: 0.28495094180107117, Test Accuracy: 0.9329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9791 - loss: 0.0739 - epoch: 196.0000
# Epoch 197/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9787 - loss: 0.0704
# Epoch 197: Test Loss: 0.28492262959480286, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9788 - loss: 0.0704 - epoch: 197.0000
# Epoch 198/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9795 - loss: 0.0797
# Epoch 198: Test Loss: 0.28767484426498413, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9795 - loss: 0.0797 - epoch: 198.0000
# Epoch 199/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9811 - loss: 0.0723
# Epoch 199: Test Loss: 0.2805628478527069, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9811 - loss: 0.0724 - epoch: 199.0000
# Epoch 200/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9815 - loss: 0.0675
# Epoch 200: Test Loss: 0.2824092507362366, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9815 - loss: 0.0675 - epoch: 200.0000
# Epoch 201/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9805 - loss: 0.0684
# Epoch 201: Test Loss: 0.28936007618904114, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9805 - loss: 0.0684 - epoch: 201.0000
# Epoch 202/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0648
# Epoch 202: Test Loss: 0.29592153429985046, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9856 - loss: 0.0648 - epoch: 202.0000
# Epoch 203/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9795 - loss: 0.0689
# Epoch 203: Test Loss: 0.28799721598625183, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9795 - loss: 0.0689 - epoch: 203.0000
# Epoch 204/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9810 - loss: 0.0725
# Epoch 204: Test Loss: 0.29013004899024963, Test Accuracy: 0.9295454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9810 - loss: 0.0725 - epoch: 204.0000
# Epoch 205/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9828 - loss: 0.0632
# Epoch 205: Test Loss: 0.2856418788433075, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9827 - loss: 0.0633 - epoch: 205.0000
# Epoch 206/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9839 - loss: 0.0633
# Epoch 206: Test Loss: 0.28675228357315063, Test Accuracy: 0.9261363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9839 - loss: 0.0633 - epoch: 206.0000
# Epoch 207/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9779 - loss: 0.0774
# Epoch 207: Test Loss: 0.2905953824520111, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9780 - loss: 0.0772 - epoch: 207.0000
# Epoch 208/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9809 - loss: 0.0690
# Epoch 208: Test Loss: 0.2777382731437683, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9809 - loss: 0.0691 - epoch: 208.0000
# Epoch 209/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 0.0636
# Epoch 209: Test Loss: 0.2819124162197113, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9862 - loss: 0.0637 - epoch: 209.0000
# Epoch 210/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9781 - loss: 0.0738
# Epoch 210: Test Loss: 0.28509482741355896, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9782 - loss: 0.0737 - epoch: 210.0000
# Epoch 211/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9814 - loss: 0.0669
# Epoch 211: Test Loss: 0.2838359475135803, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9814 - loss: 0.0668 - epoch: 211.0000
# Epoch 212/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0560
# Epoch 212: Test Loss: 0.28923508524894714, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9873 - loss: 0.0560 - epoch: 212.0000
# Epoch 213/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9850 - loss: 0.0659
# Epoch 213: Test Loss: 0.2816663086414337, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9850 - loss: 0.0658 - epoch: 213.0000
# Epoch 214/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9805 - loss: 0.0645
# Epoch 214: Test Loss: 0.2928791046142578, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9805 - loss: 0.0646 - epoch: 214.0000
# Epoch 215/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9800 - loss: 0.0707
# Epoch 215: Test Loss: 0.28030672669410706, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9800 - loss: 0.0707 - epoch: 215.0000
# Epoch 216/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.0665
# Epoch 216: Test Loss: 0.28899484872817993, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9843 - loss: 0.0665 - epoch: 216.0000
# Epoch 217/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9776 - loss: 0.0729
# Epoch 217: Test Loss: 0.2827500104904175, Test Accuracy: 0.9329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9777 - loss: 0.0728 - epoch: 217.0000
# Epoch 218/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9881 - loss: 0.0537
# Epoch 218: Test Loss: 0.2806480824947357, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9881 - loss: 0.0538 - epoch: 218.0000
# Epoch 219/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9877 - loss: 0.0560
# Epoch 219: Test Loss: 0.2866935431957245, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9877 - loss: 0.0560 - epoch: 219.0000
# Epoch 220/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9848 - loss: 0.0560
# Epoch 220: Test Loss: 0.28514522314071655, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9849 - loss: 0.0560 - epoch: 220.0000
# Epoch 221/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9795 - loss: 0.0641
# Epoch 221: Test Loss: 0.2915884554386139, Test Accuracy: 0.9295454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9795 - loss: 0.0640 - epoch: 221.0000
# Epoch 222/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9876 - loss: 0.0572
# Epoch 222: Test Loss: 0.2890665531158447, Test Accuracy: 0.9295454621315002
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9876 - loss: 0.0572 - epoch: 222.0000
# Epoch 223/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9854 - loss: 0.0575
# Epoch 223: Test Loss: 0.29027503728866577, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9854 - loss: 0.0576 - epoch: 223.0000
# Epoch 224/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9760 - loss: 0.0760
# Epoch 224: Test Loss: 0.29561755061149597, Test Accuracy: 0.9238636493682861
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9761 - loss: 0.0758 - epoch: 224.0000
# Epoch 225/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.0615
# Epoch 225: Test Loss: 0.2862139940261841, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9843 - loss: 0.0614 - epoch: 225.0000
# Epoch 226/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9845 - loss: 0.0529
# Epoch 226: Test Loss: 0.27906036376953125, Test Accuracy: 0.9340909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9845 - loss: 0.0529 - epoch: 226.0000
# Epoch 227/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9873 - loss: 0.0554
# Epoch 227: Test Loss: 0.2810059189796448, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9873 - loss: 0.0553 - epoch: 227.0000
# Epoch 228/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.0594
# Epoch 228: Test Loss: 0.2796892821788788, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9843 - loss: 0.0594 - epoch: 228.0000
# Epoch 229/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9841 - loss: 0.0563
# Epoch 229: Test Loss: 0.28438201546669006, Test Accuracy: 0.9329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9842 - loss: 0.0563 - epoch: 229.0000
# Epoch 230/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9803 - loss: 0.0660
# Epoch 230: Test Loss: 0.273934543132782, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9803 - loss: 0.0659 - epoch: 230.0000
# Epoch 231/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9860 - loss: 0.0531
# Epoch 231: Test Loss: 0.28194400668144226, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9860 - loss: 0.0531 - epoch: 231.0000
# Epoch 232/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9837 - loss: 0.0604
# Epoch 232: Test Loss: 0.2885356545448303, Test Accuracy: 0.9272727370262146
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9838 - loss: 0.0604 - epoch: 232.0000
# Epoch 233/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9861 - loss: 0.0528
# Epoch 233: Test Loss: 0.30241599678993225, Test Accuracy: 0.9261363744735718
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9861 - loss: 0.0528 - epoch: 233.0000
# Epoch 234/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 0.0576
# Epoch 234: Test Loss: 0.29648271203041077, Test Accuracy: 0.925000011920929
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9843 - loss: 0.0576 - epoch: 234.0000
# Epoch 235/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9839 - loss: 0.0532
# Epoch 235: Test Loss: 0.2848316431045532, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9839 - loss: 0.0532 - epoch: 235.0000
# Epoch 236/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9823 - loss: 0.0538
# Epoch 236: Test Loss: 0.2801964282989502, Test Accuracy: 0.9329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9823 - loss: 0.0539 - epoch: 236.0000
# Epoch 237/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0598
# Epoch 237: Test Loss: 0.26912596821784973, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9856 - loss: 0.0597 - epoch: 237.0000
# Epoch 238/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9850 - loss: 0.0482
# Epoch 238: Test Loss: 0.27632731199264526, Test Accuracy: 0.9340909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9850 - loss: 0.0482 - epoch: 238.0000
# Epoch 239/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9833 - loss: 0.0643
# Epoch 239: Test Loss: 0.2687007188796997, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9833 - loss: 0.0642 - epoch: 239.0000
# Epoch 240/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9788 - loss: 0.0603
# Epoch 240: Test Loss: 0.27987140417099, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9789 - loss: 0.0602 - epoch: 240.0000
# Epoch 241/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9863 - loss: 0.0528
# Epoch 241: Test Loss: 0.26673370599746704, Test Accuracy: 0.9375
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9862 - loss: 0.0529 - epoch: 241.0000
# Epoch 242/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0557
# Epoch 242: Test Loss: 0.27181097865104675, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9856 - loss: 0.0556 - epoch: 242.0000
# Epoch 243/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9841 - loss: 0.0589
# Epoch 243: Test Loss: 0.2734892666339874, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9841 - loss: 0.0589 - epoch: 243.0000
# Epoch 244/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9857 - loss: 0.0520
# Epoch 244: Test Loss: 0.26896753907203674, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9857 - loss: 0.0520 - epoch: 244.0000
# Epoch 245/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9846 - loss: 0.0554
# Epoch 245: Test Loss: 0.28128519654273987, Test Accuracy: 0.9306818246841431
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9846 - loss: 0.0554 - epoch: 245.0000
# Epoch 246/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9830 - loss: 0.0587
# Epoch 246: Test Loss: 0.27128419280052185, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9831 - loss: 0.0585 - epoch: 246.0000
# Epoch 247/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9811 - loss: 0.0620
# Epoch 247: Test Loss: 0.2669232487678528, Test Accuracy: 0.9375
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9812 - loss: 0.0619 - epoch: 247.0000
# Epoch 248/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0544
# Epoch 248: Test Loss: 0.2703167498111725, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9857 - loss: 0.0543 - epoch: 248.0000
# Epoch 249/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9865 - loss: 0.0535
# Epoch 249: Test Loss: 0.27851971983909607, Test Accuracy: 0.9340909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9865 - loss: 0.0535 - epoch: 249.0000
# Epoch 250/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9879 - loss: 0.0457
# Epoch 250: Test Loss: 0.2829170823097229, Test Accuracy: 0.9284090995788574
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9879 - loss: 0.0457 - epoch: 250.0000
# Epoch 251/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9814 - loss: 0.0596
# Epoch 251: Test Loss: 0.2743540406227112, Test Accuracy: 0.9340909123420715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9815 - loss: 0.0595 - epoch: 251.0000
# Epoch 252/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9856 - loss: 0.0543
# Epoch 252: Test Loss: 0.2716986835002899, Test Accuracy: 0.9318181872367859
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9855 - loss: 0.0544 - epoch: 252.0000
# Epoch 253/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9897 - loss: 0.0439
# Epoch 253: Test Loss: 0.27208414673805237, Test Accuracy: 0.9352272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9897 - loss: 0.0440 - epoch: 253.0000
# Epoch 254/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9924 - loss: 0.0399
# Epoch 254: Test Loss: 0.2625744342803955, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9923 - loss: 0.0400 - epoch: 254.0000
# Epoch 255/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9881 - loss: 0.0476
# Epoch 255: Test Loss: 0.2725767493247986, Test Accuracy: 0.9352272748947144
# ...
# Epoch 288/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9956 - loss: 0.0333
# Epoch 288: Test Loss: 0.28133317828178406, Test Accuracy: 0.9375
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9956 - loss: 0.0334 - epoch: 288.0000
# Epoch 289/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9928 - loss: 0.0365
# Epoch 289: Test Loss: 0.2806592881679535, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9928 - loss: 0.0365 - epoch: 289.0000
# Epoch 290/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0371
# Epoch 290: Test Loss: 0.2761041522026062, Test Accuracy: 0.9375
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9909 - loss: 0.0372 - epoch: 290.0000
# Epoch 291/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0446
# Epoch 291: Test Loss: 0.2740604877471924, Test Accuracy: 0.9397727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9874 - loss: 0.0445 - epoch: 291.0000
# Epoch 292/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9877 - loss: 0.0397
# Epoch 292: Test Loss: 0.2751479148864746, Test Accuracy: 0.9397727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9877 - loss: 0.0397 - epoch: 292.0000
# Epoch 293/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0367
# Epoch 293: Test Loss: 0.2800418436527252, Test Accuracy: 0.9352272748947144
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9923 - loss: 0.0367 - epoch: 293.0000
# Epoch 294/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 0.0405
# Epoch 294: Test Loss: 0.27895036339759827, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9898 - loss: 0.0405 - epoch: 294.0000
# Epoch 295/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9847 - loss: 0.0431
# Epoch 295: Test Loss: 0.2788698673248291, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9847 - loss: 0.0431 - epoch: 295.0000
# Epoch 296/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 0.0446
# Epoch 296: Test Loss: 0.27493128180503845, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9873 - loss: 0.0445 - epoch: 296.0000
# Epoch 297/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0366
# Epoch 297: Test Loss: 0.27585363388061523, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9921 - loss: 0.0366 - epoch: 297.0000
# Epoch 298/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9887 - loss: 0.0379
# Epoch 298: Test Loss: 0.2775646448135376, Test Accuracy: 0.9375
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9887 - loss: 0.0379 - epoch: 298.0000
# Epoch 299/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9914 - loss: 0.0394
# Epoch 299: Test Loss: 0.27327337861061096, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9914 - loss: 0.0394 - epoch: 299.0000
# Epoch 300/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9944 - loss: 0.0290
# Epoch 300: Test Loss: 0.26953989267349243, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9943 - loss: 0.0290 - epoch: 300.0000
# Epoch 301/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9916 - loss: 0.0387
# Epoch 301: Test Loss: 0.2673046290874481, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9916 - loss: 0.0386 - epoch: 301.0000
# Epoch 302/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9909 - loss: 0.0359
# Epoch 302: Test Loss: 0.2707188129425049, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9909 - loss: 0.0359 - epoch: 302.0000
# Epoch 303/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0312
# Epoch 303: Test Loss: 0.27687373757362366, Test Accuracy: 0.9363636374473572
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9945 - loss: 0.0312 - epoch: 303.0000
# Epoch 304/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9931 - loss: 0.0291
# Epoch 304: Test Loss: 0.28092095255851746, Test Accuracy: 0.9329545497894287
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9931 - loss: 0.0292 - epoch: 304.0000
# Epoch 305/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9874 - loss: 0.0431
# Epoch 305: Test Loss: 0.2732226252555847, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9874 - loss: 0.0430 - epoch: 305.0000
# Epoch 306/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9894 - loss: 0.0367
# Epoch 306: Test Loss: 0.2724803686141968, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9894 - loss: 0.0367 - epoch: 306.0000
# Epoch 307/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9941 - loss: 0.0305
# Epoch 307: Test Loss: 0.27357932925224304, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9941 - loss: 0.0306 - epoch: 307.0000
# Epoch 308/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0337
# Epoch 308: Test Loss: 0.2701645493507385, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9927 - loss: 0.0337 - epoch: 308.0000
# Epoch 309/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 0.0291
# Epoch 309: Test Loss: 0.2710611820220947, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9947 - loss: 0.0292 - epoch: 309.0000
# Epoch 310/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9903 - loss: 0.0371
# Epoch 310: Test Loss: 0.27492547035217285, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9903 - loss: 0.0371 - epoch: 310.0000
# Epoch 311/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0373
# Epoch 311: Test Loss: 0.27225106954574585, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9927 - loss: 0.0374 - epoch: 311.0000
# Epoch 312/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9924 - loss: 0.0315
# Epoch 312: Test Loss: 0.2755557894706726, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9923 - loss: 0.0316 - epoch: 312.0000
# Epoch 313/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.0277
# Epoch 313: Test Loss: 0.2818809747695923, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9952 - loss: 0.0277 - epoch: 313.0000
# Epoch 314/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9931 - loss: 0.0300
# Epoch 314: Test Loss: 0.2767682373523712, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9931 - loss: 0.0300 - epoch: 314.0000
# Epoch 315/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9900 - loss: 0.0356
# Epoch 315: Test Loss: 0.2740129232406616, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9900 - loss: 0.0357 - epoch: 315.0000
# Epoch 316/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9882 - loss: 0.0427
# Epoch 316: Test Loss: 0.27221161127090454, Test Accuracy: 0.9465909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9882 - loss: 0.0426 - epoch: 316.0000
# Epoch 317/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0374
# Epoch 317: Test Loss: 0.27377039194107056, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9904 - loss: 0.0373 - epoch: 317.0000
# Epoch 318/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9943 - loss: 0.0330
# Epoch 318: Test Loss: 0.26958343386650085, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9942 - loss: 0.0330 - epoch: 318.0000
# Epoch 319/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0306
# Epoch 319: Test Loss: 0.2698163390159607, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9946 - loss: 0.0306 - epoch: 319.0000
# Epoch 320/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9930 - loss: 0.0401
# Epoch 320: Test Loss: 0.27219313383102417, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9930 - loss: 0.0400 - epoch: 320.0000
# Epoch 321/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9933 - loss: 0.0320
# Epoch 321: Test Loss: 0.2795982360839844, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9933 - loss: 0.0320 - epoch: 321.0000
# Epoch 322/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9912 - loss: 0.0358
# Epoch 322: Test Loss: 0.27829527854919434, Test Accuracy: 0.9397727251052856
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9911 - loss: 0.0358 - epoch: 322.0000
# Epoch 323/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9938 - loss: 0.0315
# Epoch 323: Test Loss: 0.2827432155609131, Test Accuracy: 0.9386363625526428
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9938 - loss: 0.0315 - epoch: 323.0000
# Epoch 324/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9956 - loss: 0.0271
# Epoch 324: Test Loss: 0.27846717834472656, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9956 - loss: 0.0271 - epoch: 324.0000
# Epoch 325/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9931 - loss: 0.0297
# Epoch 325: Test Loss: 0.2775348424911499, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9931 - loss: 0.0298 - epoch: 325.0000
# Epoch 326/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9902 - loss: 0.0399
# Epoch 326: Test Loss: 0.27013465762138367, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9902 - loss: 0.0398 - epoch: 326.0000
# Epoch 327/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 0.0328
# Epoch 327: Test Loss: 0.2737703323364258, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9939 - loss: 0.0328 - epoch: 327.0000
# Epoch 328/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0279
# Epoch 328: Test Loss: 0.2788836359977722, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9920 - loss: 0.0279 - epoch: 328.0000
# Epoch 329/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9932 - loss: 0.0279
# Epoch 329: Test Loss: 0.27691835165023804, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9932 - loss: 0.0279 - epoch: 329.0000
# Epoch 330/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0314
# Epoch 330: Test Loss: 0.27544355392456055, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9922 - loss: 0.0314 - epoch: 330.0000
# Epoch 331/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9904 - loss: 0.0347
# Epoch 331: Test Loss: 0.27871784567832947, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9904 - loss: 0.0347 - epoch: 331.0000
# Epoch 332/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9893 - loss: 0.0334
# Epoch 332: Test Loss: 0.2742767632007599, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9893 - loss: 0.0334 - epoch: 332.0000
# Epoch 333/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9919 - loss: 0.0348
# Epoch 333: Test Loss: 0.2735535502433777, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9920 - loss: 0.0347 - epoch: 333.0000
# Epoch 334/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9899 - loss: 0.0324
# Epoch 334: Test Loss: 0.27649959921836853, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9899 - loss: 0.0324 - epoch: 334.0000
# Epoch 335/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9927 - loss: 0.0322
# Epoch 335: Test Loss: 0.27403828501701355, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9928 - loss: 0.0322 - epoch: 335.0000
# Epoch 336/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 0.0272
# Epoch 336: Test Loss: 0.2678647041320801, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9905 - loss: 0.0272 - epoch: 336.0000
# Epoch 337/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9934 - loss: 0.0286
# Epoch 337: Test Loss: 0.2704395055770874, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9934 - loss: 0.0287 - epoch: 337.0000
# Epoch 338/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9931 - loss: 0.0318
# Epoch 338: Test Loss: 0.27581164240837097, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9931 - loss: 0.0317 - epoch: 338.0000
# Epoch 339/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9948 - loss: 0.0272
# Epoch 339: Test Loss: 0.2708541452884674, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9948 - loss: 0.0272 - epoch: 339.0000
# Epoch 340/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0333
# Epoch 340: Test Loss: 0.26545029878616333, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9911 - loss: 0.0334 - epoch: 340.0000
# Epoch 341/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0290
# Epoch 341: Test Loss: 0.2727741301059723, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9923 - loss: 0.0290 - epoch: 341.0000
# Epoch 342/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - loss: 0.0287
# Epoch 342: Test Loss: 0.273913711309433, Test Accuracy: 0.9420454502105713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9935 - loss: 0.0287 - epoch: 342.0000
# Epoch 343/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0350
# Epoch 343: Test Loss: 0.27650687098503113, Test Accuracy: 0.9409090876579285
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9869 - loss: 0.0349 - epoch: 343.0000
# Epoch 344/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 0.0287
# Epoch 344: Test Loss: 0.2745435833930969, Test Accuracy: 0.9431818127632141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9945 - loss: 0.0287 - epoch: 344.0000
# Epoch 345/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 0.0306
# Epoch 345: Test Loss: 0.2658315598964691, Test Accuracy: 0.9465909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9923 - loss: 0.0306 - epoch: 345.0000
# Epoch 346/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - loss: 0.0321
# Epoch 346: Test Loss: 0.269294798374176, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9922 - loss: 0.0321 - epoch: 346.0000
# Epoch 347/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9959 - loss: 0.0265
# Epoch 347: Test Loss: 0.2633805572986603, Test Accuracy: 0.9454545378684998
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9959 - loss: 0.0265 - epoch: 347.0000
# Epoch 348/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9942 - loss: 0.0291
# Epoch 348: Test Loss: 0.2679084837436676, Test Accuracy: 0.9465909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9942 - loss: 0.0292 - epoch: 348.0000
# Epoch 349/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9921 - loss: 0.0324
# Epoch 349: Test Loss: 0.26639509201049805, Test Accuracy: 0.9465909004211426
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9920 - loss: 0.0324 - epoch: 349.0000
# Epoch 350/350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9911 - loss: 0.0314
# Epoch 350: Test Loss: 0.27210158109664917, Test Accuracy: 0.9443181753158569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9911 - loss: 0.0314 - epoch: 350.0000

# %%
# Muat data dari file CSV
try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot akurasi dan loss
    plt.figure(figsize=(15, 6))
    plt.suptitle("Sabtu, 10 Agustus - Training Model", fontsize=20)

    # Plot Akurasi Training, Validasi & Testing
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    # plt.plot(epochs, history_df['val_accuracy'], label='Validation Accuracy', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Test Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('Model Accuracy', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    # Plot Loss Training, Validasi & Testing
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    # plt.plot(epochs, history_df['val_loss'], label='Validation Loss', color='green')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Test Loss', color='red')  # Plot Test Loss per epoch
    plt.title('Model Loss', fontsize=15)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# # Evaluate Model

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Muat data dari file CSV
csv_logger_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_train_v1.csv"
test_log_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_csv\\v4.4.8_log_test_v1.csv"

try:
    history_df = pd.read_csv(csv_logger_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {csv_logger_v1}")
    history_df = None

try:
    test_history_df = pd.read_csv(test_log_v1)
except FileNotFoundError:
    print(f"File tidak ditemukan di path: {test_log_v1}")
    test_history_df = None

if history_df is not None and test_history_df is not None:
    # Dapatkan jumlah epoch dari panjang data
    epochs = range(1, len(history_df) + 1)

    # Plot Akurasi
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['accuracy'], label='Training Accuracy', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_accuracy'], label='Testing Accuracy', color='red')  # Plot Test Accuracy per epoch
    plt.title('History of Accuracy', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

    # Plot Loss
    plt.figure(figsize=(10, 4))  # Mengubah ukuran gambar menjadi lebih kecil
    plt.plot(epochs, history_df['loss'], label='Training Loss', color='blue')
    plt.plot(test_history_df['epoch'], test_history_df['test_loss'], label='Testing Loss', color='red')  # Plot Test Loss per epoch
    plt.title('History of Loss', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
import tensorflow as tf

# Filepath model yang disimpan
model_filepath_v1 = "C:\\Users\\USER-03\\W\\projects_skripsi\\save_models\\save_models_keras\\v4.4.8_keras_v1.keras"

# Load the last saved model
model = tf.keras.models.load_model(model_filepath_v1)

# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, log_loss, accuracy_score, classification_report, confusion_matrix

# Prediksi menggunakan model pada data uji
y_pred = model.predict(X_test)
y_pred_probabilities = tf.nn.softmax(y_pred).numpy() 
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Hitung metrik evaluasi
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
log_loss_value = log_loss(y_true_classes, y_pred_probabilities)

# Print metrik evaluasi
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Log Loss: {log_loss_value:.2f}")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step
# Accuracy: 0.94
# Precision: 0.94
# Recall: 0.94
# F1 Score: 0.94
# Log Loss: 2.15

# %%
# Tampilkan classification report yang lengkap
report = classification_report(y_true_classes, y_pred_classes, target_names=AKSARA)
print(report)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Normalisasi confusion matrix untuk mendapatkan persentase
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Tampilkan confusion matrix sebagai heatmap
plt.figure(figsize=(18, 15))
# sns.heatmap(conf_matrix_normalized, annot=True, fmt=".2%", cmap="YlGnBu", xticklabels=AKSARA, yticklabels=AKSARA)
sns.heatmap(conf_matrix_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=AKSARA, yticklabels=AKSARA)

plt.xlabel("Actual Aksara", fontsize=15)
plt.ylabel("Predicted Aksara", fontsize=15)
# plt.title("Confusion Matrix (Percentage)")
plt.title("Confusion Matrix", fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           ba       1.00      0.98      0.99        43
#           ca       0.95      0.93      0.94        45
#           da       0.93      0.91      0.92        44
#          dha       0.93      0.89      0.91        46
#           ga       0.93      0.93      0.93        41
#           ha       0.94      0.94      0.94        47
#           ja       1.00      0.97      0.99        38
#           ka       1.00      0.86      0.93        44
#           la       0.94      0.94      0.94        50
#           ma       0.96      0.96      0.96        52
#           na       0.85      0.95      0.90        37
#          nga       0.95      1.00      0.97        54
#          nya       1.00      0.97      0.99        39
#           pa       0.90      0.98      0.94        45
#           ra       1.00      1.00      1.00        47
#           sa       0.88      0.97      0.92        36
#           ta       0.82      0.95      0.88        44
#          tha       1.00      0.95      0.98        44
#           wa       0.93      0.89      0.91        47
#           ya       0.97      0.84      0.90        37
#
#     accuracy                           0.94       880
#    macro avg       0.94      0.94      0.94       880
# weighted avg       0.94      0.94      0.94       880

# %%
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from sklearn.metrics import classification_report, confusion_matrix

# # Definisikan kelas Aksara
# AKSARA = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma', 
#           'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Muat model dari checkpoint
# try:
#     model = tf.keras.models.load_model(model_filepath_v1)
#     print("Model loaded from checkpoint.")
# except Exception as e:
#     print(f"Failed to load model from checkpoint: {e}")

# # Prediksi menggunakan model pada data uji
# y_pred = model.predict(X_test)
# y_pred_probabilities = tf.nn.softmax(y_pred).numpy()  # Terapkan softmax secara eksplisit jika perlu
# y_pred_classes = np.argmax(y_pred_probabilities, axis=1)
# y_true_classes = np.argmax(y_test, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# # Normalisasi confusion matrix untuk mendapatkan persentase
# conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# # Kelas untuk setiap subset
# subset1_classes = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'Ma']
# subset2_classes = ['na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']

# # Dapatkan indeks untuk setiap subset
# subset1_indices = [AKSARA.index(cls) for cls in subset1_classes]
# subset2_indices = [AKSARA.index(cls) for cls in subset2_classes]

# # Pisahkan confusion matrix untuk dua subset kelas
# conf_matrix_subset1 = conf_matrix_normalized[np.ix_(subset1_indices, subset1_indices)]
# conf_matrix_subset2 = conf_matrix_normalized[np.ix_(subset2_indices, subset2_indices)]

# # Simpan confusion matrix subset 1 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset1, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset1_classes, yticklabels=subset1_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 1 (Percentage)")
# plt.title("Confusion Matrix - Subset 1", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\08Agu_subset1.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# # Simpan confusion matrix subset 2 sebagai gambar
# plt.figure(figsize=(10, 8))
# sns.heatmap(conf_matrix_subset2, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=subset2_classes, yticklabels=subset2_classes)
# plt.xlabel("Actual Aksara", fontsize=15)
# plt.ylabel("Predicted Aksara", fontsize=15)
# # plt.title("Confusion Matrix - Subset 2 (Percentage)")
# plt.title("Confusion Matrix - Subset 2", fontsize=17)
# plt.tight_layout()
# plt.savefig("C:\\Users\\wawn1\\projects_skripsi\\img\\08Agu_subset2.png")  # Simpan sebagai file gambar
# plt.close()  # Tutup plot untuk menghindari overlay

# %% [markdown]
# # Predictive Model

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the function to display images with predictions
def display_images_with_predictions(images, true_labels, predictions, labels, max_images=50):
    num_images = min(len(images), max_images)
    cols = 5
    rows = (num_images + cols - 1) // cols  # Compute number of rows needed

    plt.figure(figsize=(15, 3 * rows))
    
    for i in range(num_images):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        
        # Check if prediction is correct
        correct = true_labels[i] == predictions[i]
        result = "Correct" if correct else "Incorrect"
        color = "green" if correct else "red"
        
        # Adjust title to avoid overlapping
        plt.title(
            f"True: {labels[true_labels[i]]} || Pred: {labels[predictions[i]]}\n{result}",
            color=color,
            fontsize=12,  # Set font size
            pad=5  # Add padding to title
        )
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Load the trained model
model = load_model(model_filepath_v1)

# Perform predictions
y_pred_probabilities = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probabilities, axis=1)

# Convert one-hot encoded y_test to class indices if needed
if y_test.ndim == 2:
    y_test_classes = np.argmax(y_test, axis=1)
else:
    y_test_classes = y_test

# Display some test images with predictions
display_images_with_predictions(X_test, y_test_classes, y_pred_classes, AKSARA)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) # Unblur
    # Apply laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed

# Load the trained model
model = load_model(model_filepath_v1)  # Replace with your model path

# Path to the test image
test_image_path = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ba49.mine2.png"
image_size = IMAGE_SIZE

# Preprocess the image
preprocessed_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
pos = np.argmax(output)

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", output[0][pos])

# Define a variable to store the predicted label
predicted_label = ""

# Print the class based on the position using if-elif
if pos == 0:
    predicted_label = "ba"
elif pos == 1:
    predicted_label = 'ca'
elif pos == 2:
    predicted_label = 'da'
elif pos == 3:
    predicted_label = 'dha'
elif pos == 4:
    predicted_label = 'ga'
elif pos == 5:
    predicted_label = 'ha'
elif pos == 6:
    predicted_label = 'ja'
elif pos == 7:
    predicted_label = 'ka'
elif pos == 8:
    predicted_label = 'la'
elif pos == 9:
    predicted_label = 'ma'
elif pos == 10:
    predicted_label = 'na'
elif pos == 11:
    predicted_label = 'nga'
elif pos == 12:
    predicted_label = 'nya'
elif pos == 13:
    predicted_label = 'pa'
elif pos == 14:
    predicted_label = 'ra'
elif pos == 15:
    predicted_label = 'sa'
elif pos == 16:
    predicted_label = 'ta'
elif pos == 17:
    predicted_label = 'tha'
elif pos == 18:
    predicted_label = 'wa'
elif pos == 19:
    predicted_label = 'ya'

# Print the predicted label
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(image.img_to_array(image.load_img(test_image_path, target_size=image_size, color_mode='grayscale')))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
# plt.title(f"Predicted: {predicted_label} || Score: {output[0][pos]:.8f}")
plt.title(f"Predicted: {predicted_label}", fontsize=15)
plt.axis('on')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Prediction output:
#  [[9.7859496e-01 4.0490141e-07 4.2244537e-09 3.1959706e-07 2.1000624e-05
#   7.1240233e-06 2.9599432e-06 5.8240982e-08 6.6179581e-08 3.6436251e-07
#   2.2474895e-08 1.7902356e-02 1.8169204e-07 6.9512322e-07 9.9437180e-08
#   1.4882081e-08 2.6341170e-06 4.2268843e-07 3.4661444e-03 5.9586620e-09]]
# Score:  0.97859496
# Aksara:  ba

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) 
    # Apply Laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed, img_array_resized  # Return both images if needed

# Load the trained model
model = load_model(model_filepath_v1)

# Path to the test image
test_image_path = "C:\\Users\\USER-03\\W\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\ba49.mine2.png"
image_size = (96, 96)  # Define your image size

# Preprocess the image
preprocessed_image, original_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
max_val = output[0][0]
pos = 0
for i in range(1, len(output[0])):
    if output[0][i] > max_val:
        max_val = output[0][i]
        pos = i

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", max_val)

# Define labels
labels = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 
          'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']
predicted_label = labels[pos]
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(cv2.resize(image.img_to_array(image.load_img(test_image_path, color_mode='grayscale')), image_size, interpolation=cv2.INTER_AREA))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
plt.title(f"Predicted: {predicted_label}")
plt.axis('on')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Prediction output:
#  [[9.7859496e-01 4.0490141e-07 4.2244537e-09 3.1959706e-07 2.1000624e-05
#   7.1240233e-06 2.9599432e-06 5.8240982e-08 6.6179581e-08 3.6436251e-07
#   2.2474895e-08 1.7902356e-02 1.8169204e-07 6.9512322e-07 9.9437180e-08
#   1.4882081e-08 2.6341170e-06 4.2268843e-07 3.4661444e-03 5.9586620e-09]]
# Score:  0.97859496
# Aksara:  ba

# %%
import numpy as np
import cv2
from keras.preprocessing import image
from keras.models import load_model
import matplotlib.pyplot as plt

# Define the custom preprocessing function
def apply_custom_preprocessing(image):
    # Convert image to uint8 if not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
        
    # Apply Gaussian Blur
    ApplyGaussian = cv2.GaussianBlur(image, (15, 15), 0.1) 
    # Apply Laplacian filter 
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    img = cv2.filter2D(ApplyGaussian, -1, kernel)
    # Remove noise using median filter
    img = cv2.medianBlur(img, 1)
    # Apply Otsu's thresholding
    thresh = 0
    maxValue = 255
    
    th, img = cv2.threshold(img, thresh, maxValue, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)    
    return img

# Define the function to preprocess the image
def preprocess_image(img_path, image_size):
    # Load the image
    img = image.load_img(img_path, color_mode='grayscale')
    # Convert the image to array
    img_array = image.img_to_array(img)
    
    # Resize the image using INTER_AREA interpolation
    img_array_resized = cv2.resize(img_array, image_size, interpolation=cv2.INTER_AREA)
    
    # Apply custom preprocessing
    img_array_preprocessed = apply_custom_preprocessing(img_array_resized)
    
    # Normalize the image
    img_array_preprocessed = img_array_preprocessed.astype("float32") / 255.0
    # Expand dimensions to match input shape
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=-1)
    img_array_preprocessed = np.expand_dims(img_array_preprocessed, axis=0)
    
    return img_array_preprocessed, img_array_resized  # Return both images if needed

# Load the trained model
model = load_model(model_filepath_v1)

# Path to the test image
test_image_path = "C:\\Users\\wawn1\\projects_skripsi\\data\\data_original\\CustomData\\data_prediction\\nga220.pred.png"
image_size = (96, 96)  # Define your image size

# Preprocess the image
preprocessed_image, original_image = preprocess_image(test_image_path, image_size)

# Perform the prediction
output = model.predict(preprocessed_image)

# Find the index of the maximum value in the output
max_val = output[0][0]
pos = 0
for i in range(1, len(output[0])):
    if output[0][i] > max_val:
        max_val = output[0][i]
        pos = i

# Print the result based on the index
print("Prediction output:\n", output)
print("Score: ", max_val)

# Define labels
labels = ['ba', 'ca', 'da', 'dha', 'ga', 'ha', 'ja', 'ka', 'la', 'ma', 
          'na', 'nga', 'nya', 'pa', 'ra', 'sa', 'ta', 'tha', 'wa', 'ya']
predicted_label = labels[pos]
print("Aksara: ", predicted_label)

# Display the preprocessed image with prediction
plt.figure(figsize=(5, 5))

# Preprocessed Image
preprocessed_for_display = apply_custom_preprocessing(cv2.resize(image.img_to_array(image.load_img(test_image_path, color_mode='grayscale')), image_size, interpolation=cv2.INTER_AREA))
plt.imshow(preprocessed_for_display.squeeze(), cmap='gray')
plt.title(f"Predicted: {predicted_label}")
plt.axis('on')

plt.show()
